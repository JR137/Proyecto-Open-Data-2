# %% [markdown]
# # Checkpoint 1 POD II

# %% [markdown]
# ##### Luis de la Rubia y Ángel Arroyo

# %% [markdown]
# En este checkpoint realizaremos la creacion de la base de datos, la inserción de los datos de los csv de los accidentes de trafico en Madrid, y algunas consultas SQL

# %% [markdown]
# ### Creación de la Base de datos

# %% [markdown]
# El código utiliza el módulo MySQLdb para interactuar con una base de datos MySQL.

# %%
import MySQLdb

# %% [markdown]
# Primero se define configuraciones iniciales para la conexión a la base de datos sin especificar el nombre de la base de datos

# %%
# Configuración inicial de la conexión sin especificar la base de datos
db_initial_config = {
    "host": "127.0.0.1",
    "user": "root",
    "passwd": "1234"
}

# %% [markdown]
# Luego se conecta al servidor MySQL para crear una nueva base de datos si no existe (POD2).

# %%
# Conexión inicial para crear la base de datos
db_initial = MySQLdb.connect(**db_initial_config)
cur_initial = db_initial.cursor()

# %% [markdown]
# Después de crear la base de datos, cierra la conexión inicial.

# %%
# Crear la base de datos si no existe
cur_initial.execute("CREATE DATABASE IF NOT EXISTS POD2_PRUEBA1;")
cur_initial.close()
db_initial.close()

# %% [markdown]
# A continuación, define configuraciones para conectarse a la base de datos específica (POD2).

# %%
# Configuración de la conexión especificando la base de datos
db_config = {
    "host": "127.0.0.1",
    "user": "root",
    "passwd": "1234",
    "db": "POD2_PRUEBA1"
}

# %% [markdown]
# Se conecta a la base de datos especificada

# %%
# Conexión a la base de datos específica
db = MySQLdb.connect(**db_config)
cur = db.cursor()

# %% [markdown]
# Define comandos SQL para crear tablas si no existen.

# %%
sql_commands = [
    "CREATE TABLE IF NOT EXISTS distritos (cod_distrito INT, nombre VARCHAR(255) NOT NULL, PRIMARY KEY(nombre))",
    "CREATE TABLE IF NOT EXISTS lesividad (cod_lesividad INT PRIMARY KEY, descripcion VARCHAR(255))",
    "CREATE TABLE IF NOT EXISTS fechas (fecha DATE PRIMARY KEY, año INT, mes VARCHAR(50), dia INT)",
    "CREATE TABLE IF NOT EXISTS accidentes_de_trafico (id_accidente INT PRIMARY KEY AUTO_INCREMENT, num_expediente VARCHAR(255), fecha DATE, hora TIME, localizacion VARCHAR(255), numero INT, nombre_distrito VARCHAR(255), tipo_accidente VARCHAR(255), estado_meteorológico VARCHAR(255), coordenada_x_utm VARCHAR(50), coordenada_y_utm VARCHAR(50), positiva_alcohol VARCHAR(50), positiva_droga VARCHAR(50), momento_dia VARCHAR(50), FOREIGN KEY (nombre_distrito) REFERENCES distritos(nombre), FOREIGN KEY (fecha) REFERENCES fechas(fecha))",
    "CREATE INDEX idx_num_expediente ON accidentes_de_trafico(num_expediente)",
    "CREATE TABLE IF NOT EXISTS personas (id_persona INT PRIMARY KEY AUTO_INCREMENT, num_expediente VARCHAR(255), tipo_persona VARCHAR(50), rango_edad VARCHAR(50), sexo VARCHAR(50), cod_lesividad INT, FOREIGN KEY (num_expediente) REFERENCES accidentes_de_trafico(num_expediente) ON DELETE CASCADE, FOREIGN KEY (cod_lesividad) REFERENCES lesividad(cod_lesividad))",
    "CREATE TABLE IF NOT EXISTS vehiculos (id_vehiculo INT PRIMARY KEY AUTO_INCREMENT, num_expediente VARCHAR(255), tipo_vehiculo VARCHAR(255), FOREIGN KEY (num_expediente) REFERENCES accidentes_de_trafico(num_expediente) ON DELETE CASCADE)",
    "CREATE TABLE IF NOT EXISTS radares (n_radar INT PRIMARY KEY, ubicacion VARCHAR(255), carretera_vial VARCHAR(255), ubicacion_calle_30 VARCHAR(255), pk VARCHAR(500), sentido VARCHAR(50), tipo VARCHAR(50), x_wgs84 VARCHAR(255), y_wgs84 VARCHAR(255), longitud VARCHAR(255), latitud VARCHAR(255), coordenadas VARCHAR(255))",
    "CREATE TABLE IF NOT EXISTS aforo_trafico (id_aforo INT PRIMARY KEY AUTO_INCREMENT, fecha DATE, part_of_day VARCHAR(50), hor1 FLOAT, hor2 FLOAT, hor3 FLOAT, hor4 FLOAT, hor5 FLOAT, hor6 FLOAT, hor7 FLOAT, hor8 FLOAT, hor9 FLOAT, hor10 FLOAT, hor11 FLOAT, hor12 FLOAT, FOREIGN KEY (fecha) REFERENCES fechas(fecha))",
    "CREATE TABLE IF NOT EXISTS centros_educativos (pk INT PRIMARY KEY, nombre VARCHAR(255), nombre_via VARCHAR(255), clase_vial VARCHAR(255), num FLOAT, localidad VARCHAR(255), provincia VARCHAR(255), barrio VARCHAR(255), nombre_distrito VARCHAR(255), coordenada_x INT, coordenada_y INT, latitud FLOAT, longitud FLOAT, FOREIGN KEY (nombre_distrito) REFERENCES distritos(nombre))",
    "CREATE TABLE IF NOT EXISTS estadisticas_bomberos (id_estadistica INT PRIMARY KEY AUTO_INCREMENT, año INT, mes VARCHAR(50), nombre_distrito VARCHAR(255), fuegos INT, daños_en_construccion INT, salvamentos_y_rescates INT, daños_por_agua INT, incidentes_diversos INT, salidas_sin_intervencion INT, servicios_varios INT, total INT, FOREIGN KEY (nombre_distrito) REFERENCES distritos(nombre))"
]

# %% [markdown]
# Itera sobre cada comando SQL y lo ejecuta.
# Si ocurre un error durante la ejecución, imprime el mensaje de error.

# %%
# Ejecutar cada comando SQL individualmente
for command in sql_commands:
    try:
        cur.execute(command)
        db.commit()  # Asegurar que se confirman las transacciones
    except MySQLdb.Error as e:
        print(f"Error {e.args[0]}: {e.args[1]}")

# %% [markdown]
# Después de ejecutar todos los comandos SQL, cierra el cursor y la conexión a la base de datos.

# %%
# Cierra la conexión
cur.close()
db.close()

# %% [markdown]
# ### Inserción de los dataframes en la Base de datos

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Carga de datos

# %%
df_educacion= pd.read_csv('.\\Datos_Limpios\\Datos_Situacion_Educacion_Limpios\\Datos_Situacion_Educacion_Limpios.csv')
df_accidentestrafico=pd.read_csv(".\\Datos_Limpios\\Datos_Accidentes_de_Trafico_Mad_Limpios\\Datos_Accidentes_de_Trafico_Mad_Limpios.csv")
df_bomberos=pd.read_csv('.\\Datos_Limpios\\Datos_Actuaciones_Cuerpo_de_Bomberos_Limpios\\Datos_Actuaciones_Cuerpo_de_Bomberos_Limpios.csv')
df_radares=pd.read_csv('.\\Datos_Limpios\\Datos_Radares_Limpios\\Datos_Radares_Limpios.csv')
df_aforotrafico = pd.read_csv(".\\Datos_Limpios\\Datos_Aforos_de_trafico_Limpios\\Datos_Aforo_de_Trafico_Limpios.csv")

# %% [markdown]
# #### Rellenamos la tabla distrito

# %% [markdown]
# Realizamos un mapeo de los distritos con sus respectivos códigos, por si hay alguno mal

# %%
# Mapeo de distritos
mapeo_distritos = {
    0: 'FUERA TERMINO MUNICIPAL',
    1: 'CENTRO',
    2: 'ARGANZUELA',
    3: 'RETIRO',
    4: 'SALAMANCA',
    5: 'CHAMARTÍN',
    6: 'TETUÁN',
    7: 'CHAMBERÍ',
    8: 'FUENCARRAL-EL PARDO',
    9: 'MONCLOA-ARAVACA',
    10: 'LATINA',
    11: 'CARABANCHEL',
    12: 'USERA',
    13: 'PUENTE DE VALLECAS',
    14: 'MORATALAZ',
    15: 'CIUDAD LINEAL',
    16: 'HORTALEZA',
    17: 'VILLAVERDE',
    18: 'VILLA DE VALLECAS',
    19: 'VICÁLVARO',
    20: 'SAN BLAS-CANILLEJAS',
    21: 'BARAJAS',
    22:'Desconocido'
}

# %% [markdown]
# Conectamos con la base de datos

# %%
# Conexión a la base de datos
conn = MySQLdb.connect(host="127.0.0.1",
                       user="root",
                       passwd="1234",
                       db="POD2_PRUEBA1")
cursor = conn.cursor()

# %% [markdown]
# Insertamos los datos en la Tabla de distritos

# %%
# Insertar datos en la tabla distritos
for cod_distrito, nombre in mapeo_distritos.items():
    cursor.execute("INSERT INTO distritos (cod_distrito, nombre) VALUES (%s, %s)", (cod_distrito, nombre))

# Confirmar la transacción y cerrar la conexión
conn.commit()
conn.close()
print("Inserción completada.")
# Out:
# Inserción completada.

# %% [markdown]
# #### Rellenamos la tabla lesividad

# %% [markdown]
# Realizamos un mapeo con las lesividades con sus respectivos códigos, por si hay alguno mal

# %%
mapeo_lesividad_codigo = {
    'Sin asistencia sanitaria': '14',
    'Asistencia sanitaria sólo en el lugar del accidente': '07',
    'Ingreso inferior o igual a 24 horas': '02',
    'Ingreso superior a 24 horas': '03',
    'Atención en urgencias sin posterior ingreso': '01',
    'Asistencia sanitaria inmediata en centro de salud o mutua': '06',
    'Asistencia sanitaria ambulatoria con posterioridad': '05',
    'Fallecido 24 horas': '04',
}

# %% [markdown]
# Conectamos con la base de datos

# %%
# Conexión a la base de datos
conn = MySQLdb.connect(host="127.0.0.1",
                       user="root",
                       passwd="1234",
                       db="POD2_PRUEBA1")
cursor = conn.cursor()

# %% [markdown]
# Insertamos los datos en la tabla lesividad

# %%
# Insertar datos en la tabla lesividad
for descripcion, codigo in mapeo_lesividad_codigo.items():
    cursor.execute("INSERT INTO lesividad (cod_lesividad, descripcion) VALUES (%s, %s)", (codigo, descripcion))

# Confirmar la transacción y cerrar la conexión
conn.commit()
conn.close()
print("Inserción completada.")
# Out:
# Inserción completada.

# %% [markdown]
# #### Rellenamos la tabla fechas

# %% [markdown]
# Conectamos con la base de datos

# %%
# Definir la conexión a la base de datos
db = MySQLdb.connect(host="127.0.0.1",
                       user="root",
                       passwd="1234",
                       db="POD2_PRUEBA1")

# Crear un cursor para ejecutar las sentencias SQL
cursor = db.cursor()

# %% [markdown]
# Creamos dos tuplas con los distintos meses del año y la cantidad de días por mes

# %%
meses = [
    'enero', 'febrero', 'marzo', 'abril', 'mayo', 'junio',
    'julio', 'agosto', 'septiembre', 'octubre', 'noviembre', 'diciembre'
]

dias_mes = {
    'enero': 31, 'febrero': 28, 'marzo': 31, 'abril': 30, 'mayo': 31, 'junio': 30,
    'julio': 31, 'agosto': 31, 'septiembre': 30, 'octubre': 31, 'noviembre': 30, 'diciembre': 31
}

# %% [markdown]
# Este código genera las fechas del 2018 al 2023 y las inserta en la tabla de fechas

# %%
sql_inserts = []
for año in range(2018, 2024):
    for mes in meses:
        for dia in range(1, dias_mes[mes] + 1):
            fecha = f"{año}-{meses.index(mes) + 1:02d}-{dia:02d}"
            sql_inserts.append(
                f"('{fecha}', {año}, '{mes}', {dia})"
            )

batch_size = 1000
for i in range(0, len(sql_inserts), batch_size):
    batch = sql_inserts[i:i + batch_size]
    sql_batch = ',\n'.join(batch)
    sql_statement = f"INSERT INTO fechas (fecha, año, mes, dia) VALUES\n{sql_batch};"
    cursor.execute(sql_statement)
    db.commit()  # Es importante hacer commit para guardar los cambios en la base de datos

# No olvides cerrar el cursor y la conexión una vez terminado
cursor.close()
db.close()
print("Inserción completada.")
# Out:
# Inserción completada.

# %% [markdown]
# #### Rellenamos la tabla de accidentes de tráfico

# %% [markdown]
# Limpiamos los valores null y los pasamos al formato null en Mysql

# %%
df_accidentestrafico['numero'].fillna(0, inplace=True)

# %%
df_accidentestrafico = df_accidentestrafico.where(pd.notnull(df_accidentestrafico), "NULL")

# %% [markdown]
# Conectamos con la base de datos

# %%
# Conexión a la base de datos
db = MySQLdb.connect(host="127.0.0.1",    # tu host, usualmente localhost
                     user="root",         # tu usuario
                     passwd="1234",  # tu contraseña
                     db="POD2_PRUEBA1")        # el nombre de la base de datos

# Crear un objeto cursor
cur = db.cursor()

# %% [markdown]
# Insertamos los datos en la tabla de accidentes de tráfico

# %%
# Inserción de datos en la tabla accidentes_de_trafico
for _, row in df_accidentestrafico.iterrows():
    try:
        cur.execute('''INSERT INTO accidentes_de_trafico 
                    (num_expediente, fecha, hora, localizacion, numero, nombre_distrito, tipo_accidente, estado_meteorológico, coordenada_x_utm, coordenada_y_utm, positiva_alcohol, positiva_droga, momento_dia) 
                    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)''',
                    (row['num_expediente'], 
                     row['fecha'], 
                     row['hora'], 
                     row['localizacion'], 
                     row['numero'], 
                     row['distrito'],  
                     row['tipo_accidente'], 
                     row['estado_meteorológico'], 
                     row['coordenada_x_utm'], 
                     row['coordenada_y_utm'], 
                     row['positiva_alcohol'], 
                     row['positiva_droga'], 
                     row['momento_dia']))
    except MySQLdb.Error as e:
        print(f"Error: {e}")

db.commit()

# Cerrar el cursor y la conexión
cur.close()
db.close()
print("Inserción completada.")
# Out:
# Inserción completada.

# %% [markdown]
# #### Rellenar tabla de Personas

# %% [markdown]
# Conexión con la base de datos

# %%
# Conexión a la base de datos
db = MySQLdb.connect(host="127.0.0.1",    # tu host, usualmente localhost
                     user="root",         # tu usuario
                     passwd="1234",  # tu contraseña
                     db="POD2_PRUEBA1")        # el nombre de la base de datos

# Preparar el objeto cursor
cur = db.cursor()

# %% [markdown]
# Insertamos los datos en la tabla de personas

# %%
# Iterar sobre el DataFrame y preparar las consultas de inserción
for _, row in df_accidentestrafico.iterrows():
    query = f"""INSERT INTO personas (num_expediente, tipo_persona, rango_edad, sexo, cod_lesividad) 
                VALUES ('{row['num_expediente']}', '{row['tipo_persona'].replace("'", "''")}', '{row['rango_edad'].replace("'", "''")}', '{row['sexo'].replace("'", "''")}', {row['cod_lesividad']});"""
    try:
        cur.execute(query)
    except MySQLdb.Error as e:
        print(f"Error: {e}")

# Confirmar cambios y cerrar la conexión
db.commit()
cur.close()
db.close()
print("Inserción completada.")
# Out:
# Inserción completada.

# %% [markdown]
# ##### Rellenar tabla de Vehiculos

# %% [markdown]
# Conectamos con la base de datos

# %%
db = MySQLdb.connect(host="127.0.0.1", 
                     user="root",         
                     passwd="1234",  
                     db="POD2_PRUEBA1") 
cur = db.cursor()

# %% [markdown]
# Insertamos los datos en la tabla de Vehiculos

# %%
# Iterar sobre el DataFrame y preparar las consultas de inserción para la tabla vehiculos
for _, row in df_accidentestrafico.iterrows():
    # Preparar la consulta SQL para insertar datos en la tabla vehiculos
    query = f"""INSERT INTO vehiculos (num_expediente, tipo_vehiculo) 
                VALUES ('{row['num_expediente']}', '{row['tipo_vehiculo'].replace("'", "''")}');"""
    try:
        # Ejecutar la consulta SQL
        cur.execute(query)
    except MySQLdb.Error as e:
        # Imprimir el error si ocurre alguno
        print(f"Error: {e}")

# Confirmar los cambios
db.commit()

# Cerrar el cursor y la conexión
cur.close()
db.close()
print("Inserción completada.")
# Out:
# Inserción completada.

# %% [markdown]
# #####  Rellenar tabla de Radares

# %%
from sqlalchemy import create_engine

# %% [markdown]
# Conexión a la base de datos

# %%
engine = create_engine('mysql+mysqldb://root:1234@127.0.0.1:3306/POD2_prueba1')

# %% [markdown]
# Insertar los datos en la tabla 'radares'

# %%
df_radares.to_sql(name='radares', con=engine, if_exists='replace', index=False)
cur.close()
db.close()
print("Inserción completada.")
# Out:
# Inserción completada.

# %% [markdown]
# ##### Rellenar tabla de Aforo tráfico

# %% [markdown]
# Conectamos con la base de datos

# %%
# Conexión a la base de datos MySQL
db = MySQLdb.connect(host="127.0.0.1",    # tu host, usualmente localhost
                     user="root",         # tu usuario
                     passwd="1234",  # tu contraseña
                     db="POD2_PRUEBA1")        # el nombre de la base de datos

# Preparar el objeto cursor
cur = db.cursor()

# %% [markdown]
# Cambiamos los nombres de las columnas del dataframe para poder introducirlo en la base de datos

# %%
# Renombrar columnas en df_aforotrafico si es necesario para que coincidan con los nombres de las columnas en la tabla aforo_trafico
df_aforotrafico.rename(columns={
    'FDIA': 'fecha',
    'FEST': 'fest',
    'FSEN': 'fsen',
    'HOR1': 'hor1',
    'HOR2': 'hor2',
    'HOR3': 'hor3',
    'HOR4': 'hor4',
    'HOR5': 'hor5',
    'HOR6': 'hor6',
    'HOR7': 'hor7',
    'HOR8': 'hor8',
    'HOR9': 'hor9',
    'HOR10': 'hor10',
    'HOR11': 'hor11',
    'HOR12': 'hor12',
    'PART_OF_DAY': 'part_of_day'
}, inplace=True)

# %% [markdown]
# Ponemos las fechas en formato fecha

# %%
df_aforotrafico['fecha'] = pd.to_datetime(df_aforotrafico['fecha'])
# Out:
# C:\Users\luisd\AppData\Local\Temp\ipykernel_3336\2431290218.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_aforotrafico['fecha'] = pd.to_datetime(df_aforotrafico['fecha'])

# %% [markdown]
# Conectamos con la base de datos

# %%
# Conexión a la base de datos MySQL
db = MySQLdb.connect(host="127.0.0.1",    # tu host, usualmente localhost
                     user="root",         # tu usuario
                     passwd="1234",  # tu contraseña
                     db="POD2_PRUEBA1")        # el nombre de la base de datos

# Preparar el objeto cursor
cur = db.cursor()

# %% [markdown]
# Hacemos una lista de las fechas presentes en aforo tráfico

# %%
fechas_unicas = df_aforotrafico['fecha'].unique()

# %% [markdown]
# Verificamos y agregamos las fechas faltantes en la tabla fechas

# %%
for fecha in fechas_unicas:
    try:
        cur.execute(f"INSERT IGNORE INTO fechas (fecha) VALUES ('{fecha}')")
    except MySQLdb.Error as e:
        print(f"Error al insertar fecha {fecha} en la tabla fechas: {e}")

# %% [markdown]
# Insertamos los datos en aforo tráfico

# %%
for _, row in df_aforotrafico.iterrows():
    query = f"""INSERT INTO aforo_trafico (fecha, part_of_day, hor1, hor2, hor3, hor4, hor5, hor6, hor7, hor8, hor9, hor10, hor11, hor12) 
                VALUES ('{row['fecha']}', '{row['part_of_day']}', {row['hor1']}, {row['hor2']}, {row['hor3']}, {row['hor4']}, {row['hor5']}, {row['hor6']}, {row['hor7']}, {row['hor8']}, {row['hor9']}, {row['hor10']}, {row['hor11']}, {row['hor12']});"""
    try:
        cur.execute(query)
    except MySQLdb.Error as e:
        print(f"Error al insertar en aforo_trafico: {e}")

# Confirmar los cambios
db.commit()

# Cerrar el cursor y la conexión
cur.close()
db.close()
print("Inserción completada.")
# Out:
# Inserción completada.

# %% [markdown]
# ##### Rellenar tabla de Centros educativos

# %% [markdown]
# Renombramos las columnas de Centros educativos para que coincidan con las de la base de datos

# %%
df_educacion.rename(columns={
    'PK': 'pk',
    'NOMBRE': 'nombre',
    'NOMBRE-VIA': 'nombre_via',
    'CLASE-VIAL': 'clase_vial',
    'NUM': 'num',
    'LOCALIDAD': 'localidad',
    'PROVINCIA': 'provincia',
    'BARRIO': 'nombre_barrio', 
    'DISTRITO': 'nombre_distrito',
    'COORDENADA-X': 'coordenada_x',
    'COORDENADA-Y': 'coordenada_y',
    'LATITUD': 'latitud',
    'LONGITUD': 'longitud'
}, inplace=True)

# %% [markdown]
# Ponemos los valores null de los nombre de los barrios a Desconocido

# %%
df_educacion['nombre_barrio'].fillna('Desconocido', inplace=True)

# %% [markdown]
# Mapeamos los distritos para ponerlos en el mismo formato que en la tabla de Distritos

# %%
# Mapeo de distritos
mapeo_distritos = {
    'CENTRO': 'CENTRO',
    'ARGANZUELA': 'ARGANZUELA',
    'RETIRO': 'RETIRO',
    'SALAMANCA': 'SALAMANCA',
    'CHAMARTIN': 'CHAMARTÍN',
    'TETUAN': 'TETUÁN',
    'CHAMBERI': 'CHAMBERÍ',
    'FUENCARRAL-EL PARDO': 'FUENCARRAL-EL PARDO',
    'MONCLOA-ARAVACA': 'MONCLOA-ARAVACA',
    'LATINA': 'LATINA',
    'CARABANCHEL': 'CARABANCHEL',
    'USERA': 'USERA',
    'PUENTE DE VALLECAS': 'PUENTE DE VALLECAS',
    'MORATALAZ': 'MORATALAZ',
    'CIUDAD LINEAL': 'CIUDAD LINEAL',
    'HORTALEZA': 'HORTALEZA',
    'VILLAVERDE': 'VILLAVERDE',
    'VILLA DE VALLECAS': 'VILLA DE VALLECAS',
    'VICÁLVARO': 'VICÁLVARO',
    'SAN BLAS-CANILLEJAS': 'SAN BLAS-CANILLEJAS',
    'BARAJAS': 'BARAJAS',
    'Desconocido':'Desconocido'
}

# Mapear los nombres de los distritos
df_educacion['nombre_distrito'] = df_educacion['nombre_distrito'].map(mapeo_distritos)

# %% [markdown]
# Ponemos los valores null a Desconocido

# %%
df_educacion['nombre_distrito'].fillna('Desconocido', inplace=True)

# %% [markdown]
# Conectamos con la base de datos

# %%
db = MySQLdb.connect(host="127.0.0.1", user="root", passwd="1234", db="POD2_PRUEBA1")
cur = db.cursor()

# %% [markdown]
# Insertamos los datos en la tabla de Centros educativos

# %%
# Iterar sobre el DataFrame y preparar las consultas de inserción
for _, row in df_educacion.iterrows():
    query = f"""INSERT INTO centros_educativos (pk, nombre, nombre_via, clase_vial, num, localidad, provincia, nombre_distrito, coordenada_x, coordenada_y, latitud, longitud, barrio) 
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"""
    data = (row['pk'], row['nombre'], row['nombre_via'], row['clase_vial'], row['num'], row['localidad'], row['provincia'], row['nombre_distrito'], row['coordenada_x'], row['coordenada_y'], row['latitud'], row['longitud'], row['nombre_barrio'])
    
    try:
        cur.execute(query, data)
    except MySQLdb.Error as e:
        print(f"Error: {e}")

# Confirmar los cambios
db.commit()

# Cerrar el cursor y la conexión
cur.close()
db.close()
print("Inserción completada.")
# Out:
# Inserción completada.

# %% [markdown]
# ##### Rellenar tabla de Bomberos

# %% [markdown]
# Unimos las dos tablas de Fuera del término municipal

# %%
df_bomberos.loc[df_bomberos['DISTRITO'] == 'FUERA DEL TÉRMINO MUNICIPAL', 'DISTRITO'] = 'FUERA TERMINO MUNICIPAL'

# %% [markdown]
# Mapeamos los distritos para que coincidan con los de la tabla de distritos

# %%
# Mapeo de distritos
mapeo_distritos = {
    'CENTRO': 'CENTRO',
    'ARGANZUELA': 'ARGANZUELA',
    'RETIRO': 'RETIRO',
    'SALAMANCA': 'SALAMANCA',
    'CHAMARTIN': 'CHAMARTÍN',
    'TETUAN': 'TETUÁN',
    'CHAMBERI': 'CHAMBERÍ',
    'FUENCARRAL': 'FUENCARRAL-EL PARDO',
    'MONCLOA': 'MONCLOA-ARAVACA',
    'LATINA': 'LATINA',
    'CARABANCHEL': 'CARABANCHEL',
    'USERA': 'USERA',
    'PUENTE VALLECAS': 'PUENTE DE VALLECAS',
    'MORATALAZ': 'MORATALAZ',
    'CIUDAD LINEAL': 'CIUDAD LINEAL',
    'HORTALEZA': 'HORTALEZA',
    'VILLAVERDE': 'VILLAVERDE',
    'VILLA DE VALLECAS': 'VILLA DE VALLECAS',
    'VICALVARO': 'VICÁLVARO',
    'SAN BLAS': 'SAN BLAS-CANILLEJAS',
    'BARAJAS': 'BARAJAS',
    'FUERA TERMINO MUNICIPAL': 'FUERA TERMINO MUNICIPAL'
}

# Mapear los nombres de los distritos
df_bomberos['DISTRITO'] = df_bomberos['DISTRITO'].map(mapeo_distritos)

# %% [markdown]
# Conectamos con la base de datos

# %%
# Configuración de la conexión a la base de datos
db_config = {
    "host": "127.0.0.1",
    "user": "root",
    "passwd": "1234",
    "db": "POD2_PRUEBA1"
}

# Establecer la conexión a la base de datos
db = MySQLdb.connect(**db_config)
cur = db.cursor()

# %% [markdown]
# Insertamos los datos en la tabla de bomberos

# %%
# Iterar sobre el DataFrame y preparar los comandos de inserción
for index, row in df_bomberos.iterrows():
    sql = """INSERT INTO estadisticas_bomberos (año, mes, nombre_distrito, fuegos, daños_en_construccion, salvamentos_y_rescates, daños_por_agua, incidentes_diversos, salidas_sin_intervencion, servicios_varios, total)
             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"""
    values = (row['AÑO'], row['MES'], row['DISTRITO'], row['FUEGOS'], row['DAÑOS EN CONSTRUCCION'], row['SALVAMENTOS Y RESCATES'], row['DAÑOS POR AGUA'], row['INCIDENTES DIVERSOS'], row['SALIDAS SIN INTERVENCION'], row['SERVICIOS VARIOS'], row['TOTAL'])
    
    try:
        cur.execute(sql, values)
    except MySQLdb.Error as e:
        print(f"Error al insertar datos: {e}")

# Confirmar la inserción y cerrar la conexión
db.commit()
cur.close()
db.close()

print("Inserción completada.")
# Out:
# Inserción completada.

# %% [markdown]
# ## Consultas SQL

# %%
# Configuración de la conexión a la base de datos
db_config = {
    "host": "127.0.0.1",
    "user": "root",
    "passwd": "1234",
    "db": "POD2_PRUEBA1"
}

# Establecer la conexión a la base de datos
db = MySQLdb.connect(**db_config)
cur = db.cursor()

# %% [markdown]
# #### Consultas de selección

# %% [markdown]
# Seleccion de los accidentes de tráfico cuando el distrito es en el centro

# %%
query="""SELECT * FROM accidentes_de_trafico WHERE nombre_distrito = 'Centro';"""
cur.execute(query)
cur.fetchall()
# Out:
# ((33,
#   '2021S005215',
#   datetime.date(2021, 1, 4),
#   datetime.timedelta(seconds=13200),
#   'CALL. SAN BERNARDO, 33',
#   33,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (42,
#   '2021S009542',
#   datetime.date(2021, 1, 6),
#   datetime.timedelta(seconds=5340),
#   'PLAZA. CANOVAS DEL CASTILLO, 3',
#   3,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Lluvia débil',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (56,
#   '2021S013718',
#   datetime.date(2021, 1, 8),
#   datetime.timedelta(seconds=10800),
#   'CALL. FOMENTO, 20',
#   20,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (57,
#   '2021S013718',
#   datetime.date(2021, 1, 8),
#   datetime.timedelta(seconds=10800),
#   'CALL. FOMENTO, 20',
#   20,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (121,
#   '2021S020243',
#   datetime.date(2021, 1, 11),
#   datetime.timedelta(seconds=2400),
#   'PLAZA. CORTES / CALL. MARQUES DE CUBAS',
#   2,
#   'CENTRO',
#   'Caída',
#   'LLuvia intensa',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (133,
#   '2021S022758',
#   datetime.date(2021, 1, 12),
#   datetime.timedelta(seconds=2400),
#   'CALL. AMPARO / CALL. TRIBULETE',
#   1,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (203,
#   '2021S000810',
#   datetime.date(2021, 1, 23),
#   datetime.timedelta(seconds=2400),
#   'CALL. GRAN VIA, 39',
#   39,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Nublado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (206,
#   '2021S000931',
#   datetime.date(2021, 1, 24),
#   datetime.timedelta(seconds=5400),
#   'PLAZA. CANOVAS DEL CASTILLO, 5',
#   5,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (207,
#   '2021S000931',
#   datetime.date(2021, 1, 24),
#   datetime.timedelta(seconds=5400),
#   'PLAZA. CANOVAS DEL CASTILLO, 5',
#   5,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (223,
#   '2021S001260',
#   datetime.date(2021, 1, 31),
#   datetime.timedelta(seconds=900),
#   'CALL. GRAN VIA, 78',
#   78,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (224,
#   '2021S001260',
#   datetime.date(2021, 1, 31),
#   datetime.timedelta(seconds=900),
#   'CALL. GRAN VIA, 78',
#   78,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (230,
#   '2021S001354',
#   datetime.date(2021, 2, 2),
#   datetime.timedelta(seconds=9900),
#   'CALL. FUENCARRAL, 102',
#   102,
#   'CENTRO',
#   'Otro',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (262,
#   '2021S009625',
#   datetime.date(2021, 2, 6),
#   datetime.timedelta(seconds=4380),
#   'CALL. HORTALEZA / CALL. INFANTAS',
#   5,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (263,
#   '2021S009622',
#   datetime.date(2021, 2, 6),
#   datetime.timedelta(seconds=5100),
#   'CALL. PRINCESA, 30',
#   30,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (267,
#   '2021S011957',
#   datetime.date(2021, 2, 7),
#   datetime.timedelta(seconds=21000),
#   'CALL. BEATRIZ GALINDO / CALL. SAN BUENAVENTURA',
#   6,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (268,
#   '2021S011957',
#   datetime.date(2021, 2, 7),
#   datetime.timedelta(seconds=21000),
#   'CALL. BEATRIZ GALINDO / CALL. SAN BUENAVENTURA',
#   6,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (280,
#   '2021S013879',
#   datetime.date(2021, 2, 8),
#   datetime.timedelta(seconds=14400),
#   'PLAZA. CAMPILLO DEL MUNDO NUEVO, 2',
#   2,
#   'CENTRO',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (281,
#   '2021S013879',
#   datetime.date(2021, 2, 8),
#   datetime.timedelta(seconds=14400),
#   'PLAZA. CAMPILLO DEL MUNDO NUEVO, 2',
#   2,
#   'CENTRO',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (288,
#   '2021S015235',
#   datetime.date(2021, 2, 9),
#   datetime.timedelta(seconds=9000),
#   'PASEO. PRADO, 26',
#   26,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (315,
#   '2021S002093',
#   datetime.date(2021, 2, 13),
#   datetime.timedelta(0),
#   'CUSTA. SAN VICENTE, 1 FRENTE AL 16',
#   1,
#   'CENTRO',
#   'Otro',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (323,
#   '2021S002301',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=3000),
#   'CALL. CAPITAN SALAZAR MARTINEZ, 2',
#   2,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (324,
#   '2021S002301',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=3000),
#   'CALL. CAPITAN SALAZAR MARTINEZ, 2',
#   2,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (376,
#   '2021S001477',
#   datetime.date(2021, 3, 2),
#   datetime.timedelta(seconds=10200),
#   'PLAZA. ESPAÑA, 5',
#   5,
#   'CENTRO',
#   'Otro',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (431,
#   '2021S013826',
#   datetime.date(2021, 3, 8),
#   datetime.timedelta(seconds=7200),
#   'CALL. GRAN VIA, 37',
#   37,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'S',
#   'madrugada'),
#  (432,
#   '2021S013826',
#   datetime.date(2021, 3, 8),
#   datetime.timedelta(seconds=7200),
#   'CALL. GRAN VIA, 37',
#   37,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (453,
#   '2021S017627',
#   datetime.date(2021, 3, 10),
#   datetime.timedelta(seconds=6300),
#   'CALL. SILVA / CALL. LUNA',
#   1,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (454,
#   '2021S017627',
#   datetime.date(2021, 3, 10),
#   datetime.timedelta(seconds=6300),
#   'CALL. SILVA / CALL. LUNA',
#   1,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (455,
#   '2021S017627',
#   datetime.date(2021, 3, 10),
#   datetime.timedelta(seconds=6300),
#   'CALL. SILVA / CALL. LUNA',
#   1,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (456,
#   '2021S017693',
#   datetime.date(2021, 3, 10),
#   datetime.timedelta(seconds=1500),
#   'PLAZA. GABRIEL MIRO / CALL. BEATRIZ GALINDO',
#   1,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (457,
#   '2021S017693',
#   datetime.date(2021, 3, 10),
#   datetime.timedelta(seconds=1500),
#   'PLAZA. GABRIEL MIRO / CALL. BEATRIZ GALINDO',
#   1,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (537,
#   '2021S004342',
#   datetime.date(2021, 3, 20),
#   datetime.timedelta(seconds=5700),
#   'CALL. SEGOVIA / RONDA. SEGOVIA',
#   1,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (593,
#   '2021S000129',
#   datetime.date(2021, 4, 1),
#   datetime.timedelta(seconds=900),
#   'PLAZA. CIBELES / PASEO. RECOLETOS',
#   2,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (594,
#   '2021S000129',
#   datetime.date(2021, 4, 1),
#   datetime.timedelta(seconds=900),
#   'PLAZA. CIBELES / PASEO. RECOLETOS',
#   2,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (595,
#   '2021S000129',
#   datetime.date(2021, 4, 1),
#   datetime.timedelta(seconds=900),
#   'PLAZA. CIBELES / PASEO. RECOLETOS',
#   2,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (596,
#   '2021S000129',
#   datetime.date(2021, 4, 1),
#   datetime.timedelta(seconds=900),
#   'PLAZA. CIBELES / PASEO. RECOLETOS',
#   2,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (597,
#   '2021S000129',
#   datetime.date(2021, 4, 1),
#   datetime.timedelta(seconds=900),
#   'PLAZA. CIBELES / PASEO. RECOLETOS',
#   2,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (626,
#   '2021S013875',
#   datetime.date(2021, 4, 8),
#   datetime.timedelta(seconds=13440),
#   'CRA. SAN JERONIMO, 46',
#   46,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (627,
#   '2021S013875',
#   datetime.date(2021, 4, 8),
#   datetime.timedelta(seconds=13440),
#   'CRA. SAN JERONIMO, 46',
#   46,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (631,
#   '2021S013877',
#   datetime.date(2021, 4, 8),
#   datetime.timedelta(seconds=14400),
#   'CALL. CONCEPCION JERONIMA, 3',
#   3,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (652,
#   '2021S015634',
#   datetime.date(2021, 4, 9),
#   datetime.timedelta(seconds=4800),
#   'PLAZA. EMPERADOR CARLOS V, 1',
#   1,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (653,
#   '2021S015634',
#   datetime.date(2021, 4, 9),
#   datetime.timedelta(seconds=4800),
#   'PLAZA. EMPERADOR CARLOS V, 1',
#   1,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (682,
#   '2021S020532',
#   datetime.date(2021, 4, 11),
#   datetime.timedelta(seconds=19800),
#   'CALL. PRADO / CALL. ECHEGARAY',
#   6,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (683,
#   '2021S020532',
#   datetime.date(2021, 4, 11),
#   datetime.timedelta(seconds=19800),
#   'CALL. PRADO / CALL. ECHEGARAY',
#   6,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (684,
#   '2021S020540',
#   datetime.date(2021, 4, 11),
#   datetime.timedelta(seconds=17100),
#   'CALL. DON FELIPE / CALL. CORREDERA ALTA DE SAN PABLO',
#   2,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (685,
#   '2021S020540',
#   datetime.date(2021, 4, 11),
#   datetime.timedelta(seconds=17100),
#   'CALL. DON FELIPE / CALL. CORREDERA ALTA DE SAN PABLO',
#   2,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (723,
#   '2021S006219',
#   datetime.date(2021, 4, 16),
#   datetime.timedelta(seconds=2100),
#   'CALL. TUDESCOS, 4',
#   4,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Nublado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (724,
#   '2021S006219',
#   datetime.date(2021, 4, 16),
#   datetime.timedelta(seconds=2100),
#   'CALL. TUDESCOS, 4',
#   4,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Nublado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (746,
#   '2021S006757',
#   datetime.date(2021, 4, 24),
#   datetime.timedelta(seconds=2400),
#   'CALL. GRAN VIA / CALL. CLAVEL',
#   16,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (747,
#   '2021S006757',
#   datetime.date(2021, 4, 24),
#   datetime.timedelta(seconds=2400),
#   'CALL. GRAN VIA / CALL. CLAVEL',
#   16,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (758,
#   '2021S006862',
#   datetime.date(2021, 4, 25),
#   datetime.timedelta(seconds=3600),
#   'PLAZA. TIRSO DE MOLINA / CALL. DOCTOR CORTEZO',
#   5,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Lluvia débil',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (765,
#   '2021S007094',
#   datetime.date(2021, 4, 28),
#   datetime.timedelta(seconds=19800),
#   'CALL. MIGUEL SERVET, 6',
#   6,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (792,
#   '2021S009896',
#   datetime.date(2021, 5, 6),
#   datetime.timedelta(seconds=10200),
#   'CALL. MESONERO ROMANOS / CALL. GRAN VIA',
#   11,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (793,
#   '2021S009896',
#   datetime.date(2021, 5, 6),
#   datetime.timedelta(seconds=10200),
#   'CALL. MESONERO ROMANOS / CALL. GRAN VIA',
#   11,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (811,
#   '2021S012135',
#   datetime.date(2021, 5, 7),
#   datetime.timedelta(seconds=1200),
#   'CRA. SAN JERONIMO, 34',
#   34,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (812,
#   '2021S012135',
#   datetime.date(2021, 5, 7),
#   datetime.timedelta(seconds=1200),
#   'CRA. SAN JERONIMO, 34',
#   34,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (831,
#   '2021S015438',
#   datetime.date(2021, 5, 9),
#   datetime.timedelta(seconds=8400),
#   'RONDA. SEGOVIA / GTA. PUERTA DE TOLEDO',
#   95,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (832,
#   '2021S015438',
#   datetime.date(2021, 5, 9),
#   datetime.timedelta(seconds=8400),
#   'RONDA. SEGOVIA / GTA. PUERTA DE TOLEDO',
#   95,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (833,
#   '2021S015438',
#   datetime.date(2021, 5, 9),
#   datetime.timedelta(seconds=8400),
#   'RONDA. SEGOVIA / GTA. PUERTA DE TOLEDO',
#   95,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (866,
#   '2021S023171',
#   datetime.date(2021, 5, 12),
#   datetime.timedelta(seconds=18600),
#   'CALL. BALTASAR GRACIAN / CALL. ALBERTO AGUILERA',
#   1,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (871,
#   '2021S023167',
#   datetime.date(2021, 5, 12),
#   datetime.timedelta(seconds=12000),
#   'CALL. DOCTOR CORTEZO / PLAZA. JACINTO BENAVENTE',
#   1,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (872,
#   '2021S023167',
#   datetime.date(2021, 5, 12),
#   datetime.timedelta(seconds=12000),
#   'CALL. DOCTOR CORTEZO / PLAZA. JACINTO BENAVENTE',
#   1,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (913,
#   '2021S008672',
#   datetime.date(2021, 5, 20),
#   datetime.timedelta(seconds=2400),
#   'CALL. LIMON, 6',
#   6,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (914,
#   '2021S008672',
#   datetime.date(2021, 5, 20),
#   datetime.timedelta(seconds=2400),
#   'CALL. LIMON, 6',
#   6,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (915,
#   '2021S008672',
#   datetime.date(2021, 5, 20),
#   datetime.timedelta(seconds=2400),
#   'CALL. LIMON, 6',
#   6,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (924,
#   '2021S008751',
#   datetime.date(2021, 5, 21),
#   datetime.timedelta(seconds=19200),
#   'CALL. ATOCHA, 81',
#   81,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (925,
#   '2021S008751',
#   datetime.date(2021, 5, 21),
#   datetime.timedelta(seconds=19200),
#   'CALL. ATOCHA, 81',
#   81,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (930,
#   '2021S008846',
#   datetime.date(2021, 5, 22),
#   datetime.timedelta(seconds=3900),
#   'CALL. MEJIA LEQUERICA / CALL. SAGASTA',
#   16,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (931,
#   '2021S008846',
#   datetime.date(2021, 5, 22),
#   datetime.timedelta(seconds=3900),
#   'CALL. MEJIA LEQUERICA / CALL. SAGASTA',
#   16,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (932,
#   '2021S008846',
#   datetime.date(2021, 5, 22),
#   datetime.timedelta(seconds=3900),
#   'CALL. MEJIA LEQUERICA / CALL. SAGASTA',
#   16,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (963,
#   '2021S008925',
#   datetime.date(2021, 5, 23),
#   datetime.timedelta(seconds=2400),
#   'PASEO. RECOLETOS, 11',
#   11,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (964,
#   '2021S008925',
#   datetime.date(2021, 5, 23),
#   datetime.timedelta(seconds=2400),
#   'PASEO. RECOLETOS, 11',
#   11,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (965,
#   '2021S008925',
#   datetime.date(2021, 5, 23),
#   datetime.timedelta(seconds=2400),
#   'PASEO. RECOLETOS, 11',
#   11,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (966,
#   '2021S008925',
#   datetime.date(2021, 5, 23),
#   datetime.timedelta(seconds=2400),
#   'PASEO. RECOLETOS, 11',
#   11,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (967,
#   '2021S008925',
#   datetime.date(2021, 5, 23),
#   datetime.timedelta(seconds=2400),
#   'PASEO. RECOLETOS, 11',
#   11,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1005,
#   '2021S008929',
#   datetime.date(2021, 5, 23),
#   datetime.timedelta(seconds=7200),
#   'CALL. SAGASTA, 20',
#   20,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1009,
#   '2021S009051',
#   datetime.date(2021, 5, 25),
#   datetime.timedelta(seconds=17100),
#   'CALL. MESON DE PAREDES / CALL. MIGUEL SERVET',
#   30,
#   'CENTRO',
#   'Colisión múltiple',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1010,
#   '2021S009051',
#   datetime.date(2021, 5, 25),
#   datetime.timedelta(seconds=17100),
#   'CALL. MESON DE PAREDES / CALL. MIGUEL SERVET',
#   30,
#   'CENTRO',
#   'Colisión múltiple',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1011,
#   '2021S009051',
#   datetime.date(2021, 5, 25),
#   datetime.timedelta(seconds=17100),
#   'CALL. MESON DE PAREDES / CALL. MIGUEL SERVET',
#   30,
#   'CENTRO',
#   'Colisión múltiple',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1019,
#   '2021S009171',
#   datetime.date(2021, 5, 27),
#   datetime.timedelta(0),
#   'CALL. GENOVA, 24',
#   24,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1020,
#   '2021S009169',
#   datetime.date(2021, 5, 27),
#   datetime.timedelta(seconds=4500),
#   'CALL. AVE MARIA, 20',
#   20,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1046,
#   '2021S009321',
#   datetime.date(2021, 5, 29),
#   datetime.timedelta(seconds=2700),
#   'CALL. ATOCHA, 16',
#   16,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (1047,
#   '2021S009321',
#   datetime.date(2021, 5, 29),
#   datetime.timedelta(seconds=2700),
#   'CALL. ATOCHA, 16',
#   16,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1099,
#   '2021S009478',
#   datetime.date(2021, 5, 31),
#   datetime.timedelta(seconds=7200),
#   'PASEO. PRADO, 30',
#   30,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1100,
#   '2021S009478',
#   datetime.date(2021, 5, 31),
#   datetime.timedelta(seconds=7200),
#   'PASEO. PRADO, 30',
#   30,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1101,
#   '2021S009478',
#   datetime.date(2021, 5, 31),
#   datetime.timedelta(seconds=7200),
#   'PASEO. PRADO, 30',
#   30,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (1119,
#   '2021S003383',
#   datetime.date(2021, 6, 3),
#   datetime.timedelta(seconds=4320),
#   'CALL. TOLEDO, 50',
#   50,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Lluvia débil',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1120,
#   '2021S003383',
#   datetime.date(2021, 6, 3),
#   datetime.timedelta(seconds=4320),
#   'CALL. TOLEDO, 50',
#   50,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Lluvia débil',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1142,
#   '2021S009960',
#   datetime.date(2021, 6, 6),
#   datetime.timedelta(seconds=8400),
#   'CALL. SAGASTA, 4',
#   4,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (1162,
#   '2021S017881',
#   datetime.date(2021, 6, 10),
#   datetime.timedelta(seconds=13800),
#   'CRA. SAN JERONIMO, 3',
#   3,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1163,
#   '2021S017881',
#   datetime.date(2021, 6, 10),
#   datetime.timedelta(seconds=13800),
#   'CRA. SAN JERONIMO, 3',
#   3,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1187,
#   '2021S020691',
#   datetime.date(2021, 6, 11),
#   datetime.timedelta(seconds=19800),
#   'TRVA. BRINGAS, 1',
#   1,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1233,
#   '2021S010530',
#   datetime.date(2021, 6, 13),
#   datetime.timedelta(seconds=1020),
#   'CALL. GRAN VIA / CALL. SILVA',
#   59,
#   'CENTRO',
#   'Colisión múltiple',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1234,
#   '2021S010530',
#   datetime.date(2021, 6, 13),
#   datetime.timedelta(seconds=1020),
#   'CALL. GRAN VIA / CALL. SILVA',
#   59,
#   'CENTRO',
#   'Colisión múltiple',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1235,
#   '2021S010530',
#   datetime.date(2021, 6, 13),
#   datetime.timedelta(seconds=1020),
#   'CALL. GRAN VIA / CALL. SILVA',
#   59,
#   'CENTRO',
#   'Colisión múltiple',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1236,
#   '2021S010530',
#   datetime.date(2021, 6, 13),
#   datetime.timedelta(seconds=1020),
#   'CALL. GRAN VIA / CALL. SILVA',
#   59,
#   'CENTRO',
#   'Colisión múltiple',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1237,
#   '2021S010530',
#   datetime.date(2021, 6, 13),
#   datetime.timedelta(seconds=1020),
#   'CALL. GRAN VIA / CALL. SILVA',
#   59,
#   'CENTRO',
#   'Colisión múltiple',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1303,
#   '2021S011080',
#   datetime.date(2021, 6, 20),
#   datetime.timedelta(seconds=18000),
#   'CALL. MONTERA, 26',
#   26,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1304,
#   '2021S011082',
#   datetime.date(2021, 6, 20),
#   datetime.timedelta(seconds=6300),
#   'CALL. MIGUEL SERVET, 15',
#   15,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1317,
#   '2021S011045',
#   datetime.date(2021, 6, 20),
#   datetime.timedelta(seconds=2100),
#   'CALL. GRAN VIA, 9',
#   9,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1318,
#   '2021S011045',
#   datetime.date(2021, 6, 20),
#   datetime.timedelta(seconds=2100),
#   'CALL. GRAN VIA, 9',
#   9,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1324,
#   '2021S011118',
#   datetime.date(2021, 6, 21),
#   datetime.timedelta(seconds=8400),
#   'CALL. MAYOR, 83',
#   83,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1393,
#   '2021S011494',
#   datetime.date(2021, 6, 26),
#   datetime.timedelta(seconds=6000),
#   'CALL. ALCALA, 48',
#   48,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1448,
#   '2021S011660',
#   datetime.date(2021, 6, 28),
#   datetime.timedelta(seconds=8400),
#   'CALL. GRAN VIA, 49',
#   49,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1454,
#   '2021S011943',
#   datetime.date(2021, 6, 30),
#   datetime.timedelta(seconds=15900),
#   'CALL. GRAN VIA, 68',
#   68,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1455,
#   '2021S011943',
#   datetime.date(2021, 6, 30),
#   datetime.timedelta(seconds=15900),
#   'CALL. GRAN VIA, 68',
#   68,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1499,
#   '2021S014048',
#   datetime.date(2021, 7, 8),
#   datetime.timedelta(seconds=5400),
#   'CALL. TOLEDO / CALL. TINTOREROS',
#   3,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1500,
#   '2021S014048',
#   datetime.date(2021, 7, 8),
#   datetime.timedelta(seconds=5400),
#   'CALL. TOLEDO / CALL. TINTOREROS',
#   3,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1501,
#   '2021S014048',
#   datetime.date(2021, 7, 8),
#   datetime.timedelta(seconds=5400),
#   'CALL. TOLEDO / CALL. TINTOREROS',
#   3,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1504,
#   '2021S014091',
#   datetime.date(2021, 7, 8),
#   datetime.timedelta(seconds=19800),
#   'CALL. PRINCESA, 22',
#   22,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1505,
#   '2021S014097',
#   datetime.date(2021, 7, 8),
#   datetime.timedelta(seconds=3780),
#   'PASEO. RECOLETOS, 41',
#   41,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1506,
#   '2021S014097',
#   datetime.date(2021, 7, 8),
#   datetime.timedelta(seconds=3780),
#   'PASEO. RECOLETOS, 41',
#   41,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1531,
#   '2021S020764',
#   datetime.date(2021, 7, 11),
#   datetime.timedelta(seconds=15300),
#   'PASEO. PRADO / CALL. ATOCHA',
#   48,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1532,
#   '2021S020764',
#   datetime.date(2021, 7, 11),
#   datetime.timedelta(seconds=15300),
#   'PASEO. PRADO / CALL. ATOCHA',
#   48,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1533,
#   '2021S020764',
#   datetime.date(2021, 7, 11),
#   datetime.timedelta(seconds=15300),
#   'PASEO. PRADO / CALL. ATOCHA',
#   48,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1534,
#   '2021S020764',
#   datetime.date(2021, 7, 11),
#   datetime.timedelta(seconds=15300),
#   'PASEO. PRADO / CALL. ATOCHA',
#   48,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (1535,
#   '2021S020764',
#   datetime.date(2021, 7, 11),
#   datetime.timedelta(seconds=15300),
#   'PASEO. PRADO / CALL. ATOCHA',
#   48,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1538,
#   '2021S020750',
#   datetime.date(2021, 7, 11),
#   datetime.timedelta(seconds=900),
#   'CALL. GRAN VIA / CALL. SAN BERNARDO',
#   53,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1539,
#   '2021S020750',
#   datetime.date(2021, 7, 11),
#   datetime.timedelta(seconds=900),
#   'CALL. GRAN VIA / CALL. SAN BERNARDO',
#   53,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1540,
#   '2021S020752',
#   datetime.date(2021, 7, 11),
#   datetime.timedelta(seconds=6000),
#   'PASEO. PRADO / CALL. LOS MADRAZO',
#   2,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1541,
#   '2021S020752',
#   datetime.date(2021, 7, 11),
#   datetime.timedelta(seconds=6000),
#   'PASEO. PRADO / CALL. LOS MADRAZO',
#   2,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1614,
#   '2021S012942',
#   datetime.date(2021, 7, 18),
#   datetime.timedelta(seconds=3000),
#   'PASEO. RECOLETOS / CALL. PRIM',
#   19,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1615,
#   '2021S012942',
#   datetime.date(2021, 7, 18),
#   datetime.timedelta(seconds=3000),
#   'PASEO. RECOLETOS / CALL. PRIM',
#   19,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1616,
#   '2021S012942',
#   datetime.date(2021, 7, 18),
#   datetime.timedelta(seconds=3000),
#   'PASEO. RECOLETOS / CALL. PRIM',
#   19,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1617,
#   '2021S012942',
#   datetime.date(2021, 7, 18),
#   datetime.timedelta(seconds=3000),
#   'PASEO. RECOLETOS / CALL. PRIM',
#   19,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1618,
#   '2021S012942',
#   datetime.date(2021, 7, 18),
#   datetime.timedelta(seconds=3000),
#   'PASEO. RECOLETOS / CALL. PRIM',
#   19,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1619,
#   '2021S012942',
#   datetime.date(2021, 7, 18),
#   datetime.timedelta(seconds=3000),
#   'PASEO. RECOLETOS / CALL. PRIM',
#   19,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1620,
#   '2021S012942',
#   datetime.date(2021, 7, 18),
#   datetime.timedelta(seconds=3000),
#   'PASEO. RECOLETOS / CALL. PRIM',
#   19,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1621,
#   '2021S012942',
#   datetime.date(2021, 7, 18),
#   datetime.timedelta(seconds=3000),
#   'PASEO. RECOLETOS / CALL. PRIM',
#   19,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1622,
#   '2021S012942',
#   datetime.date(2021, 7, 18),
#   datetime.timedelta(seconds=3000),
#   'PASEO. RECOLETOS / CALL. PRIM',
#   19,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1643,
#   '2021S013159',
#   datetime.date(2021, 7, 22),
#   datetime.timedelta(seconds=7200),
#   'CALL. GRAN VIA / CALL. CONCEPCION ARENAL',
#   40,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1644,
#   '2021S013159',
#   datetime.date(2021, 7, 22),
#   datetime.timedelta(seconds=7200),
#   'CALL. GRAN VIA / CALL. CONCEPCION ARENAL',
#   40,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (1645,
#   '2021S013159',
#   datetime.date(2021, 7, 22),
#   datetime.timedelta(seconds=7200),
#   'CALL. GRAN VIA / CALL. CONCEPCION ARENAL',
#   40,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1686,
#   '2021S013599',
#   datetime.date(2021, 7, 24),
#   datetime.timedelta(seconds=3480),
#   'CALL. BAILEN, 35',
#   35,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1687,
#   '2021S013368',
#   datetime.date(2021, 7, 25),
#   datetime.timedelta(seconds=6300),
#   'CALL. SANTA CATALINA / PLAZA. LEGAZPI',
#   5,
#   'CENTRO',
#   'Caída',
#   'Se desconoce',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (1694,
#   '2021S013604',
#   datetime.date(2021, 7, 25),
#   datetime.timedelta(seconds=420),
#   'PASEO. PRADO / ZORRILLA',
#   8,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1712,
#   '2021S013327',
#   datetime.date(2021, 7, 26),
#   datetime.timedelta(seconds=1200),
#   'CALL. ALCALA / CALL. BUEN GOBERNADOR',
#   1,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1713,
#   '2021S013327',
#   datetime.date(2021, 7, 26),
#   datetime.timedelta(seconds=1200),
#   'CALL. ALCALA / CALL. BUEN GOBERNADOR',
#   1,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1750,
#   '2021S013605',
#   datetime.date(2021, 7, 30),
#   datetime.timedelta(seconds=17400),
#   'CALL. REINA / CALL. CLAVEL',
#   41,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1751,
#   '2021S013605',
#   datetime.date(2021, 7, 30),
#   datetime.timedelta(seconds=17400),
#   'CALL. REINA / CALL. CLAVEL',
#   41,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1762,
#   '2021S013873',
#   datetime.date(2021, 7, 31),
#   datetime.timedelta(seconds=2700),
#   'CALL. MAYOR, 25',
#   25,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1763,
#   '2021S013873',
#   datetime.date(2021, 7, 31),
#   datetime.timedelta(seconds=2700),
#   'CALL. MAYOR, 25',
#   25,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1772,
#   '2021S013670',
#   datetime.date(2021, 7, 31),
#   datetime.timedelta(seconds=11700),
#   'CALL. CRUZ / PLAZA. CANALEJAS',
#   1,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1773,
#   '2021S013670',
#   datetime.date(2021, 7, 31),
#   datetime.timedelta(seconds=11700),
#   'CALL. CRUZ / PLAZA. CANALEJAS',
#   1,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (1774,
#   '2021S013670',
#   datetime.date(2021, 7, 31),
#   datetime.timedelta(seconds=11700),
#   'CALL. CRUZ / PLAZA. CANALEJAS',
#   1,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1781,
#   '2021S005681',
#   datetime.date(2021, 8, 4),
#   datetime.timedelta(seconds=1500),
#   'PASEO. CIUDAD DE PLASENCIA / PASEO. VIRGEN DEL PUERTO',
#   0,
#   'CENTRO',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (1787,
#   '2021S007806',
#   datetime.date(2021, 8, 5),
#   datetime.timedelta(seconds=10200),
#   'CALL. PRINCESA / CALL. MARQUES DE URQUIJO',
#   32,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1788,
#   '2021S007806',
#   datetime.date(2021, 8, 5),
#   datetime.timedelta(seconds=10200),
#   'CALL. PRINCESA / CALL. MARQUES DE URQUIJO',
#   32,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (1792,
#   '2021S014141',
#   datetime.date(2021, 8, 7),
#   datetime.timedelta(seconds=12600),
#   'CALL. AMPARO / CALL. MIGUEL SERVET',
#   1,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1793,
#   '2021S014141',
#   datetime.date(2021, 8, 7),
#   datetime.timedelta(seconds=12600),
#   'CALL. AMPARO / CALL. MIGUEL SERVET',
#   1,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1802,
#   '2021S014100',
#   datetime.date(2021, 8, 8),
#   datetime.timedelta(seconds=11940),
#   'CALL. CHURRUCA, 3',
#   3,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1803,
#   '2021S014100',
#   datetime.date(2021, 8, 8),
#   datetime.timedelta(seconds=11940),
#   'CALL. CHURRUCA, 3',
#   3,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1806,
#   '2021S014123',
#   datetime.date(2021, 8, 8),
#   datetime.timedelta(seconds=5400),
#   'CALL. ALCALA / CALL. GRAN VIA',
#   45,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1838,
#   '2021S023377',
#   datetime.date(2021, 8, 12),
#   datetime.timedelta(seconds=21000),
#   'PASEO. PRADO, 46',
#   46,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1839,
#   '2021S023377',
#   datetime.date(2021, 8, 12),
#   datetime.timedelta(seconds=21000),
#   'PASEO. PRADO, 46',
#   46,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1858,
#   '2021S014392',
#   datetime.date(2021, 8, 14),
#   datetime.timedelta(seconds=13200),
#   'PLAZA. EMPERADOR CARLOS V / CALL. SANTA ISABEL',
#   8,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1859,
#   '2021S014392',
#   datetime.date(2021, 8, 14),
#   datetime.timedelta(seconds=13200),
#   'PLAZA. EMPERADOR CARLOS V / CALL. SANTA ISABEL',
#   8,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1866,
#   '2021S014383',
#   datetime.date(2021, 8, 14),
#   datetime.timedelta(seconds=6000),
#   'PASEO. PRADO, 12',
#   12,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'Se desconoce',
#   'Se desconoce',
#   'madrugada'),
#  (1867,
#   '2021S014383',
#   datetime.date(2021, 8, 14),
#   datetime.timedelta(seconds=6000),
#   'PASEO. PRADO, 12',
#   12,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1868,
#   '2021S014383',
#   datetime.date(2021, 8, 14),
#   datetime.timedelta(seconds=6000),
#   'PASEO. PRADO, 12',
#   12,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1869,
#   '2021S014382',
#   datetime.date(2021, 8, 14),
#   datetime.timedelta(seconds=4500),
#   'CALL. ALCALA / CALL. GRAN VIA',
#   44,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1870,
#   '2021S014382',
#   datetime.date(2021, 8, 14),
#   datetime.timedelta(seconds=4500),
#   'CALL. ALCALA / CALL. GRAN VIA',
#   44,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1959,
#   '2021S014866',
#   datetime.date(2021, 8, 26),
#   datetime.timedelta(seconds=5460),
#   'CALL. ALCALA, 30',
#   30,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1964,
#   '2021S014918',
#   datetime.date(2021, 8, 27),
#   datetime.timedelta(seconds=12300),
#   'CALL. ESPIRITU SANTO, 6',
#   6,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1975,
#   '2021S014965',
#   datetime.date(2021, 8, 28),
#   datetime.timedelta(seconds=13800),
#   'PASEO. PRADO / PLAZA. CIBELES',
#   2,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1976,
#   '2021S014965',
#   datetime.date(2021, 8, 28),
#   datetime.timedelta(seconds=13800),
#   'PASEO. PRADO / PLAZA. CIBELES',
#   2,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1977,
#   '2021S014965',
#   datetime.date(2021, 8, 28),
#   datetime.timedelta(seconds=13800),
#   'PASEO. PRADO / PLAZA. CIBELES',
#   2,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (1978,
#   '2021S014965',
#   datetime.date(2021, 8, 28),
#   datetime.timedelta(seconds=13800),
#   'PASEO. PRADO / PLAZA. CIBELES',
#   2,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (2006,
#   '2021S015017',
#   datetime.date(2021, 8, 29),
#   datetime.timedelta(seconds=6000),
#   'PLAZA. ANGEL, 10',
#   10,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2010,
#   '2021S015015',
#   datetime.date(2021, 8, 29),
#   datetime.timedelta(seconds=8400),
#   'CALL. PRINCESA, 2',
#   2,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2011,
#   '2021S015015',
#   datetime.date(2021, 8, 29),
#   datetime.timedelta(seconds=8400),
#   'CALL. PRINCESA, 2',
#   2,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2012,
#   '2021S015014',
#   datetime.date(2021, 8, 29),
#   datetime.timedelta(0),
#   'JDINS. PLAZA DE ORIENTE, 0',
#   0,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2017,
#   '2021S015049',
#   datetime.date(2021, 8, 30),
#   datetime.timedelta(seconds=13800),
#   'CALL. FUENCARRAL / CALL. PALMA',
#   75,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2037,
#   '2021S003513',
#   datetime.date(2021, 9, 3),
#   datetime.timedelta(seconds=900),
#   'CALL. GRAN VIA, 72',
#   72,
#   'CENTRO',
#   'Alcance',
#   'Lluvia débil',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2038,
#   '2021S003513',
#   datetime.date(2021, 9, 3),
#   datetime.timedelta(seconds=900),
#   'CALL. GRAN VIA, 72',
#   72,
#   'CENTRO',
#   'Alcance',
#   'Lluvia débil',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2041,
#   '2021S007881',
#   datetime.date(2021, 9, 5),
#   datetime.timedelta(seconds=1200),
#   'PLAZA. SANTA MARIA SOLEDAD TORRES ACOSTA, 2',
#   2,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (2051,
#   '2021S007897',
#   datetime.date(2021, 9, 5),
#   datetime.timedelta(seconds=7200),
#   'CALLE SILVA 1',
#   1,
#   'CENTRO',
#   'Caída',
#   'Lluvia débil',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2056,
#   '2021S012406',
#   datetime.date(2021, 9, 7),
#   datetime.timedelta(seconds=13500),
#   'CALL. DIVINO PASTOR / CALL. FUENCARRAL',
#   3,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (2093,
#   '2021S018180',
#   datetime.date(2021, 9, 10),
#   datetime.timedelta(seconds=18600),
#   'CALL. CLAVEL / CALL. REINA',
#   5,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2094,
#   '2021S018180',
#   datetime.date(2021, 9, 10),
#   datetime.timedelta(seconds=18600),
#   'CALL. CLAVEL / CALL. REINA',
#   5,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'Se desconoce',
#   'Se desconoce',
#   'madrugada'),
#  (2117,
#   '2021S020912',
#   datetime.date(2021, 9, 11),
#   datetime.timedelta(seconds=8700),
#   'PLAZA. EMPERADOR CARLOS V, 8',
#   8,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2118,
#   '2021S020912',
#   datetime.date(2021, 9, 11),
#   datetime.timedelta(seconds=8700),
#   'PLAZA. EMPERADOR CARLOS V, 8',
#   8,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2119,
#   '2021S020908',
#   datetime.date(2021, 9, 11),
#   datetime.timedelta(seconds=3900),
#   'CALL. MARQUES DE CUBAS / CALL. ALCALA',
#   1,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2120,
#   '2021S023437',
#   datetime.date(2021, 9, 12),
#   datetime.timedelta(seconds=16200),
#   'CALL. SAN BERNARDO / CALLE SILVA',
#   1,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2121,
#   '2021S023437',
#   datetime.date(2021, 9, 12),
#   datetime.timedelta(seconds=16200),
#   'CALL. SAN BERNARDO / CALLE SILVA',
#   1,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2132,
#   '2021S016021',
#   datetime.date(2021, 9, 13),
#   datetime.timedelta(seconds=600),
#   'PLAZA. PUERTA CERRADA, 7',
#   7,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (2138,
#   '2021S016024',
#   datetime.date(2021, 9, 13),
#   datetime.timedelta(seconds=16800),
#   'PASEO. RECOLETOS / CALL. VILLANUEVA',
#   17,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2141,
#   '2021S016094',
#   datetime.date(2021, 9, 14),
#   datetime.timedelta(seconds=7200),
#   'CALL. SAGASTA / CALL. LARRA',
#   8,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (2142,
#   '2021S016094',
#   datetime.date(2021, 9, 14),
#   datetime.timedelta(seconds=7200),
#   'CALL. SAGASTA / CALL. LARRA',
#   8,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2143,
#   '2021S016094',
#   datetime.date(2021, 9, 14),
#   datetime.timedelta(seconds=7200),
#   'CALL. SAGASTA / CALL. LARRA',
#   8,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2161,
#   '2021S016420',
#   datetime.date(2021, 9, 18),
#   datetime.timedelta(seconds=20700),
#   'PASEO. RECOLETOS, 27',
#   27,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2162,
#   '2021S016420',
#   datetime.date(2021, 9, 18),
#   datetime.timedelta(seconds=20700),
#   'PASEO. RECOLETOS, 27',
#   27,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2168,
#   '2021S016498',
#   datetime.date(2021, 9, 19),
#   datetime.timedelta(seconds=13200),
#   'CALL. GRAN VIA, 5',
#   5,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2169,
#   '2021S016498',
#   datetime.date(2021, 9, 19),
#   datetime.timedelta(seconds=13200),
#   'CALL. GRAN VIA, 5',
#   5,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2170,
#   '2021S016498',
#   datetime.date(2021, 9, 19),
#   datetime.timedelta(seconds=13200),
#   'CALL. GRAN VIA, 5',
#   5,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2171,
#   '2021S016498',
#   datetime.date(2021, 9, 19),
#   datetime.timedelta(seconds=13200),
#   'CALL. GRAN VIA, 5',
#   5,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2172,
#   '2021S016498',
#   datetime.date(2021, 9, 19),
#   datetime.timedelta(seconds=13200),
#   'CALL. GRAN VIA, 5',
#   5,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2285,
#   '2021S017072',
#   datetime.date(2021, 9, 26),
#   datetime.timedelta(seconds=4800),
#   'PLAZA. DOS DE MAYO, 2',
#   2,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2286,
#   '2021S017072',
#   datetime.date(2021, 9, 26),
#   datetime.timedelta(seconds=4800),
#   'PLAZA. DOS DE MAYO, 2',
#   2,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2350,
#   '2021S012475',
#   datetime.date(2021, 10, 7),
#   datetime.timedelta(seconds=12600),
#   'PASEO. RECOLETOS / CALL. ABARDERO',
#   25,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (2387,
#   '2021S012464',
#   datetime.date(2021, 10, 7),
#   datetime.timedelta(seconds=4200),
#   'CALL. MALLORCA / RONDA. ATOCHA',
#   1,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2388,
#   '2021S012464',
#   datetime.date(2021, 10, 7),
#   datetime.timedelta(seconds=4200),
#   'CALL. MALLORCA / RONDA. ATOCHA',
#   1,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (2398,
#   '2021S015796',
# ...
#   'CALL. CEDACEROS / CALL. ARLABAN',
#   9,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   '440744.079',
#   '4474289.798',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9561,
#   '2023S024655',
#   datetime.date(2023, 6, 7),
#   datetime.timedelta(seconds=18000),
#   'CALL. BAILEN / CSTAN. SAN VICENTE',
#   3,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   '439530.382',
#   '4474832.015',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9564,
#   '2023S026913',
#   datetime.date(2023, 6, 8),
#   datetime.timedelta(seconds=11400),
#   'CALL. ATOCHA / PLAZA. EMPERADOR CARLOS V',
#   122,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   '441214.678',
#   '4473421.17',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9565,
#   '2023S026913',
#   datetime.date(2023, 6, 8),
#   datetime.timedelta(seconds=11400),
#   'CALL. ATOCHA / PLAZA. EMPERADOR CARLOS V',
#   122,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   '441214.678',
#   '4473421.17',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9566,
#   '2023S026913',
#   datetime.date(2023, 6, 8),
#   datetime.timedelta(seconds=11400),
#   'CALL. ATOCHA / PLAZA. EMPERADOR CARLOS V',
#   122,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   '441214.678',
#   '4473421.17',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9570,
#   '2023S022867',
#   datetime.date(2023, 6, 13),
#   datetime.timedelta(seconds=3600),
#   'CALL. MIGUEL SERVET, 21',
#   21,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   '440431.721',
#   '4473042.371',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9571,
#   '2023S022867',
#   datetime.date(2023, 6, 13),
#   datetime.timedelta(seconds=3600),
#   'CALL. MIGUEL SERVET, 21',
#   21,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   '440431.721',
#   '4473042.371',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9603,
#   '2023S023045',
#   datetime.date(2023, 6, 16),
#   datetime.timedelta(seconds=1200),
#   'CALLE ARGUMOSA 27',
#   27,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   '440792.376',
#   '4473275.607',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9612,
#   '2023S023159',
#   datetime.date(2023, 6, 17),
#   datetime.timedelta(seconds=10800),
#   'CALL. CLAVEL / CALL. REINA',
#   5,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '440657.797',
#   '4474625.59',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9613,
#   '2023S023159',
#   datetime.date(2023, 6, 17),
#   datetime.timedelta(seconds=10800),
#   'CALL. CLAVEL / CALL. REINA',
#   5,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '440657.797',
#   '4474625.59',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9614,
#   '2023S023157',
#   datetime.date(2023, 6, 17),
#   datetime.timedelta(seconds=12600),
#   'CALL. ATOCHA, 81',
#   81,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   '440783.844',
#   '4473696.296',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9615,
#   '2023S023157',
#   datetime.date(2023, 6, 17),
#   datetime.timedelta(seconds=12600),
#   'CALL. ATOCHA, 81',
#   81,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   '440783.844',
#   '4473696.296',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9616,
#   '2023S023154',
#   datetime.date(2023, 6, 17),
#   datetime.timedelta(seconds=12000),
#   'TRVA. BRINGAS, 1',
#   1,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   '439865.425',
#   '4474136.935',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9617,
#   '2023S023154',
#   datetime.date(2023, 6, 17),
#   datetime.timedelta(seconds=12000),
#   'TRVA. BRINGAS, 1',
#   1,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   '439865.425',
#   '4474136.935',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9678,
#   '2023S023319',
#   datetime.date(2023, 6, 19),
#   datetime.timedelta(seconds=18000),
#   'CALL. TRIBULETE / CALL. AMPARO',
#   1,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Lluvia débil',
#   '440455.025',
#   '4473291.807',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9679,
#   '2023S023319',
#   datetime.date(2023, 6, 19),
#   datetime.timedelta(seconds=18000),
#   'CALL. TRIBULETE / CALL. AMPARO',
#   1,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Lluvia débil',
#   '440455.025',
#   '4473291.807',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9680,
#   '2023S023319',
#   datetime.date(2023, 6, 19),
#   datetime.timedelta(seconds=18000),
#   'CALL. TRIBULETE / CALL. AMPARO',
#   1,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Lluvia débil',
#   '440455.025',
#   '4473291.807',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9683,
#   '2023S023310',
#   datetime.date(2023, 6, 19),
#   datetime.timedelta(seconds=900),
#   'CALL. VENTURA DE LA VEGA / CALL. MANUEL FERNANDEZ Y GONZALEZ',
#   17,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   '440700.385',
#   '4474069.06',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9684,
#   '2023S023310',
#   datetime.date(2023, 6, 19),
#   datetime.timedelta(seconds=900),
#   'CALL. VENTURA DE LA VEGA / CALL. MANUEL FERNANDEZ Y GONZALEZ',
#   17,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   '440700.385',
#   '4474069.06',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9788,
#   '2023S024049',
#   datetime.date(2023, 6, 29),
#   datetime.timedelta(seconds=6600),
#   'PLAZA. SANTO DOMINGO / CALL. VENERAS',
#   1,
#   'CENTRO',
#   'Colisión frontal',
#   'Despejado',
#   '439942.474',
#   '4474601.28',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9789,
#   '2023S024049',
#   datetime.date(2023, 6, 29),
#   datetime.timedelta(seconds=6600),
#   'PLAZA. SANTO DOMINGO / CALL. VENERAS',
#   1,
#   'CENTRO',
#   'Colisión frontal',
#   'Despejado',
#   '439942.474',
#   '4474601.28',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9876,
#   '2023S018841',
#   datetime.date(2023, 7, 5),
#   datetime.timedelta(seconds=21000),
#   'CALL. TOLEDO, 63',
#   63,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   '439880.67',
#   '4473619.659',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9877,
#   '2023S018841',
#   datetime.date(2023, 7, 5),
#   datetime.timedelta(seconds=21000),
#   'CALL. TOLEDO, 63',
#   63,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   '439880.67',
#   '4473619.659',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9892,
#   '2023S026976',
#   datetime.date(2023, 7, 8),
#   datetime.timedelta(seconds=12600),
#   'CALL. SAN MARCOS / CALL. LIBERTAD',
#   17,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '440727.587',
#   '4474773.409',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9893,
#   '2023S026976',
#   datetime.date(2023, 7, 8),
#   datetime.timedelta(seconds=12600),
#   'CALL. SAN MARCOS / CALL. LIBERTAD',
#   17,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '440727.587',
#   '4474773.409',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9906,
#   '2023S025301',
#   datetime.date(2023, 7, 13),
#   datetime.timedelta(seconds=20700),
#   'CALL. ATOCHA, 82',
#   82,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   '440864.574',
#   '4473632.914',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9907,
#   '2023S025301',
#   datetime.date(2023, 7, 13),
#   datetime.timedelta(seconds=20700),
#   'CALL. ATOCHA, 82',
#   82,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   '440864.574',
#   '4473632.914',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9914,
#   '2023S025202',
#   datetime.date(2023, 7, 13),
#   datetime.timedelta(seconds=3300),
#   'PASEO. RECOLETOS, 5',
#   5,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   '441248.327',
#   '4474651.277',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9915,
#   '2023S025202',
#   datetime.date(2023, 7, 13),
#   datetime.timedelta(seconds=3300),
#   'PASEO. RECOLETOS, 5',
#   5,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   '441248.327',
#   '4474651.277',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9916,
#   '2023S025202',
#   datetime.date(2023, 7, 13),
#   datetime.timedelta(seconds=3300),
#   'PASEO. RECOLETOS, 5',
#   5,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   '441248.327',
#   '4474651.277',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9921,
#   '2023S025308',
#   datetime.date(2023, 7, 14),
#   datetime.timedelta(seconds=10800),
#   'CALL. LEGANITOS, 19',
#   19,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   '439756.019',
#   '4474803.767',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9922,
#   '2023S025308',
#   datetime.date(2023, 7, 14),
#   datetime.timedelta(seconds=10800),
#   'CALL. LEGANITOS, 19',
#   19,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   '439756.019',
#   '4474803.767',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9930,
#   '2023S025304',
#   datetime.date(2023, 7, 14),
#   datetime.timedelta(seconds=8100),
#   'PLAZA. EMPERADOR CARLOS V / PASEO. SANTA MARIA DE LA CABEZA',
#   1,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   '441150.987',
#   '4473207.44',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9931,
#   '2023S025304',
#   datetime.date(2023, 7, 14),
#   datetime.timedelta(seconds=8100),
#   'PLAZA. EMPERADOR CARLOS V / PASEO. SANTA MARIA DE LA CABEZA',
#   1,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   '441150.987',
#   '4473207.44',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9932,
#   '2023S025304',
#   datetime.date(2023, 7, 14),
#   datetime.timedelta(seconds=8100),
#   'PLAZA. EMPERADOR CARLOS V / PASEO. SANTA MARIA DE LA CABEZA',
#   1,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   '441150.987',
#   '4473207.44',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9933,
#   '2023S025302',
#   datetime.date(2023, 7, 14),
#   datetime.timedelta(seconds=2400),
#   'PASEO. RECOLETOS / CALL. VILLANUEVA',
#   19,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   '441378.103',
#   '4474948.76',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9934,
#   '2023S025302',
#   datetime.date(2023, 7, 14),
#   datetime.timedelta(seconds=2400),
#   'PASEO. RECOLETOS / CALL. VILLANUEVA',
#   19,
#   'CENTRO',
#   'Colisión lateral',
#   'Despejado',
#   '441378.103',
#   '4474948.76',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (9954,
#   '2023S025419',
#   datetime.date(2023, 7, 15),
#   datetime.timedelta(seconds=19800),
#   'TUNEL BAILEN FAROLA 99',
#   29,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   '439500.781',
#   '4474425.783',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (10050,
#   '2023S026028',
#   datetime.date(2023, 7, 23),
#   datetime.timedelta(0),
#   'CALL. CALATRAVA, 32',
#   32,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   '439480.836',
#   '4473484.39',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10051,
#   '2023S026028',
#   datetime.date(2023, 7, 23),
#   datetime.timedelta(0),
#   'CALL. CALATRAVA, 32',
#   32,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   '439480.836',
#   '4473484.39',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10052,
#   '2023S026028',
#   datetime.date(2023, 7, 23),
#   datetime.timedelta(0),
#   'CALL. CALATRAVA, 32',
#   32,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   '439480.836',
#   '4473484.39',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10053,
#   '2023S026028',
#   datetime.date(2023, 7, 23),
#   datetime.timedelta(0),
#   'CALL. CALATRAVA, 32',
#   32,
#   'CENTRO',
#   'Atropello a persona',
#   'Despejado',
#   '439480.836',
#   '4473484.39',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10065,
#   '2023S026076',
#   datetime.date(2023, 7, 24),
#   datetime.timedelta(seconds=19800),
#   'CALL. PRINCESA, 16',
#   16,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   '439528.857',
#   '4475287.089',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10066,
#   '2023S026076',
#   datetime.date(2023, 7, 24),
#   datetime.timedelta(seconds=19800),
#   'CALL. PRINCESA, 16',
#   16,
#   'CENTRO',
#   'Alcance',
#   'Despejado',
#   '439528.857',
#   '4475287.089',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10072,
#   '2023S026074',
#   datetime.date(2023, 7, 24),
#   datetime.timedelta(seconds=12600),
#   'CALL. HUERTAS / CALL. LEON',
#   21,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '440693.922',
#   '4473901.948',
#   'N',
#   'S',
#   'madrugada'),
#  (10073,
#   '2023S026074',
#   datetime.date(2023, 7, 24),
#   datetime.timedelta(seconds=12600),
#   'CALL. HUERTAS / CALL. LEON',
#   21,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '440693.922',
#   '4473901.948',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10078,
#   '2023S026070',
#   datetime.date(2023, 7, 24),
#   datetime.timedelta(seconds=7500),
#   'CALL. SEGOVIA, 35',
#   35,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '439265.538',
#   '4473937.886',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10079,
#   '2023S026070',
#   datetime.date(2023, 7, 24),
#   datetime.timedelta(seconds=7500),
#   'CALL. SEGOVIA, 35',
#   35,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '439265.538',
#   '4473937.886',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10080,
#   '2023S026070',
#   datetime.date(2023, 7, 24),
#   datetime.timedelta(seconds=7500),
#   'CALL. SEGOVIA, 35',
#   35,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '439265.538',
#   '4473937.886',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10086,
#   '2023S026138',
#   datetime.date(2023, 7, 25),
#   datetime.timedelta(seconds=21300),
#   'CALL. GRAN VIA / CALL. MARQUES DE VALDEIGLESIAS',
#   2,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '440870.447',
#   '4474498.909',
#   'N',
#   'S',
#   'madrugada'),
#  (10087,
#   '2023S026138',
#   datetime.date(2023, 7, 25),
#   datetime.timedelta(seconds=21300),
#   'CALL. GRAN VIA / CALL. MARQUES DE VALDEIGLESIAS',
#   2,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '440870.447',
#   '4474498.909',
#   'N',
#   'S',
#   'madrugada'),
#  (10093,
#   '2023S026210',
#   datetime.date(2023, 7, 26),
#   datetime.timedelta(seconds=12600),
#   'PLAZA. CANOVAS DEL CASTILLO / Paseo del Prado',
#   5,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '441098.495',
#   '4474037.166',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10094,
#   '2023S026210',
#   datetime.date(2023, 7, 26),
#   datetime.timedelta(seconds=12600),
#   'PLAZA. CANOVAS DEL CASTILLO / Paseo del Prado',
#   5,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '441098.495',
#   '4474037.166',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10095,
#   '2023S026210',
#   datetime.date(2023, 7, 26),
#   datetime.timedelta(seconds=12600),
#   'PLAZA. CANOVAS DEL CASTILLO / Paseo del Prado',
#   5,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '441098.495',
#   '4474037.166',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10108,
#   '2023S026279',
#   datetime.date(2023, 7, 27),
#   datetime.timedelta(seconds=5400),
#   'PLAZA. JACINTO BENAVENTE, 1',
#   1,
#   'CENTRO',
#   'Choque contra obstáculo fijo',
#   'Despejado',
#   '440321.709',
#   '4473969.948',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10109,
#   '2023S026341',
#   datetime.date(2023, 7, 28),
#   datetime.timedelta(seconds=10680),
#   'CALL. SAGASTA, 14',
#   14,
#   'CENTRO',
#   'Otro',
#   'Despejado',
#   '440652.078',
#   '4475546.444',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10110,
#   '2023S026341',
#   datetime.date(2023, 7, 28),
#   datetime.timedelta(seconds=10680),
#   'CALL. SAGASTA, 14',
#   14,
#   'CENTRO',
#   'Otro',
#   'Despejado',
#   '440652.078',
#   '4475546.444',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10111,
#   '2023S026342',
#   datetime.date(2023, 7, 28),
#   datetime.timedelta(seconds=11400),
#   'CALL. GRAN VIA, 1',
#   1,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   '440821.833',
#   '4474511.769',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10134,
#   '2023S026428',
#   datetime.date(2023, 7, 29),
#   datetime.timedelta(seconds=18840),
#   'PLAZA. SANTO DOMINGO, 7',
#   7,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   '439862.258',
#   '4474672.844',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10135,
#   '2023S026428',
#   datetime.date(2023, 7, 29),
#   datetime.timedelta(seconds=18840),
#   'PLAZA. SANTO DOMINGO, 7',
#   7,
#   'CENTRO',
#   'Caída',
#   'Despejado',
#   '439862.258',
#   '4474672.844',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (10171,
#   '2023S000453',
#   datetime.date(2023, 8, 1),
#   datetime.timedelta(seconds=2400),
#   'CALL. ALCALA / CALL. MARQUES DE CUBAS',
#   42,
#   'CENTRO',
#   'Colisión lateral',
#   'Lluvia débil',
#   '440914.393',
#   '4474457.653',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10172,
#   '2023S000453',
#   datetime.date(2023, 8, 1),
#   datetime.timedelta(seconds=2400),
#   'CALL. ALCALA / CALL. MARQUES DE CUBAS',
#   42,
#   'CENTRO',
#   'Colisión lateral',
#   'Lluvia débil',
#   '440914.393',
#   '4474457.653',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (10263,
#   '2023S027419',
#   datetime.date(2023, 8, 15),
#   datetime.timedelta(seconds=4500),
#   'CALL. ALCALA / CALL. MARQUES DE VALDEIGLESIAS',
#   41,
#   'CENTRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   '440860.853',
#   '4474500.414',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  ...)

# %% [markdown]
# #### Consultas de selección con referencia cruzada

# %% [markdown]
# Accidente en el que más personas y vehículos han estado involucrados

# %%
query="""SELECT 
    a.num_expediente,
    COALESCE(p.total_personas, 0) AS total_personas,
    COALESCE(v.total_vehiculos, 0) AS total_vehiculos
FROM 
    accidentes_de_trafico a
LEFT JOIN (
    SELECT 
        num_expediente, 
        COUNT(*) AS total_personas
    FROM 
        personas
    GROUP BY 
        num_expediente
) p ON a.num_expediente = p.num_expediente
LEFT JOIN (
    SELECT 
        num_expediente, 
        COUNT(*) AS total_vehiculos
    FROM 
        vehiculos
    GROUP BY 
        num_expediente
) v ON a.num_expediente = v.num_expediente
ORDER BY 
    total_personas DESC, 
    total_vehiculos DESC
LIMIT 1;

"""
cur.execute(query)
cur.fetchall()
# Out:
# (('2022S002867', 72, 36),)

# %% [markdown]
# ##### Consultas de Actualización

# %% [markdown]
# Actualizar el estado meteorologico en una fecha dada

# %%
query=""" UPDATE accidentes_de_trafico SET estado_meteorológico = 'Lluvioso' WHERE fecha = '2023-01-01';"""
cur.execute(query)
cur.fetchall()

# %% [markdown]
# #### Consultas de Inserción

# %% [markdown]
# Insertar un nuevo distrito

# %%
query="""INSERT INTO distritos (cod_distrito, nombre) VALUES (99, 'NuevoDistrito');"""
cur.execute(query)
cur.fetchall()

# %% [markdown]
# #### Consulta de Borrado de Datos

# %% [markdown]
# Eliminar un radar

# %%
query="""DELETE FROM radares WHERE n_radar = 12;"""
cur.execute(query)
cur.fetchall()

# %% [markdown]
# ### Consultas especiales

# %% [markdown]
# ##### Seleccionar los accidentes cuando el aforo de tráfico es alto

# %%
query="""SELECT at.*
FROM accidentes_de_trafico at
JOIN (
    SELECT fecha, 
           (hor1 + hor2 + hor3 + hor4 + hor5 + hor6 + hor7 + hor8 + hor9 + hor10 + hor11 + hor12) / 12 AS promedio_diario
    FROM aforo_trafico
) aa ON at.fecha = aa.fecha
WHERE aa.promedio_diario > (SELECT AVG(promedio_diario) * 1.25 FROM (
    SELECT fecha, 
           (hor1 + hor2 + hor3 + hor4 + hor5 + hor6 + hor7 + hor8 + hor9 + hor10 + hor11 + hor12) / 12 AS promedio_diario
    FROM aforo_trafico) t)
"""
cur.execute(query)
cur.fetchall()
# Out:
# ((179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (179,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (180,
#   '2021S000639',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=900),
#   'CALL. PEDRO BOSCH / AVDA. CIUDAD DE BARCELONA',
#   0,
#   'ARGANZUELA',
#   'Caída',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (181,
#   '2021S000562',
#   datetime.date(2021, 1, 18),
#   datetime.timedelta(seconds=4800),
#   'CALL. BENJAMIN PALENCIA / CALL. EL BOSCO',
#   14,
#   'PUENTE DE VALLECAS',
#   'Solo salida de la vía',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (321,
#   '2021S002743',
#   datetime.date(2021, 2, 18),
#   datetime.timedelta(seconds=13800),
#   'CALL. CUARENTA Y CUATRO MERCAMADRID / CALLE CUARENTA Y CINCO MERCAMADRID',
#   5,
#   'VILLA DE VALLECAS',
#   'Atropello a persona',
#   'Despejado',
#   'NULL',
# ...
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3395,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3396,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'N',
#   'Se desconoce',
#   'madrugada'),
#  (3397,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (3397,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (3397,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  (3397,
#   '2022S000002',
#   datetime.date(2022, 1, 1),
#   datetime.timedelta(seconds=1800),
#   'PLAZA. CANOVAS DEL CASTILLO / PASEO. PRADO',
#   2,
#   'RETIRO',
#   'Colisión fronto-lateral',
#   'Despejado',
#   'NULL',
#   'NULL',
#   'S',
#   'Se desconoce',
#   'madrugada'),
#  ...)

# %% [markdown]
#  ##### Análisis de Tendencias de Accidentes de Tráfico por Distrito y Tipo de Accidente.

# %%
sql='SELECT a.nombre_distrito, f.año, f.mes, a.tipo_accidente, COUNT(*) AS total_accidentes FROM accidentes_de_trafico a JOIN fechas f ON a.fecha = f.fecha GROUP BY a.nombre_distrito, f.año, f.mes, a.tipo_accidente ORDER BY a.nombre_distrito, f.año, f.mes, total_accidentes DESC; '
cur.execute(sql)
cur.fetchall()
# Out:
# (('ARGANZUELA', 2021, 'abril', 'Alcance', 57),
#  ('ARGANZUELA', 2021, 'abril', 'Colisión fronto-lateral', 34),
#  ('ARGANZUELA', 2021, 'abril', 'Colisión lateral', 24),
#  ('ARGANZUELA', 2021, 'abril', 'Choque contra obstáculo fijo', 23),
#  ('ARGANZUELA', 2021, 'abril', 'Colisión múltiple', 12),
#  ('ARGANZUELA', 2021, 'abril', 'Atropello a persona', 10),
#  ('ARGANZUELA', 2021, 'abril', 'Caída', 10),
#  ('ARGANZUELA', 2021, 'abril', 'Solo salida de la vía', 1),
#  ('ARGANZUELA', 2021, 'agosto', 'Colisión fronto-lateral', 32),
#  ('ARGANZUELA', 2021, 'agosto', 'Alcance', 22),
#  ('ARGANZUELA', 2021, 'agosto', 'Colisión lateral', 17),
#  ('ARGANZUELA', 2021, 'agosto', 'Colisión múltiple', 17),
#  ('ARGANZUELA', 2021, 'agosto', 'Caída', 9),
#  ('ARGANZUELA', 2021, 'agosto', 'Atropello a persona', 8),
#  ('ARGANZUELA', 2021, 'agosto', 'Choque contra obstáculo fijo', 4),
#  ('ARGANZUELA', 2021, 'agosto', 'Colisión frontal', 2),
#  ('ARGANZUELA', 2021, 'diciembre', 'Colisión fronto-lateral', 75),
#  ('ARGANZUELA', 2021, 'diciembre', 'Alcance', 72),
#  ('ARGANZUELA', 2021, 'diciembre', 'Colisión múltiple', 20),
#  ('ARGANZUELA', 2021, 'diciembre', 'Colisión lateral', 17),
#  ('ARGANZUELA', 2021, 'diciembre', 'Choque contra obstáculo fijo', 15),
#  ('ARGANZUELA', 2021, 'diciembre', 'Atropello a persona', 13),
#  ('ARGANZUELA', 2021, 'diciembre', 'Caída', 11),
#  ('ARGANZUELA', 2021, 'diciembre', 'Otro', 8),
#  ('ARGANZUELA', 2021, 'diciembre', 'Solo salida de la vía', 5),
#  ('ARGANZUELA', 2021, 'diciembre', 'Colisión frontal', 2),
#  ('ARGANZUELA', 2021, 'enero', 'Alcance', 45),
#  ('ARGANZUELA', 2021, 'enero', 'Colisión múltiple', 23),
#  ('ARGANZUELA', 2021, 'enero', 'Colisión fronto-lateral', 22),
#  ('ARGANZUELA', 2021, 'enero', 'Choque contra obstáculo fijo', 14),
#  ('ARGANZUELA', 2021, 'enero', 'Colisión lateral', 13),
#  ('ARGANZUELA', 2021, 'enero', 'Caída', 11),
#  ('ARGANZUELA', 2021, 'enero', 'Atropello a persona', 6),
#  ('ARGANZUELA', 2021, 'enero', 'Colisión frontal', 4),
#  ('ARGANZUELA', 2021, 'febrero', 'Alcance', 37),
#  ('ARGANZUELA', 2021, 'febrero', 'Colisión fronto-lateral', 30),
#  ('ARGANZUELA', 2021, 'febrero', 'Caída', 18),
#  ('ARGANZUELA', 2021, 'febrero', 'Choque contra obstáculo fijo', 12),
#  ('ARGANZUELA', 2021, 'febrero', 'Colisión lateral', 10),
#  ('ARGANZUELA', 2021, 'febrero', 'Atropello a persona', 6),
#  ('ARGANZUELA', 2021, 'febrero', 'Colisión frontal', 2),
#  ('ARGANZUELA', 2021, 'febrero', 'Otro', 1),
#  ('ARGANZUELA', 2021, 'julio', 'Colisión fronto-lateral', 57),
#  ('ARGANZUELA', 2021, 'julio', 'Alcance', 28),
#  ('ARGANZUELA', 2021, 'julio', 'Colisión lateral', 27),
#  ('ARGANZUELA', 2021, 'julio', 'Choque contra obstáculo fijo', 16),
#  ('ARGANZUELA', 2021, 'julio', 'Atropello a persona', 13),
#  ('ARGANZUELA', 2021, 'julio', 'Caída', 7),
#  ('ARGANZUELA', 2021, 'julio', 'Colisión frontal', 3),
#  ('ARGANZUELA', 2021, 'julio', 'Colisión múltiple', 3),
#  ('ARGANZUELA', 2021, 'julio', 'Solo salida de la vía', 3),
#  ('ARGANZUELA', 2021, 'julio', 'Despeñamiento', 2),
#  ('ARGANZUELA', 2021, 'julio', 'Otro', 1),
#  ('ARGANZUELA', 2021, 'junio', 'Alcance', 55),
#  ('ARGANZUELA', 2021, 'junio', 'Colisión lateral', 28),
#  ('ARGANZUELA', 2021, 'junio', 'Atropello a persona', 25),
#  ('ARGANZUELA', 2021, 'junio', 'Colisión fronto-lateral', 22),
#  ('ARGANZUELA', 2021, 'junio', 'Choque contra obstáculo fijo', 18),
#  ('ARGANZUELA', 2021, 'junio', 'Colisión múltiple', 11),
#  ('ARGANZUELA', 2021, 'junio', 'Caída', 8),
#  ('ARGANZUELA', 2021, 'junio', 'Colisión frontal', 2),
#  ('ARGANZUELA', 2021, 'marzo', 'Alcance', 38),
#  ('ARGANZUELA', 2021, 'marzo', 'Colisión fronto-lateral', 30),
#  ('ARGANZUELA', 2021, 'marzo', 'Colisión lateral', 20),
#  ('ARGANZUELA', 2021, 'marzo', 'Colisión múltiple', 17),
#  ('ARGANZUELA', 2021, 'marzo', 'Atropello a persona', 12),
#  ('ARGANZUELA', 2021, 'marzo', 'Choque contra obstáculo fijo', 11),
#  ('ARGANZUELA', 2021, 'marzo', 'Colisión frontal', 8),
#  ('ARGANZUELA', 2021, 'marzo', 'Caída', 7),
#  ('ARGANZUELA', 2021, 'marzo', 'Otro', 5),
#  ('ARGANZUELA', 2021, 'marzo', 'Solo salida de la vía', 1),
#  ('ARGANZUELA', 2021, 'mayo', 'Colisión fronto-lateral', 52),
#  ('ARGANZUELA', 2021, 'mayo', 'Alcance', 43),
#  ('ARGANZUELA', 2021, 'mayo', 'Colisión lateral', 27),
#  ('ARGANZUELA', 2021, 'mayo', 'Atropello a persona', 14),
#  ('ARGANZUELA', 2021, 'mayo', 'Caída', 11),
#  ('ARGANZUELA', 2021, 'mayo', 'Colisión múltiple', 8),
#  ('ARGANZUELA', 2021, 'mayo', 'Choque contra obstáculo fijo', 7),
#  ('ARGANZUELA', 2021, 'noviembre', 'Colisión fronto-lateral', 64),
#  ('ARGANZUELA', 2021, 'noviembre', 'Alcance', 46),
#  ('ARGANZUELA', 2021, 'noviembre', 'Colisión lateral', 23),
#  ('ARGANZUELA', 2021, 'noviembre', 'Choque contra obstáculo fijo', 18),
#  ('ARGANZUELA', 2021, 'noviembre', 'Colisión múltiple', 14),
#  ('ARGANZUELA', 2021, 'noviembre', 'Caída', 10),
#  ('ARGANZUELA', 2021, 'noviembre', 'Atropello a persona', 7),
#  ('ARGANZUELA', 2021, 'noviembre', 'Solo salida de la vía', 2),
#  ('ARGANZUELA', 2021, 'octubre', 'Colisión fronto-lateral', 47),
#  ('ARGANZUELA', 2021, 'octubre', 'Colisión lateral', 38),
#  ('ARGANZUELA', 2021, 'octubre', 'Alcance', 37),
#  ('ARGANZUELA', 2021, 'octubre', 'Choque contra obstáculo fijo', 25),
#  ('ARGANZUELA', 2021, 'octubre', 'Colisión múltiple', 21),
#  ('ARGANZUELA', 2021, 'octubre', 'Caída', 20),
#  ('ARGANZUELA', 2021, 'octubre', 'Atropello a persona', 14),
#  ('ARGANZUELA', 2021, 'octubre', 'Colisión frontal', 2),
#  ('ARGANZUELA', 2021, 'septiembre', 'Colisión lateral', 44),
#  ('ARGANZUELA', 2021, 'septiembre', 'Alcance', 40),
#  ('ARGANZUELA', 2021, 'septiembre', 'Colisión fronto-lateral', 36),
#  ('ARGANZUELA', 2021, 'septiembre', 'Colisión múltiple', 24),
#  ('ARGANZUELA', 2021, 'septiembre', 'Caída', 17),
#  ('ARGANZUELA', 2021, 'septiembre', 'Choque contra obstáculo fijo', 14),
#  ('ARGANZUELA', 2021, 'septiembre', 'Atropello a persona', 8),
#  ('ARGANZUELA', 2021, 'septiembre', 'Colisión frontal', 2),
#  ('ARGANZUELA', 2022, 'abril', 'Colisión fronto-lateral', 38),
#  ('ARGANZUELA', 2022, 'abril', 'Alcance', 26),
#  ('ARGANZUELA', 2022, 'abril', 'Colisión lateral', 19),
#  ('ARGANZUELA', 2022, 'abril', 'Colisión múltiple', 16),
#  ('ARGANZUELA', 2022, 'abril', 'Choque contra obstáculo fijo', 14),
#  ('ARGANZUELA', 2022, 'abril', 'Atropello a persona', 13),
#  ('ARGANZUELA', 2022, 'abril', 'Caída', 11),
#  ('ARGANZUELA', 2022, 'abril', 'Colisión frontal', 6),
#  ('ARGANZUELA', 2022, 'abril', 'Vuelco', 4),
#  ('ARGANZUELA', 2022, 'abril', 'Otro', 1),
#  ('ARGANZUELA', 2022, 'agosto', 'Colisión fronto-lateral', 45),
#  ('ARGANZUELA', 2022, 'agosto', 'Alcance', 30),
#  ('ARGANZUELA', 2022, 'agosto', 'Colisión lateral', 26),
#  ('ARGANZUELA', 2022, 'agosto', 'Choque contra obstáculo fijo', 16),
#  ('ARGANZUELA', 2022, 'agosto', 'Caída', 12),
#  ('ARGANZUELA', 2022, 'agosto', 'Atropello a persona', 11),
#  ('ARGANZUELA', 2022, 'agosto', 'Colisión múltiple', 11),
#  ('ARGANZUELA', 2022, 'agosto', 'Vuelco', 5),
#  ('ARGANZUELA', 2022, 'agosto', 'Otro', 4),
#  ('ARGANZUELA', 2022, 'agosto', 'Atropello a animal', 1),
#  ('ARGANZUELA', 2022, 'diciembre', 'Alcance', 66),
#  ('ARGANZUELA', 2022, 'diciembre', 'Colisión fronto-lateral', 48),
#  ('ARGANZUELA', 2022, 'diciembre', 'Colisión lateral', 37),
#  ('ARGANZUELA', 2022, 'diciembre', 'Choque contra obstáculo fijo', 11),
#  ('ARGANZUELA', 2022, 'diciembre', 'Atropello a persona', 9),
#  ('ARGANZUELA', 2022, 'diciembre', 'Caída', 8),
#  ('ARGANZUELA', 2022, 'diciembre', 'Colisión múltiple', 7),
#  ('ARGANZUELA', 2022, 'diciembre', 'Otro', 3),
#  ('ARGANZUELA', 2022, 'diciembre', 'Colisión frontal', 2),
#  ('ARGANZUELA', 2022, 'diciembre', 'Vuelco', 1),
#  ('ARGANZUELA', 2022, 'enero', 'Alcance', 52),
#  ('ARGANZUELA', 2022, 'enero', 'Colisión fronto-lateral', 35),
#  ('ARGANZUELA', 2022, 'enero', 'Colisión lateral', 19),
#  ('ARGANZUELA', 2022, 'enero', 'Choque contra obstáculo fijo', 14),
#  ('ARGANZUELA', 2022, 'enero', 'Colisión múltiple', 10),
#  ('ARGANZUELA', 2022, 'enero', 'Caída', 4),
#  ('ARGANZUELA', 2022, 'enero', 'Otro', 4),
#  ('ARGANZUELA', 2022, 'enero', 'Atropello a persona', 2),
#  ('ARGANZUELA', 2022, 'enero', 'Atropello a animal', 1),
#  ('ARGANZUELA', 2022, 'febrero', 'Colisión fronto-lateral', 41),
#  ('ARGANZUELA', 2022, 'febrero', 'Alcance', 39),
#  ('ARGANZUELA', 2022, 'febrero', 'Colisión lateral', 29),
#  ('ARGANZUELA', 2022, 'febrero', 'Choque contra obstáculo fijo', 14),
#  ('ARGANZUELA', 2022, 'febrero', 'Atropello a persona', 11),
#  ('ARGANZUELA', 2022, 'febrero', 'Colisión múltiple', 10),
#  ('ARGANZUELA', 2022, 'febrero', 'Caída', 8),
#  ('ARGANZUELA', 2022, 'febrero', 'Colisión frontal', 8),
#  ('ARGANZUELA', 2022, 'febrero', 'Otro', 1),
#  ('ARGANZUELA', 2022, 'febrero', 'Vuelco', 1),
#  ('ARGANZUELA', 2022, 'julio', 'Alcance', 47),
#  ('ARGANZUELA', 2022, 'julio', 'Colisión lateral', 44),
#  ('ARGANZUELA', 2022, 'julio', 'Colisión fronto-lateral', 32),
#  ('ARGANZUELA', 2022, 'julio', 'Caída', 18),
#  ('ARGANZUELA', 2022, 'julio', 'Atropello a persona', 17),
#  ('ARGANZUELA', 2022, 'julio', 'Colisión múltiple', 10),
#  ('ARGANZUELA', 2022, 'julio', 'Choque contra obstáculo fijo', 8),
#  ('ARGANZUELA', 2022, 'julio', 'Otro', 1),
#  ('ARGANZUELA', 2022, 'julio', 'Vuelco', 1),
#  ('ARGANZUELA', 2022, 'junio', 'Colisión fronto-lateral', 48),
#  ('ARGANZUELA', 2022, 'junio', 'Alcance', 41),
#  ('ARGANZUELA', 2022, 'junio', 'Colisión lateral', 34),
#  ('ARGANZUELA', 2022, 'junio', 'Colisión múltiple', 14),
#  ('ARGANZUELA', 2022, 'junio', 'Caída', 11),
#  ('ARGANZUELA', 2022, 'junio', 'Choque contra obstáculo fijo', 11),
#  ('ARGANZUELA', 2022, 'junio', 'Atropello a persona', 10),
#  ('ARGANZUELA', 2022, 'junio', 'Solo salida de la vía', 1),
#  ('ARGANZUELA', 2022, 'marzo', 'Alcance', 53),
#  ('ARGANZUELA', 2022, 'marzo', 'Colisión fronto-lateral', 39),
#  ('ARGANZUELA', 2022, 'marzo', 'Choque contra obstáculo fijo', 30),
#  ('ARGANZUELA', 2022, 'marzo', 'Colisión lateral', 28),
#  ('ARGANZUELA', 2022, 'marzo', 'Colisión múltiple', 19),
#  ('ARGANZUELA', 2022, 'marzo', 'Atropello a persona', 12),
#  ('ARGANZUELA', 2022, 'marzo', 'Caída', 8),
#  ('ARGANZUELA', 2022, 'marzo', 'Colisión frontal', 8),
#  ('ARGANZUELA', 2022, 'marzo', 'Otro', 3),
#  ('ARGANZUELA', 2022, 'marzo', 'Atropello a animal', 1),
#  ('ARGANZUELA', 2022, 'mayo', 'Alcance', 57),
#  ('ARGANZUELA', 2022, 'mayo', 'Choque contra obstáculo fijo', 24),
#  ('ARGANZUELA', 2022, 'mayo', 'Colisión fronto-lateral', 23),
#  ('ARGANZUELA', 2022, 'mayo', 'Caída', 18),
#  ('ARGANZUELA', 2022, 'mayo', 'Colisión lateral', 17),
#  ('ARGANZUELA', 2022, 'mayo', 'Atropello a persona', 16),
#  ('ARGANZUELA', 2022, 'mayo', 'Colisión múltiple', 16),
#  ('ARGANZUELA', 2022, 'mayo', 'Colisión frontal', 2),
#  ('ARGANZUELA', 2022, 'mayo', 'Otro', 2),
#  ('ARGANZUELA', 2022, 'mayo', 'Solo salida de la vía', 1),
#  ('ARGANZUELA', 2022, 'noviembre', 'Alcance', 59),
#  ('ARGANZUELA', 2022, 'noviembre', 'Colisión lateral', 44),
#  ('ARGANZUELA', 2022, 'noviembre', 'Colisión fronto-lateral', 31),
#  ('ARGANZUELA', 2022, 'noviembre', 'Colisión múltiple', 24),
#  ('ARGANZUELA', 2022, 'noviembre', 'Choque contra obstáculo fijo', 16),
#  ('ARGANZUELA', 2022, 'noviembre', 'Atropello a persona', 14),
#  ('ARGANZUELA', 2022, 'noviembre', 'Caída', 13),
#  ('ARGANZUELA', 2022, 'noviembre', 'Colisión frontal', 4),
#  ('ARGANZUELA', 2022, 'octubre', 'Colisión fronto-lateral', 54),
#  ('ARGANZUELA', 2022, 'octubre', 'Alcance', 34),
#  ('ARGANZUELA', 2022, 'octubre', 'Caída', 10),
#  ('ARGANZUELA', 2022, 'octubre', 'Colisión lateral', 10),
#  ('ARGANZUELA', 2022, 'octubre', 'Choque contra obstáculo fijo', 9),
#  ('ARGANZUELA', 2022, 'octubre', 'Atropello a persona', 6),
#  ('ARGANZUELA', 2022, 'octubre', 'Colisión múltiple', 6),
#  ('ARGANZUELA', 2022, 'octubre', 'Otro', 5),
#  ('ARGANZUELA', 2022, 'octubre', 'Solo salida de la vía', 1),
#  ('ARGANZUELA', 2022, 'septiembre', 'Alcance', 35),
#  ('ARGANZUELA', 2022, 'septiembre', 'Colisión lateral', 34),
#  ('ARGANZUELA', 2022, 'septiembre', 'Colisión fronto-lateral', 21),
#  ('ARGANZUELA', 2022, 'septiembre', 'Atropello a persona', 17),
#  ('ARGANZUELA', 2022, 'septiembre', 'Colisión múltiple', 17),
#  ('ARGANZUELA', 2022, 'septiembre', 'Choque contra obstáculo fijo', 13),
#  ('ARGANZUELA', 2022, 'septiembre', 'Caída', 10),
#  ('ARGANZUELA', 2022, 'septiembre', 'Colisión frontal', 4),
#  ('ARGANZUELA', 2022, 'septiembre', 'Otro', 2),
#  ('ARGANZUELA', 2023, 'abril', 'Alcance', 49),
#  ('ARGANZUELA', 2023, 'abril', 'Colisión fronto-lateral', 32),
#  ('ARGANZUELA', 2023, 'abril', 'Colisión lateral', 30),
#  ('ARGANZUELA', 2023, 'abril', 'Choque contra obstáculo fijo', 14),
#  ('ARGANZUELA', 2023, 'abril', 'Caída', 13),
#  ('ARGANZUELA', 2023, 'abril', 'Colisión múltiple', 12),
#  ('ARGANZUELA', 2023, 'abril', 'Atropello a persona', 10),
#  ('ARGANZUELA', 2023, 'abril', 'Colisión frontal', 4),
#  ('ARGANZUELA', 2023, 'abril', 'Otro', 1),
#  ('ARGANZUELA', 2023, 'agosto', 'Alcance', 34),
#  ('ARGANZUELA', 2023, 'agosto', 'Colisión lateral', 26),
#  ('ARGANZUELA', 2023, 'agosto', 'Colisión fronto-lateral', 18),
#  ('ARGANZUELA', 2023, 'agosto', 'Caída', 11),
#  ('ARGANZUELA', 2023, 'agosto', 'Choque contra obstáculo fijo', 11),
#  ('ARGANZUELA', 2023, 'agosto', 'Atropello a persona', 10),
#  ('ARGANZUELA', 2023, 'agosto', 'Colisión múltiple', 7),
#  ('ARGANZUELA', 2023, 'agosto', 'Otro', 2),
#  ('ARGANZUELA', 2023, 'agosto', 'Solo salida de la vía', 2),
#  ('ARGANZUELA', 2023, 'agosto', 'Atropello a animal', 1),
#  ('ARGANZUELA', 2023, 'diciembre', 'Alcance', 18),
#  ('ARGANZUELA', 2023, 'diciembre', 'Colisión lateral', 15),
#  ('ARGANZUELA', 2023, 'diciembre', 'Colisión múltiple', 11),
#  ('ARGANZUELA', 2023, 'diciembre', 'Choque contra obstáculo fijo', 7),
#  ('ARGANZUELA', 2023, 'diciembre', 'Colisión fronto-lateral', 7),
#  ('ARGANZUELA', 2023, 'diciembre', 'Caída', 2),
#  ('ARGANZUELA', 2023, 'diciembre', 'Solo salida de la vía', 2),
#  ('ARGANZUELA', 2023, 'enero', 'Alcance', 53),
#  ('ARGANZUELA', 2023, 'enero', 'Colisión fronto-lateral', 41),
#  ('ARGANZUELA', 2023, 'enero', 'Colisión múltiple', 27),
#  ('ARGANZUELA', 2023, 'enero', 'Colisión lateral', 21),
#  ('ARGANZUELA', 2023, 'enero', 'Caída', 16),
#  ('ARGANZUELA', 2023, 'enero', 'Atropello a persona', 14),
#  ('ARGANZUELA', 2023, 'enero', 'Choque contra obstáculo fijo', 11),
#  ('ARGANZUELA', 2023, 'enero', 'Colisión frontal', 2),
#  ('ARGANZUELA', 2023, 'enero', 'Otro', 1),
#  ('ARGANZUELA', 2023, 'febrero', 'Colisión lateral', 51),
#  ('ARGANZUELA', 2023, 'febrero', 'Alcance', 35),
#  ('ARGANZUELA', 2023, 'febrero', 'Colisión fronto-lateral', 32),
#  ('ARGANZUELA', 2023, 'febrero', 'Caída', 12),
#  ('ARGANZUELA', 2023, 'febrero', 'Choque contra obstáculo fijo', 9),
#  ('ARGANZUELA', 2023, 'febrero', 'Colisión múltiple', 9),
#  ('ARGANZUELA', 2023, 'febrero', 'Otro', 3),
#  ('ARGANZUELA', 2023, 'febrero', 'Atropello a persona', 2),
#  ('ARGANZUELA', 2023, 'febrero', 'Colisión frontal', 2),
#  ('ARGANZUELA', 2023, 'julio', 'Alcance', 35),
#  ('ARGANZUELA', 2023, 'julio', 'Colisión fronto-lateral', 21),
#  ('ARGANZUELA', 2023, 'julio', 'Caída', 15),
#  ('ARGANZUELA', 2023, 'julio', 'Colisión múltiple', 15),
#  ('ARGANZUELA', 2023, 'julio', 'Atropello a persona', 12),
#  ('ARGANZUELA', 2023, 'julio', 'Colisión lateral', 12),
#  ('ARGANZUELA', 2023, 'julio', 'Choque contra obstáculo fijo', 9),
#  ('ARGANZUELA', 2023, 'julio', 'Colisión frontal', 5),
#  ('ARGANZUELA', 2023, 'julio', 'Otro', 5),
#  ('ARGANZUELA', 2023, 'julio', 'Vuelco', 2),
#  ('ARGANZUELA', 2023, 'junio', 'Alcance', 32),
#  ('ARGANZUELA', 2023, 'junio', 'Colisión lateral', 27),
#  ('ARGANZUELA', 2023, 'junio', 'Colisión fronto-lateral', 26),
#  ('ARGANZUELA', 2023, 'junio', 'Colisión múltiple', 15),
#  ('ARGANZUELA', 2023, 'junio', 'Caída', 9),
#  ('ARGANZUELA', 2023, 'junio', 'Vuelco', 8),
#  ('ARGANZUELA', 2023, 'junio', 'Choque contra obstáculo fijo', 5),
#  ('ARGANZUELA', 2023, 'junio', 'Otro', 3),
#  ('ARGANZUELA', 2023, 'junio', 'Solo salida de la vía', 1),
#  ('ARGANZUELA', 2023, 'marzo', 'Colisión fronto-lateral', 44),
#  ('ARGANZUELA', 2023, 'marzo', 'Colisión lateral', 36),
#  ('ARGANZUELA', 2023, 'marzo', 'Alcance', 23),
#  ('ARGANZUELA', 2023, 'marzo', 'Colisión múltiple', 14),
#  ('ARGANZUELA', 2023, 'marzo', 'Atropello a persona', 13),
#  ('ARGANZUELA', 2023, 'marzo', 'Choque contra obstáculo fijo', 10),
#  ('ARGANZUELA', 2023, 'marzo', 'Caída', 8),
#  ('ARGANZUELA', 2023, 'marzo', 'Vuelco', 4),
#  ('ARGANZUELA', 2023, 'marzo', 'Colisión frontal', 2),
#  ('ARGANZUELA', 2023, 'marzo', 'Atropello a animal', 1),
#  ('ARGANZUELA', 2023, 'marzo', 'Otro', 1),
#  ('ARGANZUELA', 2023, 'marzo', 'Solo salida de la vía', 1),
#  ('ARGANZUELA', 2023, 'mayo', 'Alcance', 58),
#  ('ARGANZUELA', 2023, 'mayo', 'Colisión fronto-lateral', 28),
#  ('ARGANZUELA', 2023, 'mayo', 'Colisión lateral', 28),
#  ('ARGANZUELA', 2023, 'mayo', 'Caída', 19),
#  ('ARGANZUELA', 2023, 'mayo', 'Colisión múltiple', 15),
#  ('ARGANZUELA', 2023, 'mayo', 'Choque contra obstáculo fijo', 13),
#  ('ARGANZUELA', 2023, 'mayo', 'Atropello a persona', 10),
#  ('ARGANZUELA', 2023, 'mayo', 'Colisión frontal', 6),
#  ('ARGANZUELA', 2023, 'mayo', 'Atropello a animal', 1),
#  ('ARGANZUELA', 2023, 'mayo', 'Otro', 1),
#  ('ARGANZUELA', 2023, 'mayo', 'Vuelco', 1),
#  ('ARGANZUELA', 2023, 'noviembre', 'Colisión lateral', 16),
#  ('ARGANZUELA', 2023, 'noviembre', 'Colisión múltiple', 14),
#  ('ARGANZUELA', 2023, 'noviembre', 'Alcance', 12),
#  ('ARGANZUELA', 2023, 'noviembre', 'Colisión fronto-lateral', 7),
#  ('ARGANZUELA', 2023, 'noviembre', 'Atropello a persona', 4),
#  ('ARGANZUELA', 2023, 'noviembre', 'Choque contra obstáculo fijo', 2),
#  ('ARGANZUELA', 2023, 'noviembre', 'Colisión frontal', 2),
#  ('ARGANZUELA', 2023, 'noviembre', 'Caída', 1),
#  ('ARGANZUELA', 2023, 'octubre', 'Colisión múltiple', 20),
#  ('ARGANZUELA', 2023, 'octubre', 'Colisión fronto-lateral', 16),
#  ('ARGANZUELA', 2023, 'octubre', 'Alcance', 12),
#  ('ARGANZUELA', 2023, 'octubre', 'Colisión lateral', 9),
#  ('ARGANZUELA', 2023, 'octubre', 'Choque contra obstáculo fijo', 8),
#  ('ARGANZUELA', 2023, 'octubre', 'Atropello a persona', 6),
#  ('ARGANZUELA', 2023, 'octubre', 'Caída', 6),
#  ('ARGANZUELA', 2023, 'septiembre', 'Alcance', 10),
#  ('ARGANZUELA', 2023, 'septiembre', 'Colisión fronto-lateral', 6),
#  ('ARGANZUELA', 2023, 'septiembre', 'Atropello a persona', 2),
#  ('ARGANZUELA', 2023, 'septiembre', 'Choque contra obstáculo fijo', 2),
#  ('ARGANZUELA', 2023, 'septiembre', 'Colisión frontal', 2),
#  ('ARGANZUELA', 2023, 'septiembre', 'Colisión lateral', 2),
#  ('ARGANZUELA', 2023, 'septiembre', 'Caída', 1),
#  ('ARGANZUELA', 2023, 'septiembre', 'Otro', 1),
#  ('BARAJAS', 2021, 'abril', 'Choque contra obstáculo fijo', 15),
#  ('BARAJAS', 2021, 'abril', 'Colisión múltiple', 5),
#  ('BARAJAS', 2021, 'abril', 'Alcance', 4),
#  ('BARAJAS', 2021, 'abril', 'Colisión fronto-lateral', 4),
#  ('BARAJAS', 2021, 'abril', 'Colisión lateral', 4),
#  ('BARAJAS', 2021, 'abril', 'Atropello a persona', 2),
#  ('BARAJAS', 2021, 'abril', 'Vuelco', 2),
#  ('BARAJAS', 2021, 'agosto', 'Choque contra obstáculo fijo', 12),
#  ('BARAJAS', 2021, 'agosto', 'Colisión fronto-lateral', 12),
#  ('BARAJAS', 2021, 'agosto', 'Alcance', 10),
#  ('BARAJAS', 2021, 'agosto', 'Colisión lateral', 6),
#  ('BARAJAS', 2021, 'agosto', 'Atropello a persona', 5),
#  ('BARAJAS', 2021, 'agosto', 'Caída', 2),
#  ('BARAJAS', 2021, 'diciembre', 'Colisión fronto-lateral', 29),
#  ('BARAJAS', 2021, 'diciembre', 'Alcance', 19),
#  ('BARAJAS', 2021, 'diciembre', 'Colisión lateral', 15),
#  ('BARAJAS', 2021, 'diciembre', 'Atropello a persona', 13),
#  ('BARAJAS', 2021, 'diciembre', 'Choque contra obstáculo fijo', 8),
#  ('BARAJAS', 2021, 'diciembre', 'Colisión múltiple', 4),
#  ('BARAJAS', 2021, 'diciembre', 'Otro', 3),
#  ('BARAJAS', 2021, 'diciembre', 'Caída', 2),
#  ('BARAJAS', 2021, 'enero', 'Choque contra obstáculo fijo', 15),
#  ('BARAJAS', 2021, 'enero', 'Colisión fronto-lateral', 8),
#  ('BARAJAS', 2021, 'enero', 'Alcance', 4),
#  ('BARAJAS', 2021, 'enero', 'Caída', 4),
#  ('BARAJAS', 2021, 'enero', 'Atropello a persona', 2),
#  ('BARAJAS', 2021, 'febrero', 'Alcance', 6),
#  ('BARAJAS', 2021, 'febrero', 'Atropello a persona', 5),
#  ('BARAJAS', 2021, 'febrero', 'Colisión lateral', 5),
#  ('BARAJAS', 2021, 'febrero', 'Choque contra obstáculo fijo', 4),
#  ('BARAJAS', 2021, 'febrero', 'Caída', 2),
#  ('BARAJAS', 2021, 'febrero', 'Otro', 1),
#  ('BARAJAS', 2021, 'julio', 'Colisión fronto-lateral', 20),
#  ('BARAJAS', 2021, 'julio', 'Choque contra obstáculo fijo', 16),
#  ('BARAJAS', 2021, 'julio', 'Caída', 8),
#  ('BARAJAS', 2021, 'julio', 'Alcance', 7),
#  ('BARAJAS', 2021, 'julio', 'Atropello a persona', 5),
#  ('BARAJAS', 2021, 'julio', 'Colisión lateral', 4),
#  ('BARAJAS', 2021, 'julio', 'Colisión múltiple', 3),
#  ('BARAJAS', 2021, 'julio', 'Solo salida de la vía', 2),
#  ('BARAJAS', 2021, 'junio', 'Colisión fronto-lateral', 20),
#  ('BARAJAS', 2021, 'junio', 'Alcance', 15),
#  ('BARAJAS', 2021, 'junio', 'Choque contra obstáculo fijo', 14),
#  ('BARAJAS', 2021, 'junio', 'Colisión lateral', 8),
#  ('BARAJAS', 2021, 'junio', 'Caída', 4),
#  ('BARAJAS', 2021, 'junio', 'Colisión múltiple', 3),
#  ('BARAJAS', 2021, 'junio', 'Atropello a persona', 2),
#  ('BARAJAS', 2021, 'junio', 'Atropello a animal', 1),
#  ('BARAJAS', 2021, 'marzo', 'Colisión fronto-lateral', 15),
#  ('BARAJAS', 2021, 'marzo', 'Choque contra obstáculo fijo', 10),
#  ('BARAJAS', 2021, 'marzo', 'Alcance', 8),
#  ('BARAJAS', 2021, 'marzo', 'Atropello a persona', 6),
#  ('BARAJAS', 2021, 'marzo', 'Colisión lateral', 3),
#  ('BARAJAS', 2021, 'marzo', 'Caída', 1),
#  ('BARAJAS', 2021, 'marzo', 'Otro', 1),
#  ('BARAJAS', 2021, 'mayo', 'Colisión fronto-lateral', 25),
#  ('BARAJAS', 2021, 'mayo', 'Choque contra obstáculo fijo', 9),
#  ('BARAJAS', 2021, 'mayo', 'Colisión lateral', 6),
#  ('BARAJAS', 2021, 'mayo', 'Alcance', 5),
#  ('BARAJAS', 2021, 'mayo', 'Colisión frontal', 4),
#  ('BARAJAS', 2021, 'mayo', 'Atropello a persona', 2),
#  ('BARAJAS', 2021, 'noviembre', 'Colisión lateral', 12),
#  ('BARAJAS', 2021, 'noviembre', 'Colisión múltiple', 12),
#  ('BARAJAS', 2021, 'noviembre', 'Atropello a persona', 11),
#  ('BARAJAS', 2021, 'noviembre', 'Choque contra obstáculo fijo', 10),
#  ('BARAJAS', 2021, 'noviembre', 'Colisión fronto-lateral', 10),
#  ('BARAJAS', 2021, 'noviembre', 'Alcance', 7),
#  ('BARAJAS', 2021, 'noviembre', 'Caída', 5),
#  ('BARAJAS', 2021, 'noviembre', 'Colisión frontal', 2),
#  ('BARAJAS', 2021, 'noviembre', 'Otro', 1),
#  ('BARAJAS', 2021, 'noviembre', 'Vuelco', 1),
#  ('BARAJAS', 2021, 'octubre', 'Colisión fronto-lateral', 14),
#  ('BARAJAS', 2021, 'octubre', 'Alcance', 13),
#  ('BARAJAS', 2021, 'octubre', 'Choque contra obstáculo fijo', 12),
#  ('BARAJAS', 2021, 'octubre', 'Atropello a persona', 8),
#  ('BARAJAS', 2021, 'octubre', 'Colisión lateral', 8),
#  ('BARAJAS', 2021, 'octubre', 'Colisión frontal', 4),
#  ('BARAJAS', 2021, 'octubre', 'Caída', 3),
#  ('BARAJAS', 2021, 'octubre', 'Colisión múltiple', 3),
#  ('BARAJAS', 2021, 'octubre', 'Otro', 1),
#  ('BARAJAS', 2021, 'septiembre', 'Colisión fronto-lateral', 21),
#  ('BARAJAS', 2021, 'septiembre', 'Alcance', 19),
#  ('BARAJAS', 2021, 'septiembre', 'Choque contra obstáculo fijo', 14),
#  ('BARAJAS', 2021, 'septiembre', 'Colisión lateral', 6),
#  ('BARAJAS', 2021, 'septiembre', 'Colisión múltiple', 6),
#  ('BARAJAS', 2021, 'septiembre', 'Atropello a persona', 5),
#  ('BARAJAS', 2021, 'septiembre', 'Colisión frontal', 2),
#  ('BARAJAS', 2021, 'septiembre', 'Caída', 1),
#  ('BARAJAS', 2021, 'septiembre', 'Atropello a animal', 1),
#  ('BARAJAS', 2022, 'abril', 'Colisión fronto-lateral', 40),
#  ('BARAJAS', 2022, 'abril', 'Choque contra obstáculo fijo', 17),
#  ('BARAJAS', 2022, 'abril', 'Alcance', 11),
#  ('BARAJAS', 2022, 'abril', 'Colisión frontal', 10),
#  ('BARAJAS', 2022, 'abril', 'Colisión lateral', 8),
#  ('BARAJAS', 2022, 'abril', 'Colisión múltiple', 3),
#  ('BARAJAS', 2022, 'abril', 'Solo salida de la vía', 2),
#  ('BARAJAS', 2022, 'abril', 'Caída', 1),
#  ('BARAJAS', 2022, 'agosto', 'Alcance', 20),
#  ('BARAJAS', 2022, 'agosto', 'Colisión fronto-lateral', 14),
#  ('BARAJAS', 2022, 'agosto', 'Colisión lateral', 9),
#  ('BARAJAS', 2022, 'agosto', 'Otro', 3),
#  ('BARAJAS', 2022, 'agosto', 'Atropello a persona', 2),
#  ('BARAJAS', 2022, 'agosto', 'Choque contra obstáculo fijo', 1),
#  ('BARAJAS', 2022, 'diciembre', 'Colisión fronto-lateral', 17),
#  ('BARAJAS', 2022, 'diciembre', 'Colisión lateral', 14),
#  ('BARAJAS', 2022, 'diciembre', 'Choque contra obstáculo fijo', 12),
#  ('BARAJAS', 2022, 'diciembre', 'Alcance', 11),
#  ('BARAJAS', 2022, 'diciembre', 'Caída', 4),
#  ('BARAJAS', 2022, 'diciembre', 'Colisión múltiple', 3),
#  ('BARAJAS', 2022, 'enero', 'Colisión lateral', 19),
#  ('BARAJAS', 2022, 'enero', 'Colisión fronto-lateral', 18),
#  ('BARAJAS', 2022, 'enero', 'Alcance', 10),
#  ('BARAJAS', 2022, 'enero', 'Choque contra obstáculo fijo', 7),
#  ('BARAJAS', 2022, 'enero', 'Atropello a persona', 6),
#  ('BARAJAS', 2022, 'enero', 'Caída', 6),
#  ('BARAJAS', 2022, 'enero', 'Colisión frontal', 3),
#  ('BARAJAS', 2022, 'enero', 'Otro', 1),
#  ('BARAJAS', 2022, 'enero', 'Vuelco', 1),
#  ('BARAJAS', 2022, 'febrero', 'Colisión fronto-lateral', 16),
#  ('BARAJAS', 2022, 'febrero', 'Colisión lateral', 15),
#  ('BARAJAS', 2022, 'febrero', 'Alcance', 8),
#  ('BARAJAS', 2022, 'febrero', 'Caída', 6),
#  ('BARAJAS', 2022, 'febrero', 'Colisión múltiple', 5),
#  ('BARAJAS', 2022, 'febrero', 'Atropello a persona', 4),
#  ('BARAJAS', 2022, 'febrero', 'Choque contra obstáculo fijo', 2),
#  ('BARAJAS', 2022, 'febrero', 'Vuelco', 1),
#  ('BARAJAS', 2022, 'julio', 'Alcance', 21),
#  ('BARAJAS', 2022, 'julio', 'Colisión fronto-lateral', 16),
#  ('BARAJAS', 2022, 'julio', 'Colisión lateral', 14),
#  ('BARAJAS', 2022, 'julio', 'Choque contra obstáculo fijo', 13),
#  ('BARAJAS', 2022, 'julio', 'Colisión múltiple', 4),
#  ('BARAJAS', 2022, 'julio', 'Atropello a persona', 3),
#  ('BARAJAS', 2022, 'julio', 'Caída', 3),
#  ('BARAJAS', 2022, 'julio', 'Otro', 2),
#  ('BARAJAS', 2022, 'junio', 'Alcance', 16),
#  ('BARAJAS', 2022, 'junio', 'Colisión fronto-lateral', 15),
#  ('BARAJAS', 2022, 'junio', 'Caída', 6),
#  ('BARAJAS', 2022, 'junio', 'Choque contra obstáculo fijo', 5),
#  ('BARAJAS', 2022, 'junio', 'Atropello a persona', 4),
#  ('BARAJAS', 2022, 'junio', 'Colisión lateral', 4),
#  ('BARAJAS', 2022, 'junio', 'Colisión múltiple', 4),
#  ('BARAJAS', 2022, 'junio', 'Otro', 1),
#  ('BARAJAS', 2022, 'marzo', 'Choque contra obstáculo fijo', 29),
#  ('BARAJAS', 2022, 'marzo', 'Colisión fronto-lateral', 17),
#  ('BARAJAS', 2022, 'marzo', 'Colisión lateral', 14),
#  ('BARAJAS', 2022, 'marzo', 'Alcance', 8),
#  ('BARAJAS', 2022, 'marzo', 'Caída', 3),
#  ('BARAJAS', 2022, 'mayo', 'Colisión lateral', 15),
#  ('BARAJAS', 2022, 'mayo', 'Colisión fronto-lateral', 14),
#  ('BARAJAS', 2022, 'mayo', 'Choque contra obstáculo fijo', 11),
#  ('BARAJAS', 2022, 'mayo', 'Colisión múltiple', 11),
#  ('BARAJAS', 2022, 'mayo', 'Alcance', 7),
#  ('BARAJAS', 2022, 'mayo', 'Caída', 7),
#  ('BARAJAS', 2022, 'mayo', 'Atropello a persona', 6),
#  ('BARAJAS', 2022, 'mayo', 'Colisión frontal', 2),
#  ('BARAJAS', 2022, 'mayo', 'Solo salida de la vía', 2),
#  ('BARAJAS', 2022, 'mayo', 'Atropello a animal', 1),
#  ('BARAJAS', 2022, 'mayo', 'Otro', 1),
#  ('BARAJAS', 2022, 'noviembre', 'Colisión fronto-lateral', 36),
#  ('BARAJAS', 2022, 'noviembre', 'Alcance', 21),
#  ('BARAJAS', 2022, 'noviembre', 'Colisión lateral', 12),
#  ('BARAJAS', 2022, 'noviembre', 'Choque contra obstáculo fijo', 9),
#  ('BARAJAS', 2022, 'noviembre', 'Atropello a persona', 4),
#  ('BARAJAS', 2022, 'noviembre', 'Colisión frontal', 2),
#  ('BARAJAS', 2022, 'noviembre', 'Atropello a animal', 1),
#  ('BARAJAS', 2022, 'noviembre', 'Caída', 1),
#  ('BARAJAS', 2022, 'octubre', 'Colisión fronto-lateral', 29),
#  ('BARAJAS', 2022, 'octubre', 'Choque contra obstáculo fijo', 21),
#  ('BARAJAS', 2022, 'octubre', 'Alcance', 12),
#  ('BARAJAS', 2022, 'octubre', 'Atropello a persona', 12),
#  ('BARAJAS', 2022, 'octubre', 'Colisión lateral', 8),
#  ('BARAJAS', 2022, 'octubre', 'Colisión múltiple', 4),
#  ('BARAJAS', 2022, 'octubre', 'Colisión frontal', 2),
#  ('BARAJAS', 2022, 'octubre', 'Caída', 1),
#  ('BARAJAS', 2022, 'octubre', 'Otro', 1),
#  ('BARAJAS', 2022, 'septiembre', 'Alcance', 18),
#  ('BARAJAS', 2022, 'septiembre', 'Colisión lateral', 15),
#  ('BARAJAS', 2022, 'septiembre', 'Colisión fronto-lateral', 14),
#  ('BARAJAS', 2022, 'septiembre', 'Choque contra obstáculo fijo', 7),
#  ('BARAJAS', 2022, 'septiembre', 'Otro', 3),
#  ('BARAJAS', 2022, 'septiembre', 'Colisión frontal', 2),
#  ('BARAJAS', 2022, 'septiembre', 'Solo salida de la vía', 2),
#  ('BARAJAS', 2023, 'abril', 'Colisión fronto-lateral', 19),
#  ('BARAJAS', 2023, 'abril', 'Colisión lateral', 13),
#  ('BARAJAS', 2023, 'abril', 'Alcance', 11),
#  ('BARAJAS', 2023, 'abril', 'Choque contra obstáculo fijo', 8),
#  ('BARAJAS', 2023, 'abril', 'Caída', 3),
#  ('BARAJAS', 2023, 'abril', 'Colisión frontal', 2),
#  ('BARAJAS', 2023, 'abril', 'Otro', 2),
#  ('BARAJAS', 2023, 'abril', 'Vuelco', 1),
#  ('BARAJAS', 2023, 'agosto', 'Colisión fronto-lateral', 18),
#  ('BARAJAS', 2023, 'agosto', 'Choque contra obstáculo fijo', 10),
#  ('BARAJAS', 2023, 'agosto', 'Colisión lateral', 8),
#  ('BARAJAS', 2023, 'agosto', 'Alcance', 7),
#  ('BARAJAS', 2023, 'agosto', 'Atropello a persona', 7),
#  ('BARAJAS', 2023, 'agosto', 'Colisión múltiple', 4),
#  ('BARAJAS', 2023, 'agosto', 'Solo salida de la vía', 3),
#  ('BARAJAS', 2023, 'agosto', 'Caída', 2),
#  ('BARAJAS', 2023, 'agosto', 'Colisión frontal', 2),
#  ('BARAJAS', 2023, 'diciembre', 'Choque contra obstáculo fijo', 5),
#  ('BARAJAS', 2023, 'diciembre', 'Colisión lateral', 5),
#  ('BARAJAS', 2023, 'diciembre', 'Colisión fronto-lateral', 2),
#  ('BARAJAS', 2023, 'diciembre', 'Caída', 1),
#  ('BARAJAS', 2023, 'enero', 'Colisión múltiple', 11),
#  ('BARAJAS', 2023, 'enero', 'Colisión lateral', 10),
#  ('BARAJAS', 2023, 'enero', 'Colisión fronto-lateral', 9),
#  ('BARAJAS', 2023, 'enero', 'Atropello a persona', 8),
#  ('BARAJAS', 2023, 'enero', 'Alcance', 7),
#  ('BARAJAS', 2023, 'enero', 'Colisión frontal', 5),
#  ('BARAJAS', 2023, 'enero', 'Caída', 3),
#  ('BARAJAS', 2023, 'enero', 'Choque contra obstáculo fijo', 3),
#  ('BARAJAS', 2023, 'enero', 'Otro', 1),
#  ('BARAJAS', 2023, 'febrero', 'Colisión fronto-lateral', 29),
#  ('BARAJAS', 2023, 'febrero', 'Alcance', 8),
#  ('BARAJAS', 2023, 'febrero', 'Colisión lateral', 6),
#  ('BARAJAS', 2023, 'febrero', 'Choque contra obstáculo fijo', 4),
#  ('BARAJAS', 2023, 'febrero', 'Caída', 2),
#  ('BARAJAS', 2023, 'febrero', 'Otro', 2),
#  ('BARAJAS', 2023, 'julio', 'Colisión fronto-lateral', 26),
#  ('BARAJAS', 2023, 'julio', 'Alcance', 14),
#  ('BARAJAS', 2023, 'julio', 'Colisión lateral', 9),
#  ('BARAJAS', 2023, 'julio', 'Caída', 6),
#  ('BARAJAS', 2023, 'julio', 'Colisión múltiple', 6),
#  ('BARAJAS', 2023, 'julio', 'Choque contra obstáculo fijo', 3),
#  ('BARAJAS', 2023, 'julio', 'Atropello a persona', 2),
#  ('BARAJAS', 2023, 'julio', 'Otro', 2),
#  ('BARAJAS', 2023, 'julio', 'Solo salida de la vía', 1),
#  ('BARAJAS', 2023, 'junio', 'Alcance', 19),
#  ('BARAJAS', 2023, 'junio', 'Colisión fronto-lateral', 18),
#  ('BARAJAS', 2023, 'junio', 'Choque contra obstáculo fijo', 14),
#  ('BARAJAS', 2023, 'junio', 'Colisión lateral', 14),
#  ('BARAJAS', 2023, 'junio', 'Colisión frontal', 6),
#  ('BARAJAS', 2023, 'junio', 'Caída', 3),
#  ('BARAJAS', 2023, 'junio', 'Atropello a persona', 2),
#  ('BARAJAS', 2023, 'junio', 'Solo salida de la vía', 1),
#  ('BARAJAS', 2023, 'junio', 'Vuelco', 1),
#  ('BARAJAS', 2023, 'marzo', 'Colisión fronto-lateral', 21),
#  ('BARAJAS', 2023, 'marzo', 'Choque contra obstáculo fijo', 14),
#  ('BARAJAS', 2023, 'marzo', 'Alcance', 11),
#  ('BARAJAS', 2023, 'marzo', 'Colisión lateral', 11),
#  ('BARAJAS', 2023, 'marzo', 'Atropello a persona', 4),
#  ('BARAJAS', 2023, 'marzo', 'Colisión múltiple', 4),
#  ('BARAJAS', 2023, 'marzo', 'Caída', 3),
#  ('BARAJAS', 2023, 'marzo', 'Colisión frontal', 3),
#  ('BARAJAS', 2023, 'mayo', 'Alcance', 16),
#  ('BARAJAS', 2023, 'mayo', 'Atropello a persona', 12),
#  ('BARAJAS', 2023, 'mayo', 'Colisión fronto-lateral', 10),
#  ('BARAJAS', 2023, 'mayo', 'Choque contra obstáculo fijo', 5),
#  ('BARAJAS', 2023, 'mayo', 'Colisión múltiple', 4),
#  ('BARAJAS', 2023, 'mayo', 'Colisión frontal', 3),
#  ('BARAJAS', 2023, 'mayo', 'Colisión lateral', 3),
#  ('BARAJAS', 2023, 'mayo', 'Caída', 2),
#  ('BARAJAS', 2023, 'mayo', 'Otro', 2),
#  ('BARAJAS', 2023, 'noviembre', 'Colisión fronto-lateral', 7),
#  ('BARAJAS', 2023, 'noviembre', 'Choque contra obstáculo fijo', 4),
#  ('BARAJAS', 2023, 'noviembre', 'Colisión lateral', 4),
#  ('BARAJAS', 2023, 'noviembre', 'Colisión múltiple', 4),
#  ('BARAJAS', 2023, 'noviembre', 'Atropello a persona', 2),
#  ('BARAJAS', 2023, 'octubre', 'Colisión fronto-lateral', 16),
#  ('BARAJAS', 2023, 'octubre', 'Choque contra obstáculo fijo', 3),
#  ('BARAJAS', 2023, 'octubre', 'Alcance', 2),
#  ('BARAJAS', 2023, 'octubre', 'Colisión lateral', 2),
#  ('BARAJAS', 2023, 'octubre', 'Solo salida de la vía', 1),
#  ('BARAJAS', 2023, 'septiembre', 'Choque contra obstáculo fijo', 7),
#  ('BARAJAS', 2023, 'septiembre', 'Alcance', 3),
#  ('BARAJAS', 2023, 'septiembre', 'Atropello a persona', 2),
#  ('BARAJAS', 2023, 'septiembre', 'Colisión fronto-lateral', 2),
#  ('BARAJAS', 2023, 'septiembre', 'Colisión lateral', 2),
#  ('CARABANCHEL', 2021, 'abril', 'Colisión fronto-lateral', 49),
#  ('CARABANCHEL', 2021, 'abril', 'Alcance', 40),
#  ('CARABANCHEL', 2021, 'abril', 'Choque contra obstáculo fijo', 34),
#  ('CARABANCHEL', 2021, 'abril', 'Colisión múltiple', 27),
#  ('CARABANCHEL', 2021, 'abril', 'Colisión lateral', 22),
#  ('CARABANCHEL', 2021, 'abril', 'Atropello a persona', 16),
#  ('CARABANCHEL', 2021, 'abril', 'Caída', 14),
#  ('CARABANCHEL', 2021, 'abril', 'Colisión frontal', 4),
#  ('CARABANCHEL', 2021, 'abril', 'Otro', 3),
#  ('CARABANCHEL', 2021, 'agosto', 'Alcance', 59),
#  ('CARABANCHEL', 2021, 'agosto', 'Choque contra obstáculo fijo', 46),
#  ('CARABANCHEL', 2021, 'agosto', 'Colisión fronto-lateral', 42),
#  ('CARABANCHEL', 2021, 'agosto', 'Colisión lateral', 25),
#  ('CARABANCHEL', 2021, 'agosto', 'Atropello a persona', 11),
#  ('CARABANCHEL', 2021, 'agosto', 'Caída', 10),
#  ('CARABANCHEL', 2021, 'agosto', 'Colisión múltiple', 9),
#  ('CARABANCHEL', 2021, 'agosto', 'Solo salida de la vía', 2),
#  ('CARABANCHEL', 2021, 'agosto', 'Otro', 1),
#  ('CARABANCHEL', 2021, 'diciembre', 'Colisión fronto-lateral', 49),
#  ('CARABANCHEL', 2021, 'diciembre', 'Choque contra obstáculo fijo', 44),
#  ('CARABANCHEL', 2021, 'diciembre', 'Colisión lateral', 31),
#  ('CARABANCHEL', 2021, 'diciembre', 'Alcance', 30),
#  ('CARABANCHEL', 2021, 'diciembre', 'Atropello a persona', 10),
#  ('CARABANCHEL', 2021, 'diciembre', 'Caída', 8),
#  ('CARABANCHEL', 2021, 'diciembre', 'Colisión frontal', 4),
#  ('CARABANCHEL', 2021, 'diciembre', 'Solo salida de la vía', 4),
#  ('CARABANCHEL', 2021, 'diciembre', 'Colisión múltiple', 3),
#  ('CARABANCHEL', 2021, 'diciembre', 'Otro', 2),
#  ('CARABANCHEL', 2021, 'diciembre', 'Atropello a animal', 1),
#  ('CARABANCHEL', 2021, 'diciembre', 'Vuelco', 1),
#  ('CARABANCHEL', 2021, 'enero', 'Alcance', 46),
#  ('CARABANCHEL', 2021, 'enero', 'Colisión lateral', 32),
#  ('CARABANCHEL', 2021, 'enero', 'Atropello a persona', 24),
#  ('CARABANCHEL', 2021, 'enero', 'Colisión fronto-lateral', 24),
#  ('CARABANCHEL', 2021, 'enero', 'Choque contra obstáculo fijo', 18),
#  ('CARABANCHEL', 2021, 'enero', 'Colisión múltiple', 12),
#  ('CARABANCHEL', 2021, 'enero', 'Colisión frontal', 5),
#  ('CARABANCHEL', 2021, 'enero', 'Caída', 4),
#  ('CARABANCHEL', 2021, 'enero', 'Otro', 4),
#  ('CARABANCHEL', 2021, 'enero', 'Vuelco', 3),
#  ('CARABANCHEL', 2021, 'febrero', 'Colisión fronto-lateral', 61),
#  ('CARABANCHEL', 2021, 'febrero', 'Alcance', 30),
#  ('CARABANCHEL', 2021, 'febrero', 'Choque contra obstáculo fijo', 28),
#  ('CARABANCHEL', 2021, 'febrero', 'Colisión lateral', 25),
#  ('CARABANCHEL', 2021, 'febrero', 'Colisión múltiple', 21),
#  ('CARABANCHEL', 2021, 'febrero', 'Atropello a persona', 16),
#  ('CARABANCHEL', 2021, 'febrero', 'Otro', 10),
#  ('CARABANCHEL', 2021, 'febrero', 'Caída', 8),
#  ('CARABANCHEL', 2021, 'julio', 'Alcance', 68),
#  ('CARABANCHEL', 2021, 'julio', 'Colisión fronto-lateral', 56),
#  ('CARABANCHEL', 2021, 'julio', 'Colisión lateral', 36),
#  ('CARABANCHEL', 2021, 'julio', 'Choque contra obstáculo fijo', 28),
#  ('CARABANCHEL', 2021, 'julio', 'Colisión múltiple', 16),
#  ('CARABANCHEL', 2021, 'julio', 'Caída', 13),
#  ('CARABANCHEL', 2021, 'julio', 'Atropello a persona', 12),
#  ('CARABANCHEL', 2021, 'julio', 'Otro', 3),
#  ('CARABANCHEL', 2021, 'julio', 'Vuelco', 3),
#  ('CARABANCHEL', 2021, 'julio', 'Colisión frontal', 2),
#  ('CARABANCHEL', 2021, 'julio', 'Solo salida de la vía', 1),
#  ('CARABANCHEL', 2021, 'junio', 'Colisión fronto-lateral', 66),
#  ('CARABANCHEL', 2021, 'junio', 'Alcance', 58),
#  ('CARABANCHEL', 2021, 'junio', 'Choque contra obstáculo fijo', 49),
#  ('CARABANCHEL', 2021, 'junio', 'Colisión lateral', 35),
#  ('CARABANCHEL', 2021, 'junio', 'Atropello a persona', 21),
#  ('CARABANCHEL', 2021, 'junio', 'Caída', 21),
#  ('CARABANCHEL', 2021, 'junio', 'Colisión múltiple', 14),
#  ('CARABANCHEL', 2021, 'junio', 'Colisión frontal', 13),
#  ('CARABANCHEL', 2021, 'junio', 'Otro', 2),
#  ('CARABANCHEL', 2021, 'marzo', 'Colisión fronto-lateral', 71),
#  ('CARABANCHEL', 2021, 'marzo', 'Alcance', 61),
#  ('CARABANCHEL', 2021, 'marzo', 'Choque contra obstáculo fijo', 27),
#  ('CARABANCHEL', 2021, 'marzo', 'Atropello a persona', 20),
#  ('CARABANCHEL', 2021, 'marzo', 'Caída', 19),
#  ('CARABANCHEL', 2021, 'marzo', 'Colisión lateral', 18),
#  ('CARABANCHEL', 2021, 'marzo', 'Colisión múltiple', 18),
#  ('CARABANCHEL', 2021, 'marzo', 'Colisión frontal', 11),
#  ('CARABANCHEL', 2021, 'mayo', 'Choque contra obstáculo fijo', 51),
#  ('CARABANCHEL', 2021, 'mayo', 'Colisión fronto-lateral', 47),
#  ('CARABANCHEL', 2021, 'mayo', 'Colisión lateral', 37),
#  ('CARABANCHEL', 2021, 'mayo', 'Alcance', 35),
#  ('CARABANCHEL', 2021, 'mayo', 'Atropello a persona', 13),
#  ('CARABANCHEL', 2021, 'mayo', 'Colisión frontal', 13),
#  ('CARABANCHEL', 2021, 'mayo', 'Colisión múltiple', 12),
#  ('CARABANCHEL', 2021, 'mayo', 'Caída', 8),
#  ('CARABANCHEL', 2021, 'mayo', 'Otro', 3),
#  ('CARABANCHEL', 2021, 'mayo', 'Solo salida de la vía', 1),
#  ('CARABANCHEL', 2021, 'noviembre', 'Alcance', 62),
#  ('CARABANCHEL', 2021, 'noviembre', 'Colisión fronto-lateral', 59),
#  ('CARABANCHEL', 2021, 'noviembre', 'Choque contra obstáculo fijo', 39),
#  ('CARABANCHEL', 2021, 'noviembre', 'Colisión múltiple', 30),
#  ('CARABANCHEL', 2021, 'noviembre', 'Caída', 22),
#  ('CARABANCHEL', 2021, 'noviembre', 'Colisión lateral', 22),
#  ('CARABANCHEL', 2021, 'noviembre', 'Atropello a persona', 13),
#  ('CARABANCHEL', 2021, 'noviembre', 'Otro', 7),
#  ('CARABANCHEL', 2021, 'noviembre', 'Colisión frontal', 6),
#  ('CARABANCHEL', 2021, 'octubre', 'Colisión fronto-lateral', 89),
#  ('CARABANCHEL', 2021, 'octubre', 'Alcance', 49),
#  ('CARABANCHEL', 2021, 'octubre', 'Colisión lateral', 46),
#  ('CARABANCHEL', 2021, 'octubre', 'Choque contra obstáculo fijo', 40),
#  ('CARABANCHEL', 2021, 'octubre', 'Colisión frontal', 15),
#  ('CARABANCHEL', 2021, 'octubre', 'Atropello a persona', 10),
#  ('CARABANCHEL', 2021, 'octubre', 'Caída', 8),
#  ('CARABANCHEL', 2021, 'octubre', 'Colisión múltiple', 6),
#  ('CARABANCHEL', 2021, 'septiembre', 'Colisión fronto-lateral', 72),
#  ('CARABANCHEL', 2021, 'septiembre', 'Alcance', 54),
#  ('CARABANCHEL', 2021, 'septiembre', 'Colisión lateral', 37),
#  ('CARABANCHEL', 2021, 'septiembre', 'Choque contra obstáculo fijo', 35),
#  ('CARABANCHEL', 2021, 'septiembre', 'Caída', 12),
#  ('CARABANCHEL', 2021, 'septiembre', 'Atropello a persona', 9),
#  ('CARABANCHEL', 2021, 'septiembre', 'Colisión frontal', 9),
#  ('CARABANCHEL', 2021, 'septiembre', 'Vuelco', 4),
#  ('CARABANCHEL', 2021, 'septiembre', 'Colisión múltiple', 3),
#  ('CARABANCHEL', 2021, 'septiembre', 'Atropello a animal', 1),
#  ('CARABANCHEL', 2022, 'abril', 'Alcance', 63),
#  ('CARABANCHEL', 2022, 'abril', 'Colisión fronto-lateral', 50),
#  ('CARABANCHEL', 2022, 'abril', 'Choque contra obstáculo fijo', 39),
#  ('CARABANCHEL', 2022, 'abril', 'Colisión lateral', 28),
#  ('CARABANCHEL', 2022, 'abril', 'Colisión múltiple', 25),
#  ('CARABANCHEL', 2022, 'abril', 'Atropello a persona', 22),
#  ('CARABANCHEL', 2022, 'abril', 'Caída', 16),
#  ('CARABANCHEL', 2022, 'abril', 'Colisión frontal', 14),
#  ('CARABANCHEL', 2022, 'abril', 'Otro', 5),
#  ('CARABANCHEL', 2022, 'agosto', 'Alcance', 48),
#  ('CARABANCHEL', 2022, 'agosto', 'Colisión fronto-lateral', 42),
#  ('CARABANCHEL', 2022, 'agosto', 'Colisión lateral', 29),
#  ('CARABANCHEL', 2022, 'agosto', 'Choque contra obstáculo fijo', 27),
#  ('CARABANCHEL', 2022, 'agosto', 'Atropello a persona', 18),
#  ('CARABANCHEL', 2022, 'agosto', 'Caída', 16),
#  ('CARABANCHEL', 2022, 'agosto', 'Colisión frontal', 4),
#  ('CARABANCHEL', 2022, 'agosto', 'Colisión múltiple', 4),
#  ('CARABANCHEL', 2022, 'agosto', 'Vuelco', 2),
#  ('CARABANCHEL', 2022, 'agosto', 'Otro', 1),
#  ('CARABANCHEL', 2022, 'diciembre', 'Colisión fronto-lateral', 49),
#  ('CARABANCHEL', 2022, 'diciembre', 'Alcance', 35),
#  ('CARABANCHEL', 2022, 'diciembre', 'Colisión lateral', 35),
#  ('CARABANCHEL', 2022, 'diciembre', 'Choque contra obstáculo fijo', 26),
#  ('CARABANCHEL', 2022, 'diciembre', 'Colisión múltiple', 25),
#  ('CARABANCHEL', 2022, 'diciembre', 'Atropello a persona', 17),
#  ('CARABANCHEL', 2022, 'diciembre', 'Otro', 15),
#  ('CARABANCHEL', 2022, 'diciembre', 'Colisión frontal', 12),
#  ('CARABANCHEL', 2022, 'diciembre', 'Caída', 12),
#  ('CARABANCHEL', 2022, 'diciembre', 'Atropello a animal', 2),
#  ('CARABANCHEL', 2022, 'enero', 'Colisión fronto-lateral', 79),
#  ('CARABANCHEL', 2022, 'enero', 'Alcance', 50),
#  ('CARABANCHEL', 2022, 'enero', 'Choque contra obstáculo fijo', 40),
#  ('CARABANCHEL', 2022, 'enero', 'Colisión lateral', 33),
#  ('CARABANCHEL', 2022, 'enero', 'Atropello a persona', 32),
#  ('CARABANCHEL', 2022, 'enero', 'Caída', 15),
#  ('CARABANCHEL', 2022, 'enero', 'Colisión múltiple', 14),
#  ('CARABANCHEL', 2022, 'enero', 'Colisión frontal', 6),
#  ('CARABANCHEL', 2022, 'enero', 'Otro', 2),
#  ('CARABANCHEL', 2022, 'enero', 'Atropello a animal', 1),
#  ('CARABANCHEL', 2022, 'febrero', 'Colisión fronto-lateral', 62),
#  ('CARABANCHEL', 2022, 'febrero', 'Choque contra obstáculo fijo', 37),
#  ('CARABANCHEL', 2022, 'febrero', 'Colisión lateral', 34),
#  ('CARABANCHEL', 2022, 'febrero', 'Alcance', 27),
#  ('CARABANCHEL', 2022, 'febrero', 'Colisión múltiple', 16),
#  ('CARABANCHEL', 2022, 'febrero', 'Caída', 14),
#  ('CARABANCHEL', 2022, 'febrero', 'Colisión frontal', 10),
#  ('CARABANCHEL', 2022, 'febrero', 'Atropello a persona', 4),
#  ('CARABANCHEL', 2022, 'febrero', 'Otro', 3),
#  ('CARABANCHEL', 2022, 'julio', 'Colisión fronto-lateral', 53),
#  ('CARABANCHEL', 2022, 'julio', 'Alcance', 47),
#  ('CARABANCHEL', 2022, 'julio', 'Colisión lateral', 27),
#  ('CARABANCHEL', 2022, 'julio', 'Choque contra obstáculo fijo', 22),
#  ('CARABANCHEL', 2022, 'julio', 'Atropello a persona', 20),
#  ('CARABANCHEL', 2022, 'julio', 'Caída', 17),
#  ('CARABANCHEL', 2022, 'julio', 'Colisión múltiple', 11),
#  ('CARABANCHEL', 2022, 'julio', 'Colisión frontal', 7),
#  ('CARABANCHEL', 2022, 'julio', 'Otro', 2),
#  ('CARABANCHEL', 2022, 'julio', 'Vuelco', 1),
#  ('CARABANCHEL', 2022, 'junio', 'Colisión fronto-lateral', 75),
#  ('CARABANCHEL', 2022, 'junio', 'Alcance', 43),
#  ('CARABANCHEL', 2022, 'junio', 'Choque contra obstáculo fijo', 42),
#  ('CARABANCHEL', 2022, 'junio', 'Colisión frontal', 19),
#  ('CARABANCHEL', 2022, 'junio', 'Colisión lateral', 18),
#  ('CARABANCHEL', 2022, 'junio', 'Atropello a persona', 13),
#  ('CARABANCHEL', 2022, 'junio', 'Caída', 12),
#  ('CARABANCHEL', 2022, 'junio', 'Colisión múltiple', 3),
#  ('CARABANCHEL', 2022, 'junio', 'Solo salida de la vía', 3),
#  ('CARABANCHEL', 2022, 'junio', 'Vuelco', 3),
#  ('CARABANCHEL', 2022, 'junio', 'Atropello a animal', 2),
#  ('CARABANCHEL', 2022, 'marzo', 'Colisión fronto-lateral', 60),
#  ('CARABANCHEL', 2022, 'marzo', 'Alcance', 55),
#  ('CARABANCHEL', 2022, 'marzo', 'Choque contra obstáculo fijo', 40),
#  ('CARABANCHEL', 2022, 'marzo', 'Colisión lateral', 32),
#  ('CARABANCHEL', 2022, 'marzo', 'Atropello a persona', 23),
#  ('CARABANCHEL', 2022, 'marzo', 'Caída', 19),
#  ('CARABANCHEL', 2022, 'marzo', 'Colisión múltiple', 15),
#  ('CARABANCHEL', 2022, 'marzo', 'Colisión frontal', 2),
#  ('CARABANCHEL', 2022, 'marzo', 'Otro', 1),
#  ('CARABANCHEL', 2022, 'mayo', 'Colisión fronto-lateral', 76),
#  ('CARABANCHEL', 2022, 'mayo', 'Choque contra obstáculo fijo', 51),
#  ('CARABANCHEL', 2022, 'mayo', 'Alcance', 46),
#  ('CARABANCHEL', 2022, 'mayo', 'Colisión lateral', 40),
#  ('CARABANCHEL', 2022, 'mayo', 'Atropello a persona', 34),
#  ('CARABANCHEL', 2022, 'mayo', 'Colisión frontal', 8),
#  ('CARABANCHEL', 2022, 'mayo', 'Caída', 6),
#  ('CARABANCHEL', 2022, 'mayo', 'Colisión múltiple', 6),
#  ('CARABANCHEL', 2022, 'mayo', 'Otro', 4),
#  ('CARABANCHEL', 2022, 'mayo', 'Atropello a animal', 2),
#  ('CARABANCHEL', 2022, 'mayo', 'Vuelco', 1),
#  ('CARABANCHEL', 2022, 'noviembre', 'Alcance', 63),
#  ('CARABANCHEL', 2022, 'noviembre', 'Colisión fronto-lateral', 54),
#  ('CARABANCHEL', 2022, 'noviembre', 'Choque contra obstáculo fijo', 43),
#  ('CARABANCHEL', 2022, 'noviembre', 'Colisión lateral', 20),
#  ('CARABANCHEL', 2022, 'noviembre', 'Atropello a persona', 18),
#  ('CARABANCHEL', 2022, 'noviembre', 'Caída', 16),
#  ('CARABANCHEL', 2022, 'noviembre', 'Colisión múltiple', 16),
#  ('CARABANCHEL', 2022, 'noviembre', 'Otro', 6),
#  ('CARABANCHEL', 2022, 'noviembre', 'Colisión frontal', 4),
#  ('CARABANCHEL', 2022, 'noviembre', 'Solo salida de la vía', 1),
#  ('CARABANCHEL', 2022, 'octubre', 'Colisión fronto-lateral', 88),
#  ('CARABANCHEL', 2022, 'octubre', 'Alcance', 63),
#  ('CARABANCHEL', 2022, 'octubre', 'Colisión lateral', 37),
#  ('CARABANCHEL', 2022, 'octubre', 'Atropello a persona', 33),
#  ('CARABANCHEL', 2022, 'octubre', 'Choque contra obstáculo fijo', 31),
#  ('CARABANCHEL', 2022, 'octubre', 'Colisión múltiple', 23),
#  ('CARABANCHEL', 2022, 'octubre', 'Caída', 21),
#  ('CARABANCHEL', 2022, 'octubre', 'Colisión frontal', 4),
#  ('CARABANCHEL', 2022, 'octubre', 'Otro', 2),
#  ('CARABANCHEL', 2022, 'septiembre', 'Alcance', 44),
#  ('CARABANCHEL', 2022, 'septiembre', 'Colisión fronto-lateral', 41),
#  ('CARABANCHEL', 2022, 'septiembre', 'Colisión lateral', 34),
#  ('CARABANCHEL', 2022, 'septiembre', 'Choque contra obstáculo fijo', 27),
#  ('CARABANCHEL', 2022, 'septiembre', 'Atropello a persona', 24),
#  ('CARABANCHEL', 2022, 'septiembre', 'Colisión múltiple', 14),
#  ('CARABANCHEL', 2022, 'septiembre', 'Caída', 11),
#  ('CARABANCHEL', 2022, 'septiembre', 'Colisión frontal', 7),
#  ('CARABANCHEL', 2022, 'septiembre', 'Otro', 1),
#  ('CARABANCHEL', 2022, 'septiembre', 'Solo salida de la vía', 1),
#  ('CARABANCHEL', 2022, 'septiembre', 'Vuelco', 1),
#  ('CARABANCHEL', 2023, 'abril', 'Colisión fronto-lateral', 70),
#  ('CARABANCHEL', 2023, 'abril', 'Alcance', 57),
#  ('CARABANCHEL', 2023, 'abril', 'Colisión lateral', 36),
#  ('CARABANCHEL', 2023, 'abril', 'Choque contra obstáculo fijo', 33),
#  ('CARABANCHEL', 2023, 'abril', 'Colisión múltiple', 18),
#  ('CARABANCHEL', 2023, 'abril', 'Colisión frontal', 10),
#  ('CARABANCHEL', 2023, 'abril', 'Atropello a persona', 6),
#  ('CARABANCHEL', 2023, 'abril', 'Caída', 6),
#  ('CARABANCHEL', 2023, 'abril', 'Atropello a animal', 1),
#  ('CARABANCHEL', 2023, 'agosto', 'Colisión fronto-lateral', 43),
#  ('CARABANCHEL', 2023, 'agosto', 'Alcance', 40),
#  ('CARABANCHEL', 2023, 'agosto', 'Choque contra obstáculo fijo', 32),
#  ('CARABANCHEL', 2023, 'agosto', 'Colisión lateral', 29),
#  ('CARABANCHEL', 2023, 'agosto', 'Colisión múltiple', 20),
#  ('CARABANCHEL', 2023, 'agosto', 'Caída', 10),
#  ('CARABANCHEL', 2023, 'agosto', 'Atropello a animal', 2),
#  ('CARABANCHEL', 2023, 'agosto', 'Atropello a persona', 2),
#  ('CARABANCHEL', 2023, 'agosto', 'Colisión frontal', 2),
#  ('CARABANCHEL', 2023, 'agosto', 'Otro', 2),
#  ('CARABANCHEL', 2023, 'agosto', 'Vuelco', 2),
#  ('CARABANCHEL', 2023, 'diciembre', 'Colisión fronto-lateral', 14),
#  ('CARABANCHEL', 2023, 'diciembre', 'Alcance', 12),
#  ('CARABANCHEL', 2023, 'diciembre', 'Choque contra obstáculo fijo', 7),
#  ('CARABANCHEL', 2023, 'diciembre', 'Colisión múltiple', 5),
#  ('CARABANCHEL', 2023, 'diciembre', 'Colisión lateral', 4),
#  ('CARABANCHEL', 2023, 'diciembre', 'Vuelco', 4),
#  ('CARABANCHEL', 2023, 'diciembre', 'Caída', 3),
#  ('CARABANCHEL', 2023, 'enero', 'Alcance', 67),
#  ('CARABANCHEL', 2023, 'enero', 'Colisión fronto-lateral', 61),
#  ('CARABANCHEL', 2023, 'enero', 'Colisión múltiple', 39),
#  ('CARABANCHEL', 2023, 'enero', 'Colisión lateral', 32),
#  ('CARABANCHEL', 2023, 'enero', 'Choque contra obstáculo fijo', 15),
#  ('CARABANCHEL', 2023, 'enero', 'Atropello a persona', 13),
#  ('CARABANCHEL', 2023, 'enero', 'Caída', 10),
#  ('CARABANCHEL', 2023, 'enero', 'Colisión frontal', 9),
#  ('CARABANCHEL', 2023, 'enero', 'Otro', 3),
#  ('CARABANCHEL', 2023, 'enero', 'Atropello a animal', 2),
#  ('CARABANCHEL', 2023, 'febrero', 'Alcance', 56),
#  ('CARABANCHEL', 2023, 'febrero', 'Colisión fronto-lateral', 49),
#  ('CARABANCHEL', 2023, 'febrero', 'Colisión lateral', 42),
#  ('CARABANCHEL', 2023, 'febrero', 'Choque contra obstáculo fijo', 36),
#  ('CARABANCHEL', 2023, 'febrero', 'Caída', 17),
#  ('CARABANCHEL', 2023, 'febrero', 'Colisión múltiple', 11),
#  ('CARABANCHEL', 2023, 'febrero', 'Atropello a persona', 9),
#  ('CARABANCHEL', 2023, 'febrero', 'Colisión frontal', 4),
#  ('CARABANCHEL', 2023, 'febrero', 'Solo salida de la vía', 1),
#  ('CARABANCHEL', 2023, 'julio', 'Colisión fronto-lateral', 62),
#  ('CARABANCHEL', 2023, 'julio', 'Colisión lateral', 47),
#  ('CARABANCHEL', 2023, 'julio', 'Alcance', 33),
#  ('CARABANCHEL', 2023, 'julio', 'Choque contra obstáculo fijo', 18),
#  ('CARABANCHEL', 2023, 'julio', 'Caída', 15),
#  ('CARABANCHEL', 2023, 'julio', 'Atropello a persona', 10),
#  ('CARABANCHEL', 2023, 'julio', 'Otro', 9),
#  ('CARABANCHEL', 2023, 'julio', 'Colisión múltiple', 7),
#  ('CARABANCHEL', 2023, 'julio', 'Colisión frontal', 2),
#  ('CARABANCHEL', 2023, 'junio', 'Alcance', 63),
#  ('CARABANCHEL', 2023, 'junio', 'Colisión fronto-lateral', 47),
#  ('CARABANCHEL', 2023, 'junio', 'Colisión lateral', 35),
#  ('CARABANCHEL', 2023, 'junio', 'Choque contra obstáculo fijo', 29),
#  ('CARABANCHEL', 2023, 'junio', 'Atropello a persona', 16),
#  ('CARABANCHEL', 2023, 'junio', 'Colisión frontal', 11),
#  ('CARABANCHEL', 2023, 'junio', 'Caída', 10),
#  ('CARABANCHEL', 2023, 'junio', 'Colisión múltiple', 4),
#  ('CARABANCHEL', 2023, 'junio', 'Otro', 2),
#  ('CARABANCHEL', 2023, 'marzo', 'Colisión fronto-lateral', 80),
#  ('CARABANCHEL', 2023, 'marzo', 'Colisión lateral', 46),
#  ('CARABANCHEL', 2023, 'marzo', 'Alcance', 44),
#  ('CARABANCHEL', 2023, 'marzo', 'Atropello a persona', 26),
#  ('CARABANCHEL', 2023, 'marzo', 'Choque contra obstáculo fijo', 26),
#  ('CARABANCHEL', 2023, 'marzo', 'Colisión múltiple', 17),
#  ('CARABANCHEL', 2023, 'marzo', 'Caída', 16),
#  ('CARABANCHEL', 2023, 'marzo', 'Otro', 4),
#  ('CARABANCHEL', 2023, 'marzo', 'Colisión frontal', 2),
#  ('CARABANCHEL', 2023, 'mayo', 'Alcance', 79),
#  ('CARABANCHEL', 2023, 'mayo', 'Colisión fronto-lateral', 55),
#  ('CARABANCHEL', 2023, 'mayo', 'Choque contra obstáculo fijo', 38),
#  ('CARABANCHEL', 2023, 'mayo', 'Colisión lateral', 35),
#  ('CARABANCHEL', 2023, 'mayo', 'Atropello a persona', 19),
#  ('CARABANCHEL', 2023, 'mayo', 'Caída', 17),
#  ('CARABANCHEL', 2023, 'mayo', 'Colisión múltiple', 13),
#  ('CARABANCHEL', 2023, 'mayo', 'Colisión frontal', 12),
#  ('CARABANCHEL', 2023, 'mayo', 'Otro', 5),
#  ('CARABANCHEL', 2023, 'mayo', 'Atropello a animal', 1),
#  ('CARABANCHEL', 2023, 'noviembre', 'Colisión fronto-lateral', 25),
#  ('CARABANCHEL', 2023, 'noviembre', 'Colisión lateral', 10),
#  ('CARABANCHEL', 2023, 'noviembre', 'Alcance', 8),
#  ('CARABANCHEL', 2023, 'noviembre', 'Caída', 8),
#  ('CARABANCHEL', 2023, 'noviembre', 'Choque contra obstáculo fijo', 8),
#  ('CARABANCHEL', 2023, 'noviembre', 'Colisión múltiple', 6),
#  ('CARABANCHEL', 2023, 'noviembre', 'Otro', 3),
#  ('CARABANCHEL', 2023, 'noviembre', 'Atropello a persona', 2),
#  ('CARABANCHEL', 2023, 'noviembre', 'Colisión frontal', 2),
#  ('CARABANCHEL', 2023, 'octubre', 'Alcance', 35),
#  ('CARABANCHEL', 2023, 'octubre', 'Colisión fronto-lateral', 28),
#  ('CARABANCHEL', 2023, 'octubre', 'Colisión lateral', 18),
#  ('CARABANCHEL', 2023, 'octubre', 'Choque contra obstáculo fijo', 6),
#  ('CARABANCHEL', 2023, 'octubre', 'Atropello a persona', 4),
#  ('CARABANCHEL', 2023, 'octubre', 'Colisión frontal', 4),
#  ('CARABANCHEL', 2023, 'octubre', 'Caída', 3),
#  ('CARABANCHEL', 2023, 'octubre', 'Colisión múltiple', 3),
#  ('CARABANCHEL', 2023, 'septiembre', 'Colisión fronto-lateral', 23),
#  ('CARABANCHEL', 2023, 'septiembre', 'Alcance', 18),
#  ('CARABANCHEL', 2023, 'septiembre', 'Choque contra obstáculo fijo', 17),
#  ('CARABANCHEL', 2023, 'septiembre', 'Atropello a persona', 14),
#  ('CARABANCHEL', 2023, 'septiembre', 'Colisión lateral', 12),
#  ('CARABANCHEL', 2023, 'septiembre', 'Caída', 6),
#  ('CARABANCHEL', 2023, 'septiembre', 'Colisión múltiple', 4),
#  ('CARABANCHEL', 2023, 'septiembre', 'Vuelco', 1),
#  ('CENTRO', 2021, 'abril', 'Choque contra obstáculo fijo', 34),
#  ('CENTRO', 2021, 'abril', 'Colisión lateral', 33),
#  ('CENTRO', 2021, 'abril', 'Alcance', 32),
#  ('CENTRO', 2021, 'abril', 'Caída', 27),
#  ('CENTRO', 2021, 'abril', 'Colisión fronto-lateral', 25),
#  ('CENTRO', 2021, 'abril', 'Atropello a persona', 10),
#  ('CENTRO', 2021, 'abril', 'Colisión múltiple', 7),
#  ('CENTRO', 2021, 'abril', 'Colisión frontal', 4),
#  ('CENTRO', 2021, 'agosto', 'Atropello a persona', 23),
#  ('CENTRO', 2021, 'agosto', 'Colisión fronto-lateral', 23),
#  ('CENTRO', 2021, 'agosto', 'Alcance', 22),
#  ('CENTRO', 2021, 'agosto', 'Caída', 22),
#  ('CENTRO', 2021, 'agosto', 'Colisión lateral', 18),
#  ('CENTRO', 2021, 'agosto', 'Choque contra obstáculo fijo', 17),
#  ('CENTRO', 2021, 'agosto', 'Colisión múltiple', 8),
#  ('CENTRO', 2021, 'agosto', 'Colisión frontal', 2),
#  ('CENTRO', 2021, 'agosto', 'Otro', 1),
#  ('CENTRO', 2021, 'agosto', 'Solo salida de la vía', 1),
#  ('CENTRO', 2021, 'diciembre', 'Colisión fronto-lateral', 46),
#  ('CENTRO', 2021, 'diciembre', 'Colisión lateral', 35),
#  ('CENTRO', 2021, 'diciembre', 'Alcance', 28),
#  ('CENTRO', 2021, 'diciembre', 'Choque contra obstáculo fijo', 19),
#  ('CENTRO', 2021, 'diciembre', 'Caída', 17),
#  ('CENTRO', 2021, 'diciembre', 'Atropello a persona', 12),
#  ('CENTRO', 2021, 'diciembre', 'Otro', 6),
#  ('CENTRO', 2021, 'diciembre', 'Vuelco', 4),
#  ('CENTRO', 2021, 'diciembre', 'Solo salida de la vía', 1),
#  ('CENTRO', 2021, 'enero', 'Colisión lateral', 24),
#  ('CENTRO', 2021, 'enero', 'Atropello a persona', 20),
#  ('CENTRO', 2021, 'enero', 'Colisión fronto-lateral', 18),
#  ('CENTRO', 2021, 'enero', 'Alcance', 17),
#  ('CENTRO', 2021, 'enero', 'Choque contra obstáculo fijo', 17),
#  ('CENTRO', 2021, 'enero', 'Caída', 10),
#  ('CENTRO', 2021, 'enero', 'Colisión frontal', 4),
#  ('CENTRO', 2021, 'enero', 'Otro', 1),
#  ('CENTRO', 2021, 'febrero', 'Colisión lateral', 36),
#  ('CENTRO', 2021, 'febrero', 'Colisión fronto-lateral', 34),
#  ('CENTRO', 2021, 'febrero', 'Caída', 22),
#  ('CENTRO', 2021, 'febrero', 'Alcance', 20),
#  ('CENTRO', 2021, 'febrero', 'Choque contra obstáculo fijo', 17),
#  ('CENTRO', 2021, 'febrero', 'Atropello a persona', 13),
#  ('CENTRO', 2021, 'febrero', 'Colisión múltiple', 3),
#  ('CENTRO', 2021, 'febrero', 'Colisión frontal', 2),
#  ('CENTRO', 2021, 'febrero', 'Otro', 2),
#  ('CENTRO', 2021, 'febrero', 'Solo salida de la vía', 2),
#  ('CENTRO', 2021, 'julio', 'Colisión lateral', 56),
#  ('CENTRO', 2021, 'julio', 'Alcance', 40),
#  ('CENTRO', 2021, 'julio', 'Colisión fronto-lateral', 33),
#  ('CENTRO', 2021, 'julio', 'Caída', 29),
#  ('CENTRO', 2021, 'julio', 'Atropello a persona', 16),
#  ('CENTRO', 2021, 'julio', 'Choque contra obstáculo fijo', 12),
#  ('CENTRO', 2021, 'julio', 'Colisión múltiple', 7),
#  ('CENTRO', 2021, 'julio', 'Colisión frontal', 2),
#  ('CENTRO', 2021, 'julio', 'Otro', 1),
#  ('CENTRO', 2021, 'junio', 'Colisión lateral', 45),
#  ('CENTRO', 2021, 'junio', 'Choque contra obstáculo fijo', 34),
#  ('CENTRO', 2021, 'junio', 'Caída', 31),
#  ('CENTRO', 2021, 'junio', 'Alcance', 26),
#  ('CENTRO', 2021, 'junio', 'Colisión fronto-lateral', 21),
#  ('CENTRO', 2021, 'junio', 'Atropello a persona', 16),
#  ('CENTRO', 2021, 'junio', 'Colisión múltiple', 8),
#  ('CENTRO', 2021, 'junio', 'Colisión frontal', 5),
#  ('CENTRO', 2021, 'marzo', 'Colisión fronto-lateral', 42),
#  ('CENTRO', 2021, 'marzo', 'Colisión lateral', 36),
#  ('CENTRO', 2021, 'marzo', 'Choque contra obstáculo fijo', 23),
#  ('CENTRO', 2021, 'marzo', 'Caída', 22),
#  ('CENTRO', 2021, 'marzo', 'Alcance', 20),
#  ('CENTRO', 2021, 'marzo', 'Atropello a persona', 13),
#  ('CENTRO', 2021, 'marzo', 'Otro', 2),
#  ...)

# %% [markdown]
# ##### Correlación entre Condiciones Meteorológicas y Accidentes

# %%
sql='SELECT estado_meteorológico, COUNT(*) AS total_accidentes FROM accidentes_de_trafico GROUP BY estado_meteorológico ORDER BY total_accidentes DESC;'
cur.execute(sql)
cur.fetchall()
# Out:
# (('Despejado', 102175),
#  ('Nublado', 7811),
#  ('Lluvia débil', 6929),
#  ('LLuvia intensa', 1782),
#  ('Se desconoce', 1038),
#  ('Nevando', 237),
#  ('Granizando', 22))

# %% [markdown]
# ##### Análisis de la Demografía de las Personas Involucradas en Accidentes

# %%
query = """
SELECT p.sexo, p.rango_edad, COUNT(*) AS total_personas, l.descripcion AS lesividad
FROM personas p
JOIN lesividad l ON p.cod_lesividad = l.cod_lesividad
GROUP BY p.sexo, p.rango_edad, l.descripcion
ORDER BY total_personas DESC;
"""

cur.execute(query)
cur.fetchall()
# Out:
# (('Hombre', 'De 40 a 44 años', 10044, 'Sin asistencia sanitaria'),
#  ('Hombre', 'De 45 a 49 años', 9928, 'Sin asistencia sanitaria'),
#  ('Hombre', 'De 35 a 39 años', 8984, 'Sin asistencia sanitaria'),
#  ('Hombre', 'De 50 a 54 años', 8980, 'Sin asistencia sanitaria'),
#  ('Hombre', 'De 30 a 34 años', 8882, 'Sin asistencia sanitaria'),
#  ('Hombre', 'De 25 a 29 años', 8686, 'Sin asistencia sanitaria'),
#  ('Hombre', 'De 55 a 59 años', 7200, 'Sin asistencia sanitaria'),
#  ('Hombre', 'De 21 a 24 años', 5902, 'Sin asistencia sanitaria'),
#  ('Mujer', 'De 30 a 34 años', 5286, 'Sin asistencia sanitaria'),
#  ('Mujer', 'De 25 a 29 años', 5084, 'Sin asistencia sanitaria'),
#  ('Hombre', 'De 60 a 64 años', 5048, 'Sin asistencia sanitaria'),
#  ('Mujer', 'De 35 a 39 años', 4970, 'Sin asistencia sanitaria'),
#  ('Mujer', 'De 45 a 49 años', 4656, 'Sin asistencia sanitaria'),
#  ('Mujer', 'De 40 a 44 años', 4612, 'Sin asistencia sanitaria'),
#  ('Hombre',
#   'De 25 a 29 años',
#   4426,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre',
#   'De 30 a 34 años',
#   4170,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre',
#   'De 35 a 39 años',
#   3770,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre',
#   'De 40 a 44 años',
#   3738,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre',
#   'De 45 a 49 años',
#   3668,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer', 'De 50 a 54 años', 3320, 'Sin asistencia sanitaria'),
#  ('Mujer', 'De 21 a 24 años', 3136, 'Sin asistencia sanitaria'),
#  ('Hombre', 'De 18 a 20 años', 2882, 'Sin asistencia sanitaria'),
#  ('Hombre',
#   'De 50 a 54 años',
#   2822,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer',
#   'De 30 a 34 años',
#   2780,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre',
#   'De 21 a 24 años',
#   2724,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer',
#   'De 25 a 29 años',
#   2688,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer',
#   'De 35 a 39 años',
#   2458,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre',
#   'De 55 a 59 años',
#   2454,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer', 'De 55 a 59 años', 2434, 'Sin asistencia sanitaria'),
#  ('Hombre', 'De 65 a 69 años', 2242, 'Sin asistencia sanitaria'),
#  ('Mujer',
#   'De 45 a 49 años',
#   2074,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer',
#   'De 40 a 44 años',
#   2068,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre', 'De 70 a 74 años', 1860, 'Sin asistencia sanitaria'),
#  ('Mujer', 'De 60 a 64 años', 1782, 'Sin asistencia sanitaria'),
#  ('Mujer', 'De 70 a 74 años', 1734, 'Sin asistencia sanitaria'),
#  ('Mujer', 'De 10 a 14 años', 1674, 'Sin asistencia sanitaria'),
#  ('Mujer', 'Menor de 5 años', 1652, 'Sin asistencia sanitaria'),
#  ('Hombre', 'Más de 74 años', 1632, 'Sin asistencia sanitaria'),
#  ('Mujer', 'De 18 a 20 años', 1622, 'Sin asistencia sanitaria'),
#  ('Mujer',
#   'De 21 a 24 años',
#   1526,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre',
#   'De 60 a 64 años',
#   1472,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre', 'De 30 a 34 años', 1438, 'Ingreso inferior o igual a 24 horas'),
#  ('Mujer',
#   'De 50 a 54 años',
#   1420,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre', 'De 25 a 29 años', 1404, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'De 18 a 20 años',
#   1292,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer', 'De 65 a 69 años', 1292, 'Sin asistencia sanitaria'),
#  ('Mujer',
#   'De 55 a 59 años',
#   1278,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre', 'De 40 a 44 años', 1234, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre', 'De 35 a 39 años', 1158, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre', 'Menor de 5 años', 1142, 'Sin asistencia sanitaria'),
#  ('Mujer', 'De 15 a 17 años', 1140, 'Sin asistencia sanitaria'),
#  ('Hombre',
#   'De 25 a 29 años',
#   1102,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre', 'De 10 a 14 años', 1088, 'Sin asistencia sanitaria'),
#  ('Hombre', 'De 45 a 49 años', 1074, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre', 'De 50 a 54 años', 1018, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'De 30 a 34 años',
#   970,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre',
#   'De 35 a 39 años',
#   910,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre',
#   'De 40 a 44 años',
#   896,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer',
#   'De 60 a 64 años',
#   870,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre', 'De 15 a 17 años', 856, 'Sin asistencia sanitaria'),
#  ('Mujer',
#   'De 10 a 14 años',
#   852,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre',
#   'De 45 a 49 años',
#   836,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer',
#   'De 18 a 20 años',
#   818,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer', 'Más de 74 años', 816, 'Sin asistencia sanitaria'),
#  ('Mujer',
#   'Menor de 5 años',
#   784,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre', 'De 55 a 59 años', 778, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'De 25 a 29 años',
#   776,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre',
#   'De 35 a 39 años',
#   772,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer', 'De 30 a 34 años', 772, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'De 50 a 54 años',
#   762,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer', 'De 25 a 29 años', 740, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre', 'De 21 a 24 años', 738, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'De 45 a 49 años',
#   716,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre',
#   'De 30 a 34 años',
#   714,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre',
#   'De 40 a 44 años',
#   708,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer',
#   'De 70 a 74 años',
#   700,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre',
#   'De 21 a 24 años',
#   698,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre',
#   'De 65 a 69 años',
#   694,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer', 'De 35 a 39 años', 676, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'De 70 a 74 años',
#   668,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer',
#   'De 25 a 29 años',
#   654,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre',
#   'Más de 74 años',
#   642,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre',
#   'De 10 a 14 años',
#   638,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer',
#   'De 30 a 34 años',
#   606,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre',
#   'Menor de 5 años',
#   602,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre',
#   'De 55 a 59 años',
#   588,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer',
#   'Más de 74 años',
#   588,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer',
#   'De 65 a 69 años',
#   586,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre',
#   'De 50 a 54 años',
#   572,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer', 'De 45 a 49 años', 540, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre', 'De 60 a 64 años', 530, 'Ingreso inferior o igual a 24 horas'),
#  ('Mujer', 'De 40 a 44 años', 530, 'Ingreso inferior o igual a 24 horas'),
#  ('Mujer',
#   'De 15 a 17 años',
#   512,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer',
#   'De 35 a 39 años',
#   512,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer',
#   'De 30 a 34 años',
#   484,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre',
#   'De 15 a 17 años',
#   480,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer',
#   'De 45 a 49 años',
#   466,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre',
#   'De 21 a 24 años',
#   464,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre',
#   'De 55 a 59 años',
#   456,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer', 'De 21 a 24 años', 448, 'Ingreso inferior o igual a 24 horas'),
#  ('Mujer',
#   'De 40 a 44 años',
#   442,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer', 'De 6 a 9 años', 436, 'Sin asistencia sanitaria'),
#  ('Mujer',
#   'De 25 a 29 años',
#   432,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre', 'De 30 a 34 años', 424, 'Ingreso superior a 24 horas'),
#  ('Hombre', 'De 25 a 29 años', 422, 'Ingreso superior a 24 horas'),
#  ('Mujer',
#   'De 21 a 24 años',
#   418,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre', 'De 6 a 9 años', 412, 'Sin asistencia sanitaria'),
#  ('Hombre', 'De 40 a 44 años', 408, 'Ingreso superior a 24 horas'),
#  ('Hombre', 'De 18 a 20 años', 402, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'De 30 a 34 años',
#   398,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer', 'De 50 a 54 años', 398, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre', 'De 45 a 49 años', 394, 'Ingreso superior a 24 horas'),
#  ('Mujer',
#   'De 35 a 39 años',
#   394,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre', 'De 35 a 39 años', 388, 'Ingreso superior a 24 horas'),
#  ('Hombre',
#   'De 25 a 29 años',
#   384,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Hombre',
#   'De 40 a 44 años',
#   384,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer',
#   'De 40 a 44 años',
#   380,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre',
#   'De 45 a 49 años',
#   378,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer',
#   'De 50 a 54 años',
#   374,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre',
#   'De 35 a 39 años',
#   362,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer',
#   'De 45 a 49 años',
#   338,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer', 'De 55 a 59 años', 338, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'De 60 a 64 años',
#   334,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre',
#   'De 18 a 20 años',
#   324,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre',
#   'De 6 a 9 años',
#   316,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Mujer',
#   'De 6 a 9 años',
#   304,
#   'Asistencia sanitaria sólo en el lugar del accidente'),
#  ('Hombre', 'De 50 a 54 años', 302, 'Ingreso superior a 24 horas'),
#  ('Hombre',
#   'De 60 a 64 años',
#   294,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre', 'Más de 74 años', 294, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'De 50 a 54 años',
#   288,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer', 'Más de 74 años', 282, 'Ingreso inferior o igual a 24 horas'),
#  ('Mujer',
#   'De 21 a 24 años',
#   274,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre', 'De 65 a 69 años', 270, 'Ingreso inferior o igual a 24 horas'),
#  ('Mujer',
#   'De 50 a 54 años',
#   270,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre', 'De 21 a 24 años', 268, 'Ingreso superior a 24 horas'),
#  ('Hombre', 'De 55 a 59 años', 264, 'Ingreso superior a 24 horas'),
#  ('Mujer',
#   'De 55 a 59 años',
#   254,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre',
#   'De 21 a 24 años',
#   238,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Hombre',
#   'De 55 a 59 años',
#   238,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer',
#   'De 30 a 34 años',
#   238,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer',
#   'De 25 a 29 años',
#   236,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer', 'De 10 a 14 años', 234, 'Ingreso inferior o igual a 24 horas'),
#  ('Mujer', 'Menor de 5 años', 228, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'De 18 a 20 años',
#   226,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer', 'De 70 a 74 años', 224, 'Ingreso inferior o igual a 24 horas'),
#  ('Mujer', 'De 30 a 34 años', 222, 'Ingreso superior a 24 horas'),
#  ('Mujer',
#   'De 70 a 74 años',
#   212,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer',
#   'De 55 a 59 años',
#   206,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer',
#   'De 35 a 39 años',
#   202,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer', 'De 60 a 64 años', 202, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'De 70 a 74 años',
#   190,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer', 'De 25 a 29 años', 182, 'Ingreso superior a 24 horas'),
#  ('Mujer', 'De 45 a 49 años', 182, 'Ingreso superior a 24 horas'),
#  ('Mujer',
#   'De 60 a 64 años',
#   182,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre', 'De 70 a 74 años', 180, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre', 'De 60 a 64 años', 178, 'Ingreso superior a 24 horas'),
#  ('Mujer',
#   'De 40 a 44 años',
#   178,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer', 'De 18 a 20 años', 172, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'De 65 a 69 años',
#   170,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer', 'De 65 a 69 años', 170, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'De 60 a 64 años',
#   168,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Hombre',
#   'De 15 a 17 años',
#   164,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer',
#   'De 18 a 20 años',
#   162,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre', 'De 10 a 14 años', 160, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'Más de 74 años',
#   160,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer', 'De 15 a 17 años', 160, 'Ingreso inferior o igual a 24 horas'),
#  ('Mujer',
#   'De 45 a 49 años',
#   160,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer',
#   'Más de 74 años',
#   160,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer',
#   'Menor de 5 años',
#   160,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer',
#   'De 10 a 14 años',
#   156,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer', 'De 35 a 39 años', 156, 'Ingreso superior a 24 horas'),
#  ('Mujer', 'Más de 74 años', 150, 'Ingreso superior a 24 horas'),
#  ('Hombre', 'De 15 a 17 años', 146, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre', 'Menor de 5 años', 146, 'Ingreso inferior o igual a 24 horas'),
#  ('Mujer',
#   'De 65 a 69 años',
#   144,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Hombre',
#   'Menor de 5 años',
#   140,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer',
#   'De 15 a 17 años',
#   136,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer',
#   'De 60 a 64 años',
#   136,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer',
#   'De 70 a 74 años',
#   136,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer',
#   'Más de 74 años',
#   136,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer',
#   'De 21 a 24 años',
#   134,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer', 'De 40 a 44 años', 126, 'Ingreso superior a 24 horas'),
#  ('Mujer',
#   'Menor de 5 años',
#   126,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre',
#   'Más de 74 años',
#   124,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer', 'De 55 a 59 años', 124, 'Ingreso superior a 24 horas'),
#  ('Mujer',
#   'De 10 a 14 años',
#   120,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer',
#   'De 50 a 54 años',
#   120,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer', 'De 70 a 74 años', 120, 'Ingreso superior a 24 horas'),
#  ('Hombre',
#   'De 18 a 20 años',
#   116,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer',
#   'De 18 a 20 años',
#   116,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre',
#   'De 10 a 14 años',
#   114,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer',
#   'De 15 a 17 años',
#   114,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre', 'De 18 a 20 años', 110, 'Ingreso superior a 24 horas'),
#  ('Hombre', 'Más de 74 años', 110, 'Ingreso superior a 24 horas'),
#  ('Mujer', 'De 50 a 54 años', 106, 'Ingreso superior a 24 horas'),
#  ('Hombre',
#   'De 65 a 69 años',
#   104,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre',
#   'De 70 a 74 años',
#   102,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer', 'De 21 a 24 años', 100, 'Ingreso superior a 24 horas'),
#  ('Mujer',
#   'De 65 a 69 años',
#   98,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre', 'De 65 a 69 años', 96, 'Ingreso superior a 24 horas'),
#  ('Mujer',
#   'De 55 a 59 años',
#   96,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer',
#   'De 70 a 74 años',
#   92,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer',
#   'De 60 a 64 años',
#   88,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Hombre',
#   'Menor de 5 años',
#   80,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer',
#   'De 18 a 20 años',
#   80,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer', 'De 60 a 64 años', 78, 'Ingreso superior a 24 horas'),
#  ('Mujer', 'Menor de 5 años', 78, 'Ingreso superior a 24 horas'),
#  ('Hombre',
#   'De 70 a 74 años',
#   76,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Hombre',
#   'Más de 74 años',
#   76,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer',
#   'Más de 74 años',
#   76,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Hombre',
#   'De 10 a 14 años',
#   74,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer', 'De 10 a 14 años', 70, 'Ingreso superior a 24 horas'),
#  ('Hombre',
#   'De 65 a 69 años',
#   68,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Hombre',
#   'De 15 a 17 años',
#   64,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Mujer', 'De 18 a 20 años', 64, 'Ingreso superior a 24 horas'),
#  ('Hombre', 'De 70 a 74 años', 62, 'Ingreso superior a 24 horas'),
#  ('Mujer',
#   'De 10 a 14 años',
#   62,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer', 'De 65 a 69 años', 62, 'Ingreso superior a 24 horas'),
#  ('Mujer',
#   'Menor de 5 años',
#   58,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer',
#   'De 15 a 17 años',
#   52,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Hombre', 'De 6 a 9 años', 50, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'Menor de 5 años',
#   50,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Hombre', 'De 10 a 14 años', 48, 'Ingreso superior a 24 horas'),
#  ('Hombre', 'De 15 a 17 años', 48, 'Ingreso superior a 24 horas'),
#  ('Mujer', 'De 6 a 9 años', 46, 'Ingreso inferior o igual a 24 horas'),
#  ('Hombre',
#   'De 15 a 17 años',
#   44,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Hombre', 'Menor de 5 años', 44, 'Ingreso superior a 24 horas'),
#  ('Hombre',
#   'De 6 a 9 años',
#   42,
#   'Atención en urgencias sin posterior ingreso'),
#  ('Mujer', 'De 15 a 17 años', 42, 'Ingreso superior a 24 horas'),
#  ('Mujer',
#   'De 65 a 69 años',
#   42,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer', 'De 6 a 9 años', 40, 'Atención en urgencias sin posterior ingreso'),
#  ('Hombre', 'De 6 a 9 años', 38, 'Ingreso superior a 24 horas'),
#  ('Hombre',
#   'De 10 a 14 años',
#   32,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer',
#   'De 6 a 9 años',
#   32,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre',
#   'De 6 a 9 años',
#   28,
#   'Asistencia sanitaria inmediata en centro de salud o mutua'),
#  ('Hombre', 'De 25 a 29 años', 26, 'Fallecido 24 horas'),
#  ('Hombre', 'De 35 a 39 años', 20, 'Fallecido 24 horas'),
#  ('Mujer',
#   'De 6 a 9 años',
#   20,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Hombre', 'De 45 a 49 años', 18, 'Fallecido 24 horas'),
#  ('Hombre', 'De 60 a 64 años', 16, 'Fallecido 24 horas'),
#  ('Hombre', 'Más de 74 años', 16, 'Fallecido 24 horas'),
#  ('Hombre',
#   'De 6 a 9 años',
#   14,
#   'Asistencia sanitaria ambulatoria con posterioridad'),
#  ('Mujer', 'De 30 a 34 años', 14, 'Fallecido 24 horas'),
#  ('Mujer', 'Más de 74 años', 14, 'Fallecido 24 horas'),
#  ('Hombre', 'De 30 a 34 años', 12, 'Fallecido 24 horas'),
#  ('Hombre', 'De 50 a 54 años', 12, 'Fallecido 24 horas'),
#  ('Hombre', 'De 40 a 44 años', 10, 'Fallecido 24 horas'),
#  ('Hombre', 'De 55 a 59 años', 10, 'Fallecido 24 horas'),
#  ('Hombre', 'De 70 a 74 años', 10, 'Fallecido 24 horas'),
#  ('Mujer', 'De 45 a 49 años', 10, 'Fallecido 24 horas'),
#  ('Hombre', 'De 21 a 24 años', 8, 'Fallecido 24 horas'),
#  ('Hombre', 'De 65 a 69 años', 8, 'Fallecido 24 horas'),
#  ('Mujer', 'De 65 a 69 años', 6, 'Fallecido 24 horas'),
#  ('Hombre', 'Menor de 5 años', 4, 'Fallecido 24 horas'),
#  ('Mujer', 'De 21 a 24 años', 4, 'Fallecido 24 horas'),
#  ('Mujer', 'De 25 a 29 años', 4, 'Fallecido 24 horas'),
#  ('Mujer', 'De 35 a 39 años', 4, 'Fallecido 24 horas'),
#  ('Mujer', 'De 55 a 59 años', 4, 'Fallecido 24 horas'),
#  ('Mujer', 'De 6 a 9 años', 4, 'Ingreso superior a 24 horas'),
#  ('Mujer', 'Menor de 5 años', 4, 'Fallecido 24 horas'),
#  ('Hombre', 'De 10 a 14 años', 2, 'Fallecido 24 horas'),
#  ('Hombre', 'De 18 a 20 años', 2, 'Fallecido 24 horas'),
#  ('Mujer', 'De 10 a 14 años', 2, 'Fallecido 24 horas'),
#  ('Mujer', 'De 18 a 20 años', 2, 'Fallecido 24 horas'),
#  ('Mujer', 'De 40 a 44 años', 2, 'Fallecido 24 horas'),
#  ('Mujer', 'De 50 a 54 años', 2, 'Fallecido 24 horas'),
#  ('Mujer', 'De 60 a 64 años', 2, 'Fallecido 24 horas'),
#  ('Mujer', 'De 70 a 74 años', 2, 'Fallecido 24 horas'))

# %% [markdown]
# ##### Análisis Temporal de Accidentes por Hora del Día y Estado Meteorológico

# %%
query="""SELECT 
  EXTRACT(HOUR FROM hora) AS hora_del_dia, 
  estado_meteorológico, 
  COUNT(*) AS total_accidentes
FROM 
  accidentes_de_trafico
GROUP BY 
  hora_del_dia, estado_meteorológico
ORDER BY 
  total_accidentes DESC;
"""

cur.execute(query)
cur.fetchall()
# Out:
# ((14, 'Despejado', 7188),
#  (18, 'Despejado', 7031),
#  (19, 'Despejado', 6881),
#  (17, 'Despejado', 6736),
#  (15, 'Despejado', 6722),
#  (20, 'Despejado', 6440),
#  (16, 'Despejado', 6151),
#  (13, 'Despejado', 5758),
#  (21, 'Despejado', 5298),
#  (12, 'Despejado', 5186),
#  (9, 'Despejado', 4915),
#  (11, 'Despejado', 4428),
#  (10, 'Despejado', 4342),
#  (22, 'Despejado', 4055),
#  (8, 'Despejado', 4047),
#  (23, 'Despejado', 3492),
#  (7, 'Despejado', 2537),
#  (0, 'Despejado', 2491),
#  (1, 'Despejado', 1957),
#  (6, 'Despejado', 1682),
#  (2, 'Despejado', 1507),
#  (3, 'Despejado', 1192),
#  (5, 'Despejado', 1144),
#  (4, 'Despejado', 995),
#  (19, 'Lluvia débil', 637),
#  (20, 'Nublado', 594),
#  (19, 'Nublado', 584),
#  (18, 'Nublado', 567),
#  (20, 'Lluvia débil', 560),
#  (17, 'Nublado', 534),
#  (16, 'Nublado', 521),
#  (21, 'Lluvia débil', 470),
#  (15, 'Nublado', 461),
#  (14, 'Nublado', 460),
#  (17, 'Lluvia débil', 459),
#  (18, 'Lluvia débil', 459),
#  (21, 'Nublado', 449),
#  (12, 'Nublado', 433),
#  (8, 'Nublado', 425),
#  (9, 'Nublado', 420),
#  (13, 'Nublado', 412),
#  (14, 'Lluvia débil', 385),
#  (11, 'Nublado', 377),
#  (22, 'Lluvia débil', 365),
#  (10, 'Nublado', 361),
#  (15, 'Lluvia débil', 352),
#  (16, 'Lluvia débil', 327),
#  (8, 'Lluvia débil', 318),
#  (23, 'Lluvia débil', 294),
#  (9, 'Lluvia débil', 290),
#  (22, 'Nublado', 279),
#  (12, 'Lluvia débil', 257),
#  (13, 'Lluvia débil', 253),
#  (10, 'Lluvia débil', 244),
#  (11, 'Lluvia débil', 222),
#  (7, 'Nublado', 221),
#  (7, 'Lluvia débil', 197),
#  (6, 'Lluvia débil', 171),
#  (18, 'LLuvia intensa', 167),
#  (23, 'Nublado', 166),
#  (21, 'LLuvia intensa', 164),
#  (0, 'Lluvia débil', 163),
#  (1, 'Lluvia débil', 159),
#  (20, 'LLuvia intensa', 157),
#  (19, 'LLuvia intensa', 143),
#  (0, 'Nublado', 124),
#  (2, 'Lluvia débil', 123),
#  (6, 'Nublado', 118),
#  (23, 'LLuvia intensa', 116),
#  (16, 'LLuvia intensa', 112),
#  (17, 'LLuvia intensa', 107),
#  (22, 'LLuvia intensa', 98),
#  (13, 'LLuvia intensa', 89),
#  (1, 'Nublado', 86),
#  (18, 'Se desconoce', 82),
#  (15, 'LLuvia intensa', 80),
#  (4, 'Lluvia débil', 79),
#  (14, 'LLuvia intensa', 77),
#  (5, 'Lluvia débil', 76),
#  (20, 'Se desconoce', 75),
#  (3, 'Lluvia débil', 69),
#  (8, 'Se desconoce', 64),
#  (19, 'Se desconoce', 64),
#  (17, 'Se desconoce', 64),
#  (5, 'Nublado', 62),
#  (2, 'Nublado', 62),
#  (22, 'Se desconoce', 58),
#  (0, 'LLuvia intensa', 55),
#  (15, 'Se desconoce', 55),
#  (8, 'LLuvia intensa', 54),
#  (7, 'LLuvia intensa', 54),
#  (11, 'LLuvia intensa', 52),
#  (4, 'Nublado', 51),
#  (16, 'Se desconoce', 47),
#  (21, 'Se desconoce', 45),
#  (0, 'Se desconoce', 44),
#  (3, 'Nublado', 44),
#  (23, 'Se desconoce', 44),
#  (14, 'Se desconoce', 44),
#  (12, 'LLuvia intensa', 42),
#  (10, 'Se desconoce', 41),
#  (7, 'Se desconoce', 40),
#  (6, 'LLuvia intensa', 39),
#  (9, 'LLuvia intensa', 39),
#  (6, 'Se desconoce', 39),
#  (9, 'Se desconoce', 38),
#  (13, 'Se desconoce', 38),
#  (12, 'Se desconoce', 33),
#  (1, 'Se desconoce', 31),
#  (13, 'Nevando', 31),
#  (18, 'Nevando', 31),
#  (10, 'LLuvia intensa', 29),
#  (16, 'Nevando', 27),
#  (2, 'Se desconoce', 26),
#  (3, 'LLuvia intensa', 25),
#  (1, 'LLuvia intensa', 25),
#  (11, 'Se desconoce', 25),
#  (4, 'LLuvia intensa', 24),
#  (14, 'Nevando', 24),
#  (17, 'Nevando', 24),
#  (5, 'Se desconoce', 22),
#  (2, 'LLuvia intensa', 22),
#  (15, 'Nevando', 20),
#  (21, 'Nevando', 16),
#  (12, 'Nevando', 13),
#  (5, 'LLuvia intensa', 12),
#  (11, 'Nevando', 11),
#  (20, 'Nevando', 11),
#  (4, 'Se desconoce', 10),
#  (3, 'Se desconoce', 9),
#  (19, 'Nevando', 6),
#  (0, 'Nevando', 5),
#  (20, 'Granizando', 5),
#  (18, 'Granizando', 5),
#  (22, 'Nevando', 4),
#  (4, 'Nevando', 3),
#  (3, 'Granizando', 3),
#  (7, 'Nevando', 3),
#  (21, 'Granizando', 3),
#  (23, 'Nevando', 3),
#  (8, 'Nevando', 2),
#  (12, 'Granizando', 2),
#  (17, 'Granizando', 2),
#  (2, 'Nevando', 1),
#  (5, 'Nevando', 1),
#  (10, 'Nevando', 1),
#  (15, 'Granizando', 1),
#  (16, 'Granizando', 1))

# %% [markdown]
# ##### Diferencia de Accidentes Antes y Después de la Implementación de Medidas de Seguridad

# %%
query="""SELECT 
  IF(fecha < '2023-01-01', 'Antes', 'Después') AS Periodo,
  COUNT(*) AS TotalAccidentes
FROM 
  accidentes_de_trafico
GROUP BY 
  Periodo;

"""

cur.execute(query)
cur.fetchall()
# Out:
# (('Antes', 88836), ('Después', 31158))

# %% [markdown]
# ##### Accidentes Cercanos a Centros Educativos en Días de Alto Aforo

# %%
query="""WITH HighTrafficDays AS (
    SELECT 
        fecha,
        SUM(hor1 + hor2 + hor3 + hor4 + hor5 + hor6 + hor7 + hor8 + hor9 + hor10 + hor11 + hor12) AS total_traffic
    FROM 
        aforo_trafico
    GROUP BY 
        fecha
    HAVING 
        total_traffic > (SELECT AVG(total_traffic) * 1.5 FROM (
            SELECT 
                fecha, 
                SUM(hor1 + hor2 + hor3 + hor4 + hor5 + hor6 + hor7 + hor8 + hor9 + hor10 + hor11 + hor12) AS total_traffic
            FROM 
                aforo_trafico
            GROUP BY 
                fecha
         ) AS AverageTraffic)
),
AccidentsNearSchools AS (
    SELECT 
        ad.fecha, 
        ad.nombre_distrito, 
        COUNT(ad.id_accidente) AS num_accidents
    FROM 
        accidentes_de_trafico ad
    INNER JOIN 
        centros_educativos ce ON ad.nombre_distrito = ce.nombre_distrito
    WHERE 
        EXISTS (SELECT 1 FROM HighTrafficDays htd WHERE htd.fecha = ad.fecha)
    GROUP BY 
        ad.fecha, ad.nombre_distrito
)
SELECT 
    ans.fecha, 
    ans.nombre_distrito, 
    ans.num_accidents
FROM 
    AccidentsNearSchools ans
ORDER BY 
    ans.num_accidents DESC;



"""

cur.execute(query)
cur.fetchall()
# Out:
# ((datetime.date(2022, 2, 18), 'MONCLOA-ARAVACA', 760),
#  (datetime.date(2022, 2, 18), 'FUENCARRAL-EL PARDO', 675),
#  (datetime.date(2023, 2, 18), 'FUENCARRAL-EL PARDO', 675),
#  (datetime.date(2022, 2, 18), 'PUENTE DE VALLECAS', 504),
#  (datetime.date(2023, 1, 18), 'FUENCARRAL-EL PARDO', 450),
#  (datetime.date(2022, 2, 18), 'LATINA', 375),
#  (datetime.date(2023, 2, 18), 'CENTRO', 324),
#  (datetime.date(2023, 1, 18), 'MONCLOA-ARAVACA', 304),
#  (datetime.date(2022, 2, 18), 'CHAMBERÍ', 297),
#  (datetime.date(2023, 2, 18), 'CARABANCHEL', 252),
#  (datetime.date(2022, 2, 18), 'HORTALEZA', 231),
#  (datetime.date(2022, 1, 18), 'MONCLOA-ARAVACA', 228),
#  (datetime.date(2022, 1, 18), 'FUENCARRAL-EL PARDO', 225),
#  (datetime.date(2022, 1, 18), 'LATINA', 225),
#  (datetime.date(2022, 2, 18), 'SALAMANCA', 224),
#  (datetime.date(2023, 2, 18), 'PUENTE DE VALLECAS', 224),
#  (datetime.date(2023, 1, 18), 'CIUDAD LINEAL', 224),
#  (datetime.date(2023, 1, 18), 'CENTRO', 216),
#  (datetime.date(2022, 2, 18), 'SAN BLAS-CANILLEJAS', 189),
#  (datetime.date(2022, 2, 18), 'CENTRO', 189),
#  (datetime.date(2023, 2, 18), 'CHAMBERÍ', 189),
#  (datetime.date(2022, 2, 18), 'VILLAVERDE', 175),
#  (datetime.date(2023, 1, 18), 'PUENTE DE VALLECAS', 168),
#  (datetime.date(2023, 2, 18), 'MONCLOA-ARAVACA', 152),
#  (datetime.date(2022, 1, 18), 'CARABANCHEL', 147),
#  (datetime.date(2023, 1, 18), 'CHAMARTÍN', 144),
#  (datetime.date(2023, 2, 18), 'CHAMARTÍN', 144),
#  (datetime.date(2022, 1, 18), 'SALAMANCA', 144),
#  (datetime.date(2022, 2, 18), 'USERA', 140),
#  (datetime.date(2023, 1, 18), 'SALAMANCA', 136),
#  (datetime.date(2023, 2, 18), 'RETIRO', 132),
#  (datetime.date(2022, 1, 18), 'CHAMARTÍN', 128),
#  (datetime.date(2022, 1, 18), 'SAN BLAS-CANILLEJAS', 126),
#  (datetime.date(2023, 2, 18), 'LATINA', 125),
#  (datetime.date(2022, 1, 18), 'CHAMBERÍ', 108),
#  (datetime.date(2022, 2, 18), 'CARABANCHEL', 105),
#  (datetime.date(2022, 1, 18), 'VILLAVERDE', 100),
#  (datetime.date(2022, 2, 18), 'RETIRO', 99),
#  (datetime.date(2022, 2, 18), 'TETUÁN', 88),
#  (datetime.date(2023, 1, 18), 'CARABANCHEL', 84),
#  (datetime.date(2022, 1, 18), 'HORTALEZA', 84),
#  (datetime.date(2023, 2, 18), 'SAN BLAS-CANILLEJAS', 84),
#  (datetime.date(2023, 1, 18), 'HORTALEZA', 84),
#  (datetime.date(2023, 1, 18), 'CHAMBERÍ', 81),
#  (datetime.date(2022, 1, 18), 'CIUDAD LINEAL', 80),
#  (datetime.date(2023, 1, 18), 'LATINA', 75),
#  (datetime.date(2022, 2, 18), 'ARGANZUELA', 70),
#  (datetime.date(2023, 1, 18), 'VILLA DE VALLECAS', 70),
#  (datetime.date(2022, 1, 18), 'USERA', 70),
#  (datetime.date(2022, 2, 18), 'CIUDAD LINEAL', 64),
#  (datetime.date(2023, 2, 18), 'HORTALEZA', 63),
#  (datetime.date(2022, 2, 18), 'MORATALAZ', 60),
#  (datetime.date(2022, 1, 18), 'PUENTE DE VALLECAS', 56),
#  (datetime.date(2023, 1, 18), 'ARGANZUELA', 56),
#  (datetime.date(2023, 1, 18), 'RETIRO', 55),
#  (datetime.date(2023, 1, 18), 'TETUÁN', 55),
#  (datetime.date(2023, 1, 18), 'VILLAVERDE', 50),
#  (datetime.date(2023, 2, 18), 'MORATALAZ', 45),
#  (datetime.date(2022, 1, 18), 'TETUÁN', 44),
#  (datetime.date(2023, 1, 18), 'SAN BLAS-CANILLEJAS', 42),
#  (datetime.date(2023, 2, 18), 'SALAMANCA', 32),
#  (datetime.date(2022, 1, 18), 'MORATALAZ', 30),
#  (datetime.date(2023, 1, 18), 'MORATALAZ', 30),
#  (datetime.date(2023, 2, 18), 'ARGANZUELA', 28),
#  (datetime.date(2023, 2, 18), 'VILLA DE VALLECAS', 28),
#  (datetime.date(2022, 1, 18), 'CENTRO', 27),
#  (datetime.date(2022, 1, 18), 'BARAJAS', 24),
#  (datetime.date(2022, 1, 18), 'RETIRO', 22),
#  (datetime.date(2023, 2, 18), 'TETUÁN', 22),
#  (datetime.date(2023, 2, 18), 'USERA', 14),
#  (datetime.date(2022, 1, 18), 'VILLA DE VALLECAS', 14),
#  (datetime.date(2023, 1, 18), 'USERA', 14))

# %% [markdown]
# ##### Accidentes por Tipo con Mayor Prevalencia de Alcohol o Drogas

# %%
query="""SELECT 
    tipo_accidente,
    ROUND(
        (SUM(CASE WHEN positiva_alcohol = 'S' OR positiva_droga = 'S' THEN 1 ELSE 0 END) / COUNT(*)) * 100, 2
    ) AS porcentaje_positivos
FROM 
    accidentes_de_trafico
GROUP BY 
    tipo_accidente
ORDER BY 
    porcentaje_positivos DESC;


"""

cur.execute(query)
cur.fetchall()
# Out:
# (('Choque contra obstaculo', Decimal('50.00')),
#  ('Solo salida de la vía', Decimal('14.68')),
#  ('Vuelco', Decimal('12.63')),
#  ('Despeñamiento', Decimal('10.00')),
#  ('Choque contra obstáculo fijo', Decimal('9.97')),
#  ('Colisión frontal', Decimal('3.65')),
#  ('Caída', Decimal('3.23')),
#  ('Alcance', Decimal('2.70')),
#  ('Atropello a persona', Decimal('2.06')),
#  ('Colisión fronto-lateral', Decimal('1.84')),
#  ('Otro', Decimal('1.83')),
#  ('Colisión múltiple', Decimal('1.81')),
#  ('Colisión lateral', Decimal('1.81')),
#  ('Atropello a animal', Decimal('0.43')))

# %% [markdown]
# ##### Análisis de Congestión de Tráfico Cerca de Centros Educativos

# %%
query="""WITH SchoolsByDistrict AS (
    SELECT 
        nombre_distrito,
        COUNT(pk) AS schools_count
    FROM 
        centros_educativos
    GROUP BY 
        nombre_distrito
),
AccidentsByDistrict AS (
    SELECT 
        nombre_distrito,
        COUNT(id_accidente) AS accident_count
    FROM 
        accidentes_de_trafico
    GROUP BY 
        nombre_distrito
)
SELECT 
    sbd.nombre_distrito,
    abd.accident_count,
    sbd.schools_count
FROM 
    SchoolsByDistrict sbd
JOIN 
    AccidentsByDistrict abd ON sbd.nombre_distrito = abd.nombre_distrito
ORDER BY 
    abd.accident_count DESC, sbd.schools_count DESC
LIMIT 10;


"""

cur.execute(query)
cur.fetchall()
# Out:
# (('PUENTE DE VALLECAS', 9514, 28),
#  ('SALAMANCA', 8602, 8),
#  ('CHAMARTÍN', 8153, 16),
#  ('CIUDAD LINEAL', 8077, 16),
#  ('CARABANCHEL', 7751, 21),
#  ('CENTRO', 6646, 27),
#  ('MONCLOA-ARAVACA', 6416, 76),
#  ('FUENCARRAL-EL PARDO', 6407, 45),
#  ('SAN BLAS-CANILLEJAS', 6121, 21),
#  ('RETIRO', 6057, 11))

# %% [markdown]
# ##### Días de Semana con Mayor Incidencia de Accidentes Cerca de Centros Educativos

# %%
query="""SELECT 
    DAYNAME(ad.fecha) AS dia_semana, 
    COUNT(*) AS total_accidentes
FROM 
    accidentes_de_trafico ad
JOIN 
    centros_educativos ce ON ad.nombre_distrito = ce.nombre_distrito
GROUP BY 
    dia_semana
ORDER BY 
    total_accidentes DESC;




"""

cur.execute(query)
cur.fetchall()
# Out:
# (('Friday', 422408),
#  ('Tuesday', 406966),
#  ('Thursday', 401171),
#  ('Saturday', 386896),
#  ('Wednesday', 376560),
#  ('Monday', 374473),
#  ('Sunday', 348094))

# %% [markdown]
# ##### Correlación entre la Proximidad de Radares y la Reducción de Accidentes Graves

# %%
query="""WITH AccidentSeverity AS (
    SELECT 
        ad.nombre_distrito, 
        COUNT(*) AS total_accidentes,
        SUM(CASE WHEN tipo_accidente IN ('Colisión múltiple', 'Atropello a persona','Despeñamiento','Vuelco') THEN 1 ELSE 0 END) AS serious_accidents
    FROM 
        accidentes_de_trafico ad
    GROUP BY 
        ad.nombre_distrito
),
SchoolsByDistrict AS (
    SELECT 
        nombre_distrito,
        COUNT(pk) AS schools_count
    FROM 
        centros_educativos
    GROUP BY 
        nombre_distrito
)
SELECT 
    asv.nombre_distrito, 
    asv.total_accidentes,
    asv.serious_accidents,
    COALESCE(sbd.schools_count, 0) AS schools_count
FROM 
    AccidentSeverity asv
LEFT JOIN 
    SchoolsByDistrict sbd ON asv.nombre_distrito = sbd.nombre_distrito
ORDER BY 
    serious_accidents DESC, total_accidentes DESC
LIMIT 10;

"""

cur.execute(query)
cur.fetchall()
# Out:
# (('PUENTE DE VALLECAS', 9514, Decimal('1449'), 28),
#  ('CIUDAD LINEAL', 8077, Decimal('1344'), 16),
#  ('CARABANCHEL', 7751, Decimal('1070'), 21),
#  ('RETIRO', 6057, Decimal('1054'), 11),
#  ('SALAMANCA', 8602, Decimal('1021'), 8),
#  ('CENTRO', 6646, Decimal('997'), 27),
#  ('MONCLOA-ARAVACA', 6416, Decimal('962'), 76),
#  ('LATINA', 5789, Decimal('935'), 25),
#  ('CHAMARTÍN', 8153, Decimal('879'), 16),
#  ('ARGANZUELA', 5454, Decimal('875'), 14))

# %% [markdown]
# ##### Tendencias de Accidentes por Condiciones Meteorológicas a lo Largo del Tiempo

# %%
query="""SELECT 
    YEAR(fecha) AS año,
    MONTH(fecha) AS mes,
    estado_meteorológico,
    COUNT(*) AS total_accidentes
FROM 
    accidentes_de_trafico
GROUP BY 
    año, mes, estado_meteorológico
ORDER BY 
    año, mes, total_accidentes DESC;

"""

cur.execute(query)
cur.fetchall()
# Out:
# ((2021, 1, 'Despejado', 1940),
#  (2021, 1, 'Nublado', 314),
#  (2021, 1, 'Lluvia débil', 288),
#  (2021, 1, 'Se desconoce', 57),
#  (2021, 1, 'LLuvia intensa', 44),
#  (2021, 1, 'Nevando', 38),
#  (2021, 2, 'Despejado', 2579),
#  (2021, 2, 'Nublado', 145),
#  (2021, 2, 'Lluvia débil', 72),
#  (2021, 2, 'Se desconoce', 32),
#  (2021, 2, 'LLuvia intensa', 29),
#  (2021, 3, 'Despejado', 3292),
#  (2021, 3, 'Lluvia débil', 90),
#  (2021, 3, 'Nublado', 86),
#  (2021, 3, 'Se desconoce', 68),
#  (2021, 3, 'LLuvia intensa', 14),
#  (2021, 4, 'Despejado', 2473),
#  (2021, 4, 'Nublado', 312),
#  (2021, 4, 'Lluvia débil', 304),
#  (2021, 4, 'LLuvia intensa', 94),
#  (2021, 4, 'Se desconoce', 33),
#  (2021, 5, 'Despejado', 3455),
#  (2021, 5, 'Lluvia débil', 83),
#  (2021, 5, 'Nublado', 78),
#  (2021, 5, 'LLuvia intensa', 40),
#  (2021, 5, 'Se desconoce', 25),
#  (2021, 5, 'Granizando', 2),
#  (2021, 6, 'Despejado', 3264),
#  (2021, 6, 'Nublado', 228),
#  (2021, 6, 'Lluvia débil', 171),
#  (2021, 6, 'LLuvia intensa', 40),
#  (2021, 6, 'Se desconoce', 33),
#  (2021, 6, 'Granizando', 6),
#  (2021, 7, 'Despejado', 3024),
#  (2021, 7, 'Nublado', 101),
#  (2021, 7, 'Lluvia débil', 86),
#  (2021, 7, 'Nevando', 43),
#  (2021, 7, 'Se desconoce', 33),
#  (2021, 7, 'LLuvia intensa', 20),
#  (2021, 8, 'Despejado', 2481),
#  (2021, 8, 'Nevando', 136),
#  (2021, 8, 'Nublado', 118),
#  (2021, 8, 'Lluvia débil', 98),
#  (2021, 8, 'Se desconoce', 25),
#  (2021, 8, 'LLuvia intensa', 2),
#  (2021, 9, 'Despejado', 2997),
#  (2021, 9, 'Nublado', 310),
#  (2021, 9, 'Lluvia débil', 302),
#  (2021, 9, 'LLuvia intensa', 106),
#  (2021, 9, 'Se desconoce', 37),
#  (2021, 9, 'Nevando', 7),
#  (2021, 10, 'Despejado', 3722),
#  (2021, 10, 'Lluvia débil', 275),
#  (2021, 10, 'LLuvia intensa', 209),
#  (2021, 10, 'Nublado', 163),
#  (2021, 10, 'Se desconoce', 45),
#  (2021, 10, 'Nevando', 2),
#  (2021, 10, 'Granizando', 1),
#  (2021, 11, 'Despejado', 3323),
#  (2021, 11, 'Nublado', 330),
#  (2021, 11, 'Lluvia débil', 168),
#  (2021, 11, 'LLuvia intensa', 37),
#  (2021, 11, 'Se desconoce', 37),
#  (2021, 12, 'Despejado', 3131),
#  (2021, 12, 'Lluvia débil', 390),
#  (2021, 12, 'Nublado', 207),
#  (2021, 12, 'LLuvia intensa', 47),
#  (2021, 12, 'Se desconoce', 36),
#  (2021, 12, 'Nevando', 5),
#  (2022, 1, 'Despejado', 3879),
#  (2022, 1, 'Nublado', 67),
#  (2022, 1, 'Se desconoce', 30),
#  (2022, 1, 'Lluvia débil', 25),
#  (2022, 2, 'Despejado', 3208),
#  (2022, 2, 'Nublado', 222),
#  (2022, 2, 'Lluvia débil', 115),
#  (2022, 2, 'Se desconoce', 34),
#  (2022, 2, 'LLuvia intensa', 17),
#  (2022, 2, 'Granizando', 3),
#  (2022, 3, 'Despejado', 2215),
#  (2022, 3, 'Lluvia débil', 792),
#  (2022, 3, 'Nublado', 728),
#  (2022, 3, 'LLuvia intensa', 137),
#  (2022, 3, 'Se desconoce', 45),
#  (2022, 3, 'Granizando', 2),
#  (2022, 3, 'Nevando', 1),
#  (2022, 4, 'Despejado', 2945),
#  (2022, 4, 'Nublado', 336),
#  (2022, 4, 'Lluvia débil', 335),
#  (2022, 4, 'LLuvia intensa', 147),
#  (2022, 4, 'Se desconoce', 55),
#  (2022, 5, 'Despejado', 4107),
#  (2022, 5, 'Lluvia débil', 189),
#  (2022, 5, 'Nublado', 102),
#  (2022, 5, 'LLuvia intensa', 46),
#  (2022, 5, 'Se desconoce', 21),
#  (2022, 5, 'Granizando', 1),
#  (2022, 6, 'Despejado', 3741),
#  (2022, 6, 'Nublado', 97),
#  (2022, 6, 'Lluvia débil', 40),
#  (2022, 6, 'Se desconoce', 30),
#  (2022, 6, 'LLuvia intensa', 25),
#  (2022, 6, 'Nevando', 1),
#  (2022, 7, 'Despejado', 3474),
#  (2022, 7, 'Nublado', 83),
#  (2022, 7, 'Lluvia débil', 41),
#  (2022, 7, 'Se desconoce', 24),
#  (2022, 7, 'LLuvia intensa', 18),
#  (2022, 8, 'Despejado', 2875),
#  (2022, 8, 'Nublado', 152),
#  (2022, 8, 'Lluvia débil', 104),
#  (2022, 8, 'LLuvia intensa', 45),
#  (2022, 8, 'Se desconoce', 29),
#  (2022, 8, 'Nevando', 2),
#  (2022, 9, 'Despejado', 3272),
#  (2022, 9, 'Nublado', 216),
#  (2022, 9, 'Lluvia débil', 191),
#  (2022, 9, 'LLuvia intensa', 63),
#  (2022, 9, 'Se desconoce', 23),
#  (2022, 10, 'Despejado', 3203),
#  (2022, 10, 'Nublado', 490),
#  (2022, 10, 'Lluvia débil', 412),
#  (2022, 10, 'LLuvia intensa', 46),
#  (2022, 10, 'Se desconoce', 34),
#  (2022, 11, 'Despejado', 2863),
#  (2022, 11, 'Nublado', 609),
#  (2022, 11, 'Lluvia débil', 607),
#  (2022, 11, 'LLuvia intensa', 134),
#  (2022, 11, 'Se desconoce', 31),
#  (2022, 12, 'Despejado', 2583),
#  (2022, 12, 'Lluvia débil', 725),
#  (2022, 12, 'Nublado', 671),
#  (2022, 12, 'LLuvia intensa', 262),
#  (2022, 12, 'Se desconoce', 31),
#  (2022, 12, 'Nevando', 2),
#  (2023, 1, 'Despejado', 3137),
#  (2023, 1, 'Nublado', 205),
#  (2023, 1, 'Lluvia débil', 141),
#  (2023, 1, 'Se desconoce', 31),
#  (2023, 1, 'LLuvia intensa', 25),
#  (2023, 2, 'Despejado', 2819),
#  (2023, 2, 'Nublado', 162),
#  (2023, 2, 'Lluvia débil', 50),
#  (2023, 2, 'Se desconoce', 21),
#  (2023, 3, 'Despejado', 3662),
#  (2023, 3, 'Nublado', 61),
#  (2023, 3, 'Lluvia débil', 25),
#  (2023, 3, 'Se desconoce', 19),
#  (2023, 4, 'Despejado', 3630),
#  (2023, 4, 'Nublado', 105),
#  (2023, 4, 'Se desconoce', 37),
#  (2023, 4, 'Lluvia débil', 37),
#  (2023, 4, 'LLuvia intensa', 8),
#  (2023, 4, 'Granizando', 7),
#  (2023, 5, 'Despejado', 2688),
#  (2023, 5, 'Nublado', 576),
#  (2023, 5, 'Lluvia débil', 310),
#  (2023, 5, 'LLuvia intensa', 83),
#  (2023, 5, 'Se desconoce', 15),
#  (2023, 6, 'Despejado', 3003),
#  (2023, 6, 'Nublado', 171),
#  (2023, 6, 'Lluvia débil', 67),
#  (2023, 6, 'Se desconoce', 27),
#  (2023, 6, 'LLuvia intensa', 6),
#  (2023, 7, 'Despejado', 2972),
#  (2023, 7, 'Lluvia débil', 197),
#  (2023, 7, 'Nublado', 110),
#  (2023, 7, 'Se desconoce', 19),
#  (2023, 7, 'LLuvia intensa', 4),
#  (2023, 8, 'Despejado', 2111),
#  (2023, 8, 'Lluvia débil', 173),
#  (2023, 8, 'Nublado', 119),
#  (2023, 8, 'LLuvia intensa', 26),
#  (2023, 8, 'Se desconoce', 11),
#  (2023, 9, 'Despejado', 960),
#  (2023, 9, 'Nublado', 51),
#  (2023, 9, 'Lluvia débil', 15),
#  (2023, 9, 'LLuvia intensa', 8),
#  (2023, 9, 'Se desconoce', 1),
#  (2023, 10, 'Despejado', 1174),
#  (2023, 10, 'Nublado', 4),
#  (2023, 11, 'Despejado', 970),
#  (2023, 11, 'Nublado', 26),
#  (2023, 11, 'Se desconoce', 7),
#  (2023, 11, 'Lluvia débil', 3),
#  (2023, 12, 'Despejado', 1003),
#  (2023, 12, 'Nublado', 56),
#  (2023, 12, 'Lluvia débil', 8),
#  (2023, 12, 'Se desconoce', 2))

# %% [markdown]
# Cerramos el cursor y la base de datos

# %%
cur.close()
db.close()
